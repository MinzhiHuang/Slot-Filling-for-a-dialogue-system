# %% [markdown]
# # Step 4 Consolidate all outputs from different models
# This notebook consolidates the output from `intent classification model`, `8/11 Slots classification model`, `3/11 Slot classification model`.

# %%
import pandas as pd
from sklearn.metrics import accuracy_score

# %%
dev_files = ["./data/dev.csv","./data/dev_step1.csv", "./data/dev_step2.csv", "./data/dev_step3.csv"]

dev0_df = pd.read_csv(dev_files[0])# processed original dev set
dev1_df = pd.read_csv(dev_files[1],index_col=0)# contains intent prediction
dev2_df = pd.read_csv(dev_files[2],index_col=0)# contains 8/11 slots prediction
dev3_df = pd.read_csv(dev_files[3],index_col=0)# contains 3/11 slots prediction

print(dev0_df.shape)
print(dev1_df.shape)
print(dev2_df.shape)
print(dev3_df.shape)
# Out:
# (413, 5)
# (413, 4)
# (413, 7)
# (413, 7)

# %%
test_files = ["./data/test.csv","./data/test_step1.csv", "./data/test_step2.csv", "./data/test_step3.csv"]

test0_df = pd.read_csv(test_files[0])# processed original test set
test1_df = pd.read_csv(test_files[1],index_col=0)# contains intent prediction
test2_df = pd.read_csv(test_files[2],index_col=0)# contains 8/11 slots prediction
test3_df = pd.read_csv(test_files[3],index_col=0)# contains 3/11 slots prediction

print(test0_df.shape)
print(test1_df.shape)
print(test2_df.shape)
print(test3_df.shape)
# Out:
# (400, 1)
# (400, 3)
# (400, 3)
# (400, 3)

# %%
dev0_df#["answer_raw"]
# Out:
#                                                   text  \
# 0    I'm looking for a local place to dine in the c...
# 1    My husband and I are celebrating our anniversa...
# 2    I'm looking for an expensive restaurant in the...
# 3    Are there any accommodations in the east part ...
# 4    I'm looking for a nice place to stay, somewher...
# ..                                                 ...
# 408  I'm looking for info about 4-star accommodatio...
# 409  I'm looking for a place to eat that is cheap a...
# 410  Hi, I'm looking for an expensive restaurant in...
# 411  Can you help me find a restaurant? I want some...
# 412  I'm going to Cambridge and interested in tryin...
#
#                                             answer_raw  \
# 0    find_restaurant|restaurant-area=centre|restaur...
# 1                                           find_hotel
# 2    find_restaurant|restaurant-area=centre|restaur...
# 3         find_hotel|hotel-area=east|hotel-parking=yes
# 4    find_hotel|hotel-internet=yes|hotel-pricerange...
# ..                                                 ...
# 408        find_hotel|hotel-internet=yes|hotel-stars=4
# 409  find_restaurant|restaurant-area=centre|restaur...
# 410  find_restaurant|restaurant-area=north|restaura...
# 411    find_restaurant|restaurant-pricerange=expensive
# 412        find_restaurant|restaurant-food=traditional
#
#                                                 answer           intent  \
# 0    ['find_restaurant', 'restaurant-area=centre', ...  find_restaurant
# 1                                       ['find_hotel']       find_hotel
# 2    ['find_restaurant', 'restaurant-area=centre', ...  find_restaurant
# 3    ['find_hotel', 'hotel-area=east', 'hotel-parki...       find_hotel
# 4    ['find_hotel', 'hotel-internet=yes', 'hotel-pr...       find_hotel
# ..                                                 ...              ...
# 408  ['find_hotel', 'hotel-internet=yes', 'hotel-st...       find_hotel
# 409  ['find_restaurant', 'restaurant-area=centre', ...  find_restaurant
# 410  ['find_restaurant', 'restaurant-area=north', '...  find_restaurant
# 411  ['find_restaurant', 'restaurant-pricerange=exp...  find_restaurant
# 412  ['find_restaurant', 'restaurant-food=tradition...  find_restaurant
#
#                                                  slots
# 0    {'restaurant-area': 'centre', 'restaurant-food...
# 1                                                   {}
# 2    {'restaurant-area': 'centre', 'restaurant-pric...
# 3       {'hotel-area': 'east', 'hotel-parking': 'yes'}
# 4    {'hotel-internet': 'yes', 'hotel-pricerange': ...
# ..                                                 ...
# 408      {'hotel-internet': 'yes', 'hotel-stars': '4'}
# 409  {'restaurant-area': 'centre', 'restaurant-pric...
# 410  {'restaurant-area': 'north', 'restaurant-price...
# 411             {'restaurant-pricerange': 'expensive'}
# 412                 {'restaurant-food': 'traditional'}
#
# [413 rows x 5 columns]

# %%
# preprocessing before merge:
def preprocess_n_consolidation(df1, df2, df3):
    """
    pass in either (dev1_df, dev2_df, dev3_df) 
    or (test1_df, test2_df, test3_df) for consolidation
    """
    order = [
        "hotel-area","hotel-internet","hotel-name","hotel-parking","hotel-pricerange",'hotel-stars',"hotel-type",
        "restaurant-area","restaurant-food","restaurant-name","restaurant-pricerange",
    ]
    
    df1 = df1.rename(columns={"predicted":"pred_intent"})
    df2 = df2.rename(columns={"pred_slots":"pred_slots_2"})
    df3 = df3.rename(columns={"pred_slots":"pred_slots_3"})
    
    df = df1.merge(df2[["pred_slots_2"]], left_index=True, right_index=True, how="left",validate="1:1")
    df = df.merge(df3[["pred_slots_3"]], left_index=True, right_index=True, how="left",validate="1:1")
    
    df['pred_slots_2'] = df['pred_slots_2'].apply(lambda x: eval(x))
    df['pred_slots_3'] = df['pred_slots_3'].apply(lambda x: eval(x))
    
    def Merge(dict1, dict2):
        res = {**dict1, **dict2}
        return res

    df['pred_slots'] = df.apply(lambda x: Merge(x.pred_slots_2, x.pred_slots_3), axis=1)

    def reorder_dict(dict, order):
        reordered_dict = {key: dict[key] for key in order if key in dict.keys()}
        return reordered_dict

    df['pred_slots'] = df.apply(lambda x: reorder_dict(x.pred_slots, order), axis=1)

    def dict_2_list(dict):
        l = []
        for k, v in dict.items():
            l.append(k +"="+v)
        return l
    
    df['pred_answers'] = df.apply(lambda x: dict_2_list(x.pred_slots), axis=1)

    def to_answer_raw(pred_intent, pred_answers):
        pred_answers.insert(0, pred_intent)
        s = "|".join(pred_answers)
        return s

    df['pred_answer_raw'] = df.apply(lambda x: to_answer_raw(x.pred_intent, x.pred_answers), axis=1)
    
    return(df)

# %%
dev4_df = preprocess_n_consolidation(dev1_df, dev2_df, dev3_df)
# dev4_df

# %%
test4_df = preprocess_n_consolidation(test1_df, test2_df, test3_df)
# test4_df

# %%
slot_names = ['hotel-name', 'hotel-stars', 
              'hotel-area', 'hotel-internet', 
              'hotel-pricerange', 'hotel-parking', 
              'hotel-type',
              'restaurant-food', 
              'restaurant-name', 
              'restaurant-pricerange', 
              'restaurant-area']

def get_accuracy(gold_slots, pred_slots, slot_lists=slot_names):
    """
        return accuracy of predicted slots vs gold slots in dictionary form
    """
    correct_count = 0
    for gold_slot, pred_slot in zip(gold_slots, pred_slots):
        gold = {k:v 
                for k, v in gold_slot.items()
                if k in slot_names
               }
        # print(gold)
        sys = {k:v 
                for k, v in pred_slot.items()
                if k in slot_names
               }
        # print(sys)
        # if gold_slot == pred_slot:
        if gold == sys:
            correct_count += 1
    return correct_count / len(gold_slots)

# %%
#dev
get_accuracy(dev0_df["slots"].apply(lambda x: eval(x)), dev4_df["pred_slots"])
# Out:
# 0.7336561743341404

# %%
#dev
print("Accuracy score =", accuracy_score(dev0_df["answer_raw"], dev4_df["pred_answer_raw"]) * 100)
# Out:
# Accuracy score = 73.36561743341404

# %%
# Output
dev4_df.to_csv("./data/dev_step4.csv")
dev4_df[["text","pred_answer_raw"]].to_csv('./data/dev_pred.txt', sep='\t', index=False)

# %%
# Output test
test4_df.to_csv("./data/test_step4.csv")
test4_df[["text","pred_answer_raw"]].to_csv('./data/test_pred.txt', sep='\t', index=False)

# %%
test4_df
# Out:
#                                                   text  \
# 0    Hello, I am looking for a restaurant in Cambri...
# 1    Hi, I'm looking for a hotel to stay in that in...
# 2    I am looking for a place to stay in the north ...
# 3    I need a place to dine, and I'd like to know w...
# 4    I need a five starts hotel close to a mall and...
# ..                                                 ...
# 395  I am looking for a place to stay. The hotel sh...
# 396  I am looking to book a hotel in the Cambridge ...
# 397  I would like to go to an Indian restaurant in ...
# 398  I'm looking for a place to eat in the centre t...
# 399  I need to get a guesthouse that doesn't have f...
#
#                                             text_lower      pred_intent  \
# 0    hello, i am looking for a restaurant in cambri...  find_restaurant
# 1    hi, i'm looking for a hotel to stay in that in...       find_hotel
# 2    i am looking for a place to stay in the north ...       find_hotel
# 3    i need a place to dine, and i'd like to know w...  find_restaurant
# 4    i need a five starts hotel close to a mall and...       find_hotel
# ..                                                 ...              ...
# 395  i am looking for a place to stay. the hotel sh...       find_hotel
# 396  i am looking to book a hotel in the cambridge ...       find_hotel
# 397  i would like to go to an indian restaurant in ...  find_restaurant
# 398  i'm looking for a place to eat in the centre t...  find_restaurant
# 399  i need to get a guesthouse that doesn't have f...       find_hotel
#
#                                           pred_slots_2  \
# 0                                                   {}
# 1                            {'hotel-internet': 'yes'}
# 2          {'hotel-stars': '4', 'hotel-area': 'north'}
# 3                                                   {}
# 4                            {'hotel-internet': 'yes'}
# ..                                                 ...
# 395                            {'hotel-area': 'north'}
# 396                                                 {}
# 397                       {'restaurant-area': 'north'}
# 398                      {'restaurant-area': 'centre'}
# 399  {'hotel-parking': 'yes', 'hotel-type': 'guesth...
#
#                               pred_slots_3  \
# 0        {'restaurant-name': 'golden wok'}
# 1                                       {}
# 2                                       {}
# 3    {'restaurant-food': 'asian oriental'}
# 4                                       {}
# ..                                     ...
# 395                                     {}
# 396                                     {}
# 397          {'restaurant-food': 'indian'}
# 398         {'restaurant-food': 'chinese'}
# 399                                     {}
#
#                                             pred_slots  \
# 0                    {'restaurant-name': 'golden wok'}
# 1                            {'hotel-internet': 'yes'}
# 2          {'hotel-area': 'north', 'hotel-stars': '4'}
# 3                {'restaurant-food': 'asian oriental'}
# 4                            {'hotel-internet': 'yes'}
# ..                                                 ...
# 395                            {'hotel-area': 'north'}
# 396                                                 {}
# 397  {'restaurant-area': 'north', 'restaurant-food'...
# 398  {'restaurant-area': 'centre', 'restaurant-food...
# 399  {'hotel-parking': 'yes', 'hotel-type': 'guesth...
#
#                                           pred_answers  \
# 0        [find_restaurant, restaurant-name=golden wok]
# 1                     [find_hotel, hotel-internet=yes]
# 2        [find_hotel, hotel-area=north, hotel-stars=4]
# 3    [find_restaurant, restaurant-food=asian oriental]
# 4                     [find_hotel, hotel-internet=yes]
# ..                                                 ...
# 395                     [find_hotel, hotel-area=north]
# 396                                       [find_hotel]
# 397  [find_restaurant, restaurant-area=north, resta...
# 398  [find_restaurant, restaurant-area=centre, rest...
# 399  [find_hotel, hotel-parking=yes, hotel-type=gue...
#
#                                        pred_answer_raw
# 0           find_restaurant|restaurant-name=golden wok
# 1                        find_hotel|hotel-internet=yes
# 2            find_hotel|hotel-area=north|hotel-stars=4
# 3       find_restaurant|restaurant-food=asian oriental
# 4                        find_hotel|hotel-internet=yes
# ..                                                 ...
# 395                        find_hotel|hotel-area=north
# 396                                         find_hotel
# 397  find_restaurant|restaurant-area=north|restaura...
# 398  find_restaurant|restaurant-area=centre|restaur...
# 399  find_hotel|hotel-parking=yes|hotel-type=guesth...
#
# [400 rows x 8 columns]

# %%
kaggle_df = test4_df.copy()
kaggle_df = kaggle_df.reset_index()


kaggle_df = kaggle_df.rename(columns={"index":"ID", "pred_answer_raw":"Expected"})

kaggle_df[["ID", "Expected"]].to_csv('./data/WOZ_test_ans.csv', index=False)

# %%
kaggle_df[kaggle_df["Expected"].str.contains("restaurant-name")]
# Out:
#       ID                                               text  \
# 0      0  Hello, I am looking for a restaurant in Cambri...
# 15    15     i am looking for the chiquito restaurant bar\n
# 16    16  I need information about a certain restaurant ...
# 18    18  I'm looking for this restaurant called pizza h...
# 27    27      I am looking for a restaurant named Meghna.\n
# 38    38  Hello, I would like some information about a r...
# 70    70  I'm looking for a restaurant called nandos. Ar...
# 82    82                Find me a restaurant called cocum\n
# 94    94  Hi, I'm trying to find out more about a restau...
# 95    95  i need info about the slug and lettuce restaur...
# 117  117  I'm looking for a restaurant called "restauran...
# 123  123  I'm trying to get some information on the than...
# 129  129  Yes I am looking for information on a restaura...
# 159  159  I am looking for a place to eat by the name of...
# 173  173  What is the address for Pizza Hut in Cherry Hi...
# 217  217  I am looking for information on a restaurant c...
# 257  257  Can you get me information on a restaurant cal...
# 272  272  I am looking for the gardenia restaurant a fri...
# 273  273  I need information on a restaurant called curr...
# 283  283  I'm looking for a restaurant called the varsit...
# 293  293  Hello, I am looking for a restaurant called me...
# 317  317  I'm looking for info about a restaurant in Cam...
# 330  330    I'm looking for the restaurant named La Raza.\n
# 344  344  I am looking for a restaurant called golden wo...
# 352  352   I am looking for a restaurant called loch fyne\n
# 354  354  I'm looking for a restaurant called la margher...
# 361  361  I'm looking for the information on a restauran...
# 364  364  Please find a restaurant called stazione resta...
# 372  372  I am looking for a restaurant called darrys co...
#
#                                             text_lower      pred_intent  \
# 0    hello, i am looking for a restaurant in cambri...  find_restaurant
# 15      i am looking for the chiquito restaurant bar\n  find_restaurant
# 16   i need information about a certain restaurant ...  find_restaurant
# 18   i'm looking for this restaurant called pizza h...  find_restaurant
# 27       i am looking for a restaurant named meghna.\n  find_restaurant
# 38   hello, i would like some information about a r...  find_restaurant
# 70   i'm looking for a restaurant called nandos. ar...  find_restaurant
# 82                 find me a restaurant called cocum\n  find_restaurant
# 94   hi, i'm trying to find out more about a restau...  find_restaurant
# 95   i need info about the slug and lettuce restaur...  find_restaurant
# 117  i'm looking for a restaurant called "restauran...  find_restaurant
# 123  i'm trying to get some information on the than...  find_restaurant
# 129  yes i am looking for information on a restaura...  find_restaurant
# 159  i am looking for a place to eat by the name of...  find_restaurant
# 173  what is the address for pizza hut in cherry hi...  find_restaurant
# 217  i am looking for information on a restaurant c...  find_restaurant
# 257  can you get me information on a restaurant cal...  find_restaurant
# 272  i am looking for the gardenia restaurant a fri...  find_restaurant
# 273  i need information on a restaurant called curr...  find_restaurant
# 283  i'm looking for a restaurant called the varsit...  find_restaurant
# 293  hello, i am looking for a restaurant called me...  find_restaurant
# 317  i'm looking for info about a restaurant in cam...  find_restaurant
# 330    i'm looking for the restaurant named la raza.\n  find_restaurant
# 344  i am looking for a restaurant called golden wo...  find_restaurant
# 352   i am looking for a restaurant called loch fyne\n  find_restaurant
# 354  i'm looking for a restaurant called la margher...  find_restaurant
# 361  i'm looking for the information on a restauran...  find_restaurant
# 364  please find a restaurant called stazione resta...  find_restaurant
# 372  i am looking for a restaurant called darrys co...  find_restaurant
#
#     pred_slots_2                                       pred_slots_3  \
# 0             {}                  {'restaurant-name': 'golden wok'}
# 15            {}     {'restaurant-name': 'chiquito restaurant bar'}
# 16            {}                {'restaurant-name': 'charlie chan'}
# 18            {}        {'restaurant-name': 'pizza hut fen ditton'}
# 27            {}                      {'restaurant-name': 'meghna'}
# 38            {}                     {'restaurant-name': 'bedouin'}
# 70            {}                      {'restaurant-name': 'nandos'}
# 82            {}                       {'restaurant-name': 'cocum'}
# 94            {}                       {'restaurant-name': 'cocum'}
# 95            {}  {'restaurant-name': 'slug and lettuce restaura...
# 117           {}        {'restaurant-name': 'restaurant one seven'}
# 123           {}                  {'restaurant-name': 'thanh binh'}
# 129           {}                {'restaurant-name': 'bangkok city'}
# 159           {}        {'restaurant-name': 'city stop restaurant'}
# 173           {}                   {'restaurant-name': 'pizza hut'}
# 217           {}                    {'restaurant-name': 'kohinoor'}
# 257           {}          {'restaurant-name': 'mahal of cambridge'}
# 272           {}                    {'restaurant-name': 'gardenia'}
# 273           {}                {'restaurant-name': 'curry garden'}
# 283           {}          {'restaurant-name': 'varsity restaurant'}
# 293           {}                    {'restaurant-name': 'meze bar'}
# 317           {}                {'restaurant-name': 'little seoul'}
# 330           {}                     {'restaurant-name': 'la raza'}
# 344           {}                  {'restaurant-name': 'golden wok'}
# 352           {}                   {'restaurant-name': 'loch fyne'}
# 354           {}               {'restaurant-name': 'la margherita'}
# 361           {}                 {'restaurant-name': 'saigon city'}
# 364           {}                    {'restaurant-name': 'stazione'}
# 372           {}            {'restaurant-name': 'darrys cookhouse'}
#
#                                             pred_slots  \
# 0                    {'restaurant-name': 'golden wok'}
# 15      {'restaurant-name': 'chiquito restaurant bar'}
# 16                 {'restaurant-name': 'charlie chan'}
# 18         {'restaurant-name': 'pizza hut fen ditton'}
# 27                       {'restaurant-name': 'meghna'}
# 38                      {'restaurant-name': 'bedouin'}
# 70                       {'restaurant-name': 'nandos'}
# 82                        {'restaurant-name': 'cocum'}
# 94                        {'restaurant-name': 'cocum'}
# 95   {'restaurant-name': 'slug and lettuce restaura...
# 117        {'restaurant-name': 'restaurant one seven'}
# 123                  {'restaurant-name': 'thanh binh'}
# 129                {'restaurant-name': 'bangkok city'}
# 159        {'restaurant-name': 'city stop restaurant'}
# 173                   {'restaurant-name': 'pizza hut'}
# 217                    {'restaurant-name': 'kohinoor'}
# 257          {'restaurant-name': 'mahal of cambridge'}
# 272                    {'restaurant-name': 'gardenia'}
# 273                {'restaurant-name': 'curry garden'}
# 283          {'restaurant-name': 'varsity restaurant'}
# 293                    {'restaurant-name': 'meze bar'}
# 317                {'restaurant-name': 'little seoul'}
# 330                     {'restaurant-name': 'la raza'}
# 344                  {'restaurant-name': 'golden wok'}
# 352                   {'restaurant-name': 'loch fyne'}
# 354               {'restaurant-name': 'la margherita'}
# 361                 {'restaurant-name': 'saigon city'}
# 364                    {'restaurant-name': 'stazione'}
# 372            {'restaurant-name': 'darrys cookhouse'}
#
#                                           pred_answers  \
# 0        [find_restaurant, restaurant-name=golden wok]
# 15   [find_restaurant, restaurant-name=chiquito res...
# 16     [find_restaurant, restaurant-name=charlie chan]
# 18   [find_restaurant, restaurant-name=pizza hut fe...
# 27           [find_restaurant, restaurant-name=meghna]
# 38          [find_restaurant, restaurant-name=bedouin]
# 70           [find_restaurant, restaurant-name=nandos]
# 82            [find_restaurant, restaurant-name=cocum]
# 94            [find_restaurant, restaurant-name=cocum]
# 95   [find_restaurant, restaurant-name=slug and let...
# 117  [find_restaurant, restaurant-name=restaurant o...
# 123      [find_restaurant, restaurant-name=thanh binh]
# 129    [find_restaurant, restaurant-name=bangkok city]
# 159  [find_restaurant, restaurant-name=city stop re...
# 173       [find_restaurant, restaurant-name=pizza hut]
# 217        [find_restaurant, restaurant-name=kohinoor]
# 257  [find_restaurant, restaurant-name=mahal of cam...
# 272        [find_restaurant, restaurant-name=gardenia]
# 273    [find_restaurant, restaurant-name=curry garden]
# 283  [find_restaurant, restaurant-name=varsity rest...
# 293        [find_restaurant, restaurant-name=meze bar]
# 317    [find_restaurant, restaurant-name=little seoul]
# 330         [find_restaurant, restaurant-name=la raza]
# 344      [find_restaurant, restaurant-name=golden wok]
# 352       [find_restaurant, restaurant-name=loch fyne]
# 354   [find_restaurant, restaurant-name=la margherita]
# 361     [find_restaurant, restaurant-name=saigon city]
# 364        [find_restaurant, restaurant-name=stazione]
# 372  [find_restaurant, restaurant-name=darrys cookh...
#
#                                               Expected
# 0           find_restaurant|restaurant-name=golden wok
# 15   find_restaurant|restaurant-name=chiquito resta...
# 16        find_restaurant|restaurant-name=charlie chan
# 18   find_restaurant|restaurant-name=pizza hut fen ...
# 27              find_restaurant|restaurant-name=meghna
# 38             find_restaurant|restaurant-name=bedouin
# 70              find_restaurant|restaurant-name=nandos
# 82               find_restaurant|restaurant-name=cocum
# 94               find_restaurant|restaurant-name=cocum
# 95   find_restaurant|restaurant-name=slug and lettu...
# 117  find_restaurant|restaurant-name=restaurant one...
# 123         find_restaurant|restaurant-name=thanh binh
# 129       find_restaurant|restaurant-name=bangkok city
# 159  find_restaurant|restaurant-name=city stop rest...
# 173          find_restaurant|restaurant-name=pizza hut
# 217           find_restaurant|restaurant-name=kohinoor
# 257  find_restaurant|restaurant-name=mahal of cambr...
# 272           find_restaurant|restaurant-name=gardenia
# 273       find_restaurant|restaurant-name=curry garden
# 283  find_restaurant|restaurant-name=varsity restau...
# 293           find_restaurant|restaurant-name=meze bar
# 317       find_restaurant|restaurant-name=little seoul
# 330            find_restaurant|restaurant-name=la raza
# 344         find_restaurant|restaurant-name=golden wok
# 352          find_restaurant|restaurant-name=loch fyne
# 354      find_restaurant|restaurant-name=la margherita
# 361        find_restaurant|restaurant-name=saigon city
# 364           find_restaurant|restaurant-name=stazione
# 372   find_restaurant|restaurant-name=darrys cookhouse
