# %% [markdown]
# ## 03 - Hotel Information Extraction
# In this notebook, we try using simple classifier to extract some information on hotel like price-range, location, etc

# %%
import pandas as pd

# %%
train_file = "./data/train.csv"
train_df = pd.read_csv(train_file)
train_df.head()
# Out:
#                                                 text  \
# 0  Guten Tag, I am staying overnight in Cambridge...
# 1  Hi there! Can you give me some info on Cityroomz?
# 2  I am looking for a hotel named alyesbray lodge...
# 3  I am looking for a restaurant. I would like so...
# 4  I'm looking for an expensive restaurant in the...
#
#                                               answer           intent  \
# 0  ['find_hotel', 'hotel-area=centre', 'hotel-int...       find_hotel
# 1             ['find_hotel', 'hotel-name=cityroomz']       find_hotel
# 2  ['find_hotel', 'hotel-name=alyesbray lodge gue...       find_hotel
# 3  ['find_restaurant', 'restaurant-food=chinese',...  find_restaurant
# 4  ['find_restaurant', 'restaurant-area=centre', ...  find_restaurant
#
#                                                slots
# 0  {'hotel-area': 'centre', 'hotel-internet': 'ye...
# 1                        {'hotel-name': 'cityroomz'}
# 2      {'hotel-name': 'alyesbray lodge guest house'}
# 3  {'restaurant-food': 'chinese', 'restaurant-pri...
# 4  {'restaurant-area': 'centre', 'restaurant-pric...

# %%
train_df["text_lower"] = train_df["text"].str.lower()

# %%
# convert slots to json objects
train_df["slots"] = train_df["slots"].apply(lambda s: eval(s))
train_df.head()
# Out:
#                                                 text  \
# 0  Guten Tag, I am staying overnight in Cambridge...
# 1  Hi there! Can you give me some info on Cityroomz?
# 2  I am looking for a hotel named alyesbray lodge...
# 3  I am looking for a restaurant. I would like so...
# 4  I'm looking for an expensive restaurant in the...
#
#                                               answer           intent  \
# 0  ['find_hotel', 'hotel-area=centre', 'hotel-int...       find_hotel
# 1             ['find_hotel', 'hotel-name=cityroomz']       find_hotel
# 2  ['find_hotel', 'hotel-name=alyesbray lodge gue...       find_hotel
# 3  ['find_restaurant', 'restaurant-food=chinese',...  find_restaurant
# 4  ['find_restaurant', 'restaurant-area=centre', ...  find_restaurant
#
#                                                slots  \
# 0  {'hotel-area': 'centre', 'hotel-internet': 'ye...
# 1                        {'hotel-name': 'cityroomz'}
# 2      {'hotel-name': 'alyesbray lodge guest house'}
# 3  {'restaurant-food': 'chinese', 'restaurant-pri...
# 4  {'restaurant-area': 'centre', 'restaurant-pric...
#
#                                           text_lower
# 0  guten tag, i am staying overnight in cambridge...
# 1  hi there! can you give me some info on cityroomz?
# 2  i am looking for a hotel named alyesbray lodge...
# 3  i am looking for a restaurant. i would like so...
# 4  i'm looking for an expensive restaurant in the...

# %%
# filter to hotel only
category = 'find_hotel'
train_df = train_df.query("intent==@category")
print(len(train_df))
train_df.head()
# Out:
# 1609
#                                                 text  \
# 0  Guten Tag, I am staying overnight in Cambridge...
# 1  Hi there! Can you give me some info on Cityroomz?
# 2  I am looking for a hotel named alyesbray lodge...
# 5  I'm looking for a places to go and see during ...
# 9         I need a place to stay that has free wifi.
#
#                                               answer      intent  \
# 0  ['find_hotel', 'hotel-area=centre', 'hotel-int...  find_hotel
# 1             ['find_hotel', 'hotel-name=cityroomz']  find_hotel
# 2  ['find_hotel', 'hotel-name=alyesbray lodge gue...  find_hotel
# 5                                     ['find_hotel']  find_hotel
# 9               ['find_hotel', 'hotel-internet=yes']  find_hotel
#
#                                                slots  \
# 0  {'hotel-area': 'centre', 'hotel-internet': 'ye...
# 1                        {'hotel-name': 'cityroomz'}
# 2      {'hotel-name': 'alyesbray lodge guest house'}
# 5                                                 {}
# 9                          {'hotel-internet': 'yes'}
#
#                                           text_lower
# 0  guten tag, i am staying overnight in cambridge...
# 1  hi there! can you give me some info on cityroomz?
# 2  i am looking for a hotel named alyesbray lodge...
# 5  i'm looking for a places to go and see during ...
# 9         i need a place to stay that has free wifi.

# %%
# extract slot price-range
k = 60
# item = eval(train_df.iloc[k]["slots"])
item = train_df.iloc[k]["slots"]
print(item)
item.keys()
# Out:
# {'hotel-pricerange': 'moderate', 'hotel-type': 'guesthouse'}
# dict_keys(['hotel-pricerange', 'hotel-type'])

# %%
# kw = 'hotel-pricerange'
kw = 'hotel-stars'
train_df["target"] = train_df["slots"].apply(lambda slots:slots.get(kw, ""))
train_df.head()
# Out:
#                                                 text  \
# 0  Guten Tag, I am staying overnight in Cambridge...
# 1  Hi there! Can you give me some info on Cityroomz?
# 2  I am looking for a hotel named alyesbray lodge...
# 5  I'm looking for a places to go and see during ...
# 9         I need a place to stay that has free wifi.
#
#                                               answer      intent  \
# 0  ['find_hotel', 'hotel-area=centre', 'hotel-int...  find_hotel
# 1             ['find_hotel', 'hotel-name=cityroomz']  find_hotel
# 2  ['find_hotel', 'hotel-name=alyesbray lodge gue...  find_hotel
# 5                                     ['find_hotel']  find_hotel
# 9               ['find_hotel', 'hotel-internet=yes']  find_hotel
#
#                                                slots  \
# 0  {'hotel-area': 'centre', 'hotel-internet': 'ye...
# 1                        {'hotel-name': 'cityroomz'}
# 2      {'hotel-name': 'alyesbray lodge guest house'}
# 5                                                 {}
# 9                          {'hotel-internet': 'yes'}
#
#                                           text_lower target
# 0  guten tag, i am staying overnight in cambridge...
# 1  hi there! can you give me some info on cityroomz?
# 2  i am looking for a hotel named alyesbray lodge...
# 5  i'm looking for a places to go and see during ...
# 9         i need a place to stay that has free wifi.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
vectorizer = TfidfVectorizer()
x_train = train_df["text_lower"]
x_train_tfidf = vectorizer.fit_transform(x_train)
print(x_train_tfidf.shape)
# Out:
# (1609, 568)

# %%
# train using logistic regression

# %%
# kw = 'hotel-internet'
clf = LogisticRegression(random_state=42)
y_train = train_df["target"]
print(y_train.shape)
clf.fit(x_train_tfidf, y_train)
print("Completed")
# Out:
# (1609,)
# Completed

# %%
y_pred = clf.predict(x_train_tfidf)
print("Train score =", clf.score(x_train_tfidf, y_train))
print("Accuracy score =", accuracy_score(y_train, y_pred)) # should be the same
# Out:
# Train score = 0.906152889993785
# Accuracy score = 0.906152889993785

# %%
# test on dev set
dev_filename = "./data/dev.csv"
dev_df = pd.read_csv(dev_filename)
print(dev_df.columns)
dev_df.head()
# Out:
# Index(['text', 'answer_raw', 'answer', 'intent', 'slots'], dtype='object')
#                                                 text  \
# 0  I'm looking for a local place to dine in the c...
# 1  My husband and I are celebrating our anniversa...
# 2  I'm looking for an expensive restaurant in the...
# 3  Are there any accommodations in the east part ...
# 4  I'm looking for a nice place to stay, somewher...
#
#                                           answer_raw  \
# 0  find_restaurant|restaurant-area=centre|restaur...
# 1                                         find_hotel
# 2  find_restaurant|restaurant-area=centre|restaur...
# 3       find_hotel|hotel-area=east|hotel-parking=yes
# 4  find_hotel|hotel-internet=yes|hotel-pricerange...
#
#                                               answer           intent  \
# 0  ['find_restaurant', 'restaurant-area=centre', ...  find_restaurant
# 1                                     ['find_hotel']       find_hotel
# 2  ['find_restaurant', 'restaurant-area=centre', ...  find_restaurant
# 3  ['find_hotel', 'hotel-area=east', 'hotel-parki...       find_hotel
# 4  ['find_hotel', 'hotel-internet=yes', 'hotel-pr...       find_hotel
#
#                                                slots
# 0  {'restaurant-area': 'centre', 'restaurant-food...
# 1                                                 {}
# 2  {'restaurant-area': 'centre', 'restaurant-pric...
# 3     {'hotel-area': 'east', 'hotel-parking': 'yes'}
# 4  {'hotel-internet': 'yes', 'hotel-pricerange': ...

# %%
# apply some pre-processing
dev_df["text_lower"] = dev_df["text"].str.lower()
# convert slots to json objects
dev_df["slots"] = dev_df["slots"].apply(lambda s: eval(s))
dev_df.head()
# Out:
#                                                 text  \
# 0  I'm looking for a local place to dine in the c...
# 1  My husband and I are celebrating our anniversa...
# 2  I'm looking for an expensive restaurant in the...
# 3  Are there any accommodations in the east part ...
# 4  I'm looking for a nice place to stay, somewher...
#
#                                           answer_raw  \
# 0  find_restaurant|restaurant-area=centre|restaur...
# 1                                         find_hotel
# 2  find_restaurant|restaurant-area=centre|restaur...
# 3       find_hotel|hotel-area=east|hotel-parking=yes
# 4  find_hotel|hotel-internet=yes|hotel-pricerange...
#
#                                               answer           intent  \
# 0  ['find_restaurant', 'restaurant-area=centre', ...  find_restaurant
# 1                                     ['find_hotel']       find_hotel
# 2  ['find_restaurant', 'restaurant-area=centre', ...  find_restaurant
# 3  ['find_hotel', 'hotel-area=east', 'hotel-parki...       find_hotel
# 4  ['find_hotel', 'hotel-internet=yes', 'hotel-pr...       find_hotel
#
#                                                slots  \
# 0  {'restaurant-area': 'centre', 'restaurant-food...
# 1                                                 {}
# 2  {'restaurant-area': 'centre', 'restaurant-pric...
# 3     {'hotel-area': 'east', 'hotel-parking': 'yes'}
# 4  {'hotel-internet': 'yes', 'hotel-pricerange': ...
#
#                                           text_lower
# 0  i'm looking for a local place to dine in the c...
# 1  my husband and i are celebrating our anniversa...
# 2  i'm looking for an expensive restaurant in the...
# 3  are there any accommodations in the east part ...
# 4  i'm looking for a nice place to stay, somewher...

# %%
# extract price-range
# kw = 'hotel-pricerange'

dev_df["target"] = dev_df["slots"].apply(lambda slots:slots.get(kw, ""))
dev_df.head()
# Out:
#                                                 text  \
# 0  I'm looking for a local place to dine in the c...
# 1  My husband and I are celebrating our anniversa...
# 2  I'm looking for an expensive restaurant in the...
# 3  Are there any accommodations in the east part ...
# 4  I'm looking for a nice place to stay, somewher...
#
#                                           answer_raw  \
# 0  find_restaurant|restaurant-area=centre|restaur...
# 1                                         find_hotel
# 2  find_restaurant|restaurant-area=centre|restaur...
# 3       find_hotel|hotel-area=east|hotel-parking=yes
# 4  find_hotel|hotel-internet=yes|hotel-pricerange...
#
#                                               answer           intent  \
# 0  ['find_restaurant', 'restaurant-area=centre', ...  find_restaurant
# 1                                     ['find_hotel']       find_hotel
# 2  ['find_restaurant', 'restaurant-area=centre', ...  find_restaurant
# 3  ['find_hotel', 'hotel-area=east', 'hotel-parki...       find_hotel
# 4  ['find_hotel', 'hotel-internet=yes', 'hotel-pr...       find_hotel
#
#                                                slots  \
# 0  {'restaurant-area': 'centre', 'restaurant-food...
# 1                                                 {}
# 2  {'restaurant-area': 'centre', 'restaurant-pric...
# 3     {'hotel-area': 'east', 'hotel-parking': 'yes'}
# 4  {'hotel-internet': 'yes', 'hotel-pricerange': ...
#
#                                           text_lower target
# 0  i'm looking for a local place to dine in the c...
# 1  my husband and i are celebrating our anniversa...
# 2  i'm looking for an expensive restaurant in the...
# 3  are there any accommodations in the east part ...
# 4  i'm looking for a nice place to stay, somewher...

# %%
x_dev = dev_df["text"]
x_dev_tfidf = vectorizer.transform(x_dev)
print(x_dev_tfidf.shape)
y_dev = dev_df["target"]
dev_score = clf.score(x_dev_tfidf, y_dev)
dev_pred = clf.predict(x_dev_tfidf)
print("Slot prediction =", kw)
print("Dev accuracy =", accuracy_score(y_dev, dev_pred) * 100)
print("Dev accuracy =", dev_score * 100)
# Out:
# (413, 568)
# Slot prediction = hotel-stars
# Dev accuracy = 95.88377723970945
# Dev accuracy = 95.88377723970945

# %%
from collections import Counter
Counter(dev_pred)
# Out:
# Counter({'': 385, '4': 26, '3': 2})

# %%
# find where it predicted wrong
dev_df["predicted"] = dev_pred
wrong_df = dev_df.query("predicted != target")
print(f"Number of wrong counts = {len(wrong_df)} / {len(dev_df)}")
wrong_df
# Out:
# Number of wrong counts = 17 / 413
#                                                   text  \
# 18   Yes, hello. I need a place to crash so I'm thi...
# 47   Hello, I am trying to find a place to stay tha...
# 87   I am looking for a place to stay in Cambridge....
# 94   I am looking for a 3 star hotel on the south s...
# 98   I need to find a guesthouse with a 0 star rating.
# 109  Hello! I am looking for a place to stay. I wou...
# 155  Can you give me any info on whether you have a...
# 193  Hi there. I'm going on vacation and need a 3-s...
# 240  Hello, could you help me with finding a restau...
# 243  I'm looking for a 0 star hotel that is expensive.
# 254  Hi! I am looking for a place to stay, could yo...
# 313  I am looking for a place to stay. I need a 2 s...
# 337  I am looking for hotel with 3 star and free pa...
# 345  find me a place to stay which has 0 star and p...
# 355   Hello, can you recommend a 0 star place to stay?
# 396  I'd like to find a place to stay with a zero s...
# 408  I'm looking for info about 4-star accommodatio...
#
#                                             answer_raw  \
# 18      find_hotel|hotel-stars=0|hotel-type=guesthouse
# 47         find_hotel|hotel-internet=yes|hotel-stars=3
# 87          find_hotel|hotel-parking=yes|hotel-stars=4
# 94           find_hotel|hotel-area=south|hotel-stars=3
# 98      find_hotel|hotel-stars=0|hotel-type=guesthouse
# 109  find_hotel|hotel-pricerange=moderate|hotel-sta...
# 155                           find_hotel|hotel-stars=2
# 193                           find_hotel|hotel-stars=3
# 240     find_restaurant|restaurant-name=the lucky star
# 243  find_hotel|hotel-pricerange=expensive|hotel-st...
# 254        find_hotel|hotel-internet=yes|hotel-stars=4
# 313         find_hotel|hotel-parking=yes|hotel-stars=2
# 337         find_hotel|hotel-parking=yes|hotel-stars=3
# 345     find_hotel|hotel-stars=0|hotel-type=guesthouse
# 355                           find_hotel|hotel-stars=0
# 396        find_hotel|hotel-internet=yes|hotel-stars=0
# 408        find_hotel|hotel-internet=yes|hotel-stars=4
#
#                                                 answer           intent  \
# 18   ['find_hotel', 'hotel-stars=0', 'hotel-type=gu...       find_hotel
# 47   ['find_hotel', 'hotel-internet=yes', 'hotel-st...       find_hotel
# 87   ['find_hotel', 'hotel-parking=yes', 'hotel-sta...       find_hotel
# 94   ['find_hotel', 'hotel-area=south', 'hotel-star...       find_hotel
# 98   ['find_hotel', 'hotel-stars=0', 'hotel-type=gu...       find_hotel
# 109  ['find_hotel', 'hotel-pricerange=moderate', 'h...       find_hotel
# 155                    ['find_hotel', 'hotel-stars=2']       find_hotel
# 193                    ['find_hotel', 'hotel-stars=3']       find_hotel
# 240  ['find_restaurant', 'restaurant-name=the lucky...  find_restaurant
# 243  ['find_hotel', 'hotel-pricerange=expensive', '...       find_hotel
# 254  ['find_hotel', 'hotel-internet=yes', 'hotel-st...       find_hotel
# 313  ['find_hotel', 'hotel-parking=yes', 'hotel-sta...       find_hotel
# 337  ['find_hotel', 'hotel-parking=yes', 'hotel-sta...       find_hotel
# 345  ['find_hotel', 'hotel-stars=0', 'hotel-type=gu...       find_hotel
# 355                    ['find_hotel', 'hotel-stars=0']       find_hotel
# 396  ['find_hotel', 'hotel-internet=yes', 'hotel-st...       find_hotel
# 408  ['find_hotel', 'hotel-internet=yes', 'hotel-st...       find_hotel
#
#                                                  slots  \
# 18    {'hotel-stars': '0', 'hotel-type': 'guesthouse'}
# 47       {'hotel-internet': 'yes', 'hotel-stars': '3'}
# 87        {'hotel-parking': 'yes', 'hotel-stars': '4'}
# 94         {'hotel-area': 'south', 'hotel-stars': '3'}
# 98    {'hotel-stars': '0', 'hotel-type': 'guesthouse'}
# 109  {'hotel-pricerange': 'moderate', 'hotel-stars'...
# 155                               {'hotel-stars': '2'}
# 193                               {'hotel-stars': '3'}
# 240              {'restaurant-name': 'the lucky star'}
# 243  {'hotel-pricerange': 'expensive', 'hotel-stars...
# 254      {'hotel-internet': 'yes', 'hotel-stars': '4'}
# 313       {'hotel-parking': 'yes', 'hotel-stars': '2'}
# 337       {'hotel-parking': 'yes', 'hotel-stars': '3'}
# 345   {'hotel-stars': '0', 'hotel-type': 'guesthouse'}
# 355                               {'hotel-stars': '0'}
# 396      {'hotel-internet': 'yes', 'hotel-stars': '0'}
# 408      {'hotel-internet': 'yes', 'hotel-stars': '4'}
#
#                                             text_lower target predicted
# 18   yes, hello. i need a place to crash so i'm thi...      0         4
# 47   hello, i am trying to find a place to stay tha...      3
# 87   i am looking for a place to stay in cambridge....      4
# 94   i am looking for a 3 star hotel on the south s...      3         4
# 98   i need to find a guesthouse with a 0 star rating.      0         4
# 109  hello! i am looking for a place to stay. i wou...      2
# 155  can you give me any info on whether you have a...      2
# 193  hi there. i'm going on vacation and need a 3-s...      3
# 240  hello, could you help me with finding a restau...                4
# 243  i'm looking for a 0 star hotel that is expensive.      0         4
# 254  hi! i am looking for a place to stay, could yo...      4
# 313  i am looking for a place to stay. i need a 2 s...      2         4
# 337  i am looking for hotel with 3 star and free pa...      3         4
# 345  find me a place to stay which has 0 star and p...      0         4
# 355   hello, can you recommend a 0 star place to stay?      0         4
# 396  i'd like to find a place to stay with a zero s...      0         4
# 408  i'm looking for info about 4-star accommodatio...      4

# %%
# find where it predicted correctly, and not null
non_null_count = len(dev_df.query("target != ''"))
dev_df["predicted"] = dev_pred
correct_df = dev_df.query("predicted != '' and predicted == target")
print(f"Number of correct counts = {len(correct_df)} / {non_null_count}")
correct_df
# Out:
# Number of correct counts = 18 / 34
#                                                   text  \
# 5         I'm looking for a 4 star hotel in the south.
# 33   I need to book a hotel in the east that has 4 ...
# 40   Hello. I'm looking for a hotel on the north en...
# 61   I'm looking for a place to stay. I would like ...
# 62   i am looking for a place to stay. The hotel sh...
# 91   Hi I am looking for a 4 star guesthouse. Can y...
# 127           I need a 4 star hotel on the north side.
# 130  I'd like to find a 4 star hotel with free wifi...
# 131       I'd like a 4 star hotel in the west, please.
# 151  I am looking for a place to stay. Ideally, it ...
# 166        Can you find me a three star place to stay?
# 178  I'm looking for a 4 star hotel with a moderate...
# 199  I am looking for a place to stay with a 4 star...
# 205  Can you please help me find a place to stay, s...
# 210   I need a place to stay that has a 4 star rating.
# 282  I want to find a four star hotel that has free...
# 363  Hi, I'd like a hotel with a star of 4 on the e...
# 370  I am looking for a hotel with a three star rat...
#
#                                             answer_raw  \
# 5            find_hotel|hotel-area=south|hotel-stars=4
# 33            find_hotel|hotel-area=east|hotel-stars=4
# 40           find_hotel|hotel-area=north|hotel-stars=4
# 61      find_hotel|hotel-stars=4|hotel-type=guesthouse
# 62      find_hotel|hotel-stars=4|hotel-type=guesthouse
# 91      find_hotel|hotel-stars=4|hotel-type=guesthouse
# 127          find_hotel|hotel-area=north|hotel-stars=4
# 130        find_hotel|hotel-internet=yes|hotel-stars=4
# 131           find_hotel|hotel-area=west|hotel-stars=4
# 151     find_hotel|hotel-stars=4|hotel-type=guesthouse
# 166                           find_hotel|hotel-stars=3
# 178  find_hotel|hotel-area=dontcare|hotel-pricerang...
# 199        find_hotel|hotel-internet=yes|hotel-stars=4
# 205         find_hotel|hotel-parking=yes|hotel-stars=4
# 210                           find_hotel|hotel-stars=4
# 282        find_hotel|hotel-internet=yes|hotel-stars=4
# 363           find_hotel|hotel-area=east|hotel-stars=4
# 370    find_hotel|hotel-pricerange=cheap|hotel-stars=3
#
#                                                 answer      intent  \
# 5    ['find_hotel', 'hotel-area=south', 'hotel-star...  find_hotel
# 33   ['find_hotel', 'hotel-area=east', 'hotel-stars...  find_hotel
# 40   ['find_hotel', 'hotel-area=north', 'hotel-star...  find_hotel
# 61   ['find_hotel', 'hotel-stars=4', 'hotel-type=gu...  find_hotel
# 62   ['find_hotel', 'hotel-stars=4', 'hotel-type=gu...  find_hotel
# 91   ['find_hotel', 'hotel-stars=4', 'hotel-type=gu...  find_hotel
# 127  ['find_hotel', 'hotel-area=north', 'hotel-star...  find_hotel
# 130  ['find_hotel', 'hotel-internet=yes', 'hotel-st...  find_hotel
# 131  ['find_hotel', 'hotel-area=west', 'hotel-stars...  find_hotel
# 151  ['find_hotel', 'hotel-stars=4', 'hotel-type=gu...  find_hotel
# 166                    ['find_hotel', 'hotel-stars=3']  find_hotel
# 178  ['find_hotel', 'hotel-area=dontcare', 'hotel-p...  find_hotel
# 199  ['find_hotel', 'hotel-internet=yes', 'hotel-st...  find_hotel
# 205  ['find_hotel', 'hotel-parking=yes', 'hotel-sta...  find_hotel
# 210                    ['find_hotel', 'hotel-stars=4']  find_hotel
# 282  ['find_hotel', 'hotel-internet=yes', 'hotel-st...  find_hotel
# 363  ['find_hotel', 'hotel-area=east', 'hotel-stars...  find_hotel
# 370  ['find_hotel', 'hotel-pricerange=cheap', 'hote...  find_hotel
#
#                                                  slots  \
# 5          {'hotel-area': 'south', 'hotel-stars': '4'}
# 33          {'hotel-area': 'east', 'hotel-stars': '4'}
# 40         {'hotel-area': 'north', 'hotel-stars': '4'}
# 61    {'hotel-stars': '4', 'hotel-type': 'guesthouse'}
# 62    {'hotel-stars': '4', 'hotel-type': 'guesthouse'}
# 91    {'hotel-stars': '4', 'hotel-type': 'guesthouse'}
# 127        {'hotel-area': 'north', 'hotel-stars': '4'}
# 130      {'hotel-internet': 'yes', 'hotel-stars': '4'}
# 131         {'hotel-area': 'west', 'hotel-stars': '4'}
# 151   {'hotel-stars': '4', 'hotel-type': 'guesthouse'}
# 166                               {'hotel-stars': '3'}
# 178  {'hotel-area': 'dontcare', 'hotel-pricerange':...
# 199      {'hotel-internet': 'yes', 'hotel-stars': '4'}
# 205       {'hotel-parking': 'yes', 'hotel-stars': '4'}
# 210                               {'hotel-stars': '4'}
# 282      {'hotel-internet': 'yes', 'hotel-stars': '4'}
# 363         {'hotel-area': 'east', 'hotel-stars': '4'}
# 370  {'hotel-pricerange': 'cheap', 'hotel-stars': '3'}
#
#                                             text_lower target predicted
# 5         i'm looking for a 4 star hotel in the south.      4         4
# 33   i need to book a hotel in the east that has 4 ...      4         4
# 40   hello. i'm looking for a hotel on the north en...      4         4
# 61   i'm looking for a place to stay. i would like ...      4         4
# 62   i am looking for a place to stay. the hotel sh...      4         4
# 91   hi i am looking for a 4 star guesthouse. can y...      4         4
# 127           i need a 4 star hotel on the north side.      4         4
# 130  i'd like to find a 4 star hotel with free wifi...      4         4
# 131       i'd like a 4 star hotel in the west, please.      4         4
# 151  i am looking for a place to stay. ideally, it ...      4         4
# 166        can you find me a three star place to stay?      3         3
# 178  i'm looking for a 4 star hotel with a moderate...      4         4
# 199  i am looking for a place to stay with a 4 star...      4         4
# 205  can you please help me find a place to stay, s...      4         4
# 210   i need a place to stay that has a 4 star rating.      4         4
# 282  i want to find a four star hotel that has free...      4         4
# 363  hi, i'd like a hotel with a star of 4 on the e...      4         4
# 370  i am looking for a hotel with a three star rat...      3         3
