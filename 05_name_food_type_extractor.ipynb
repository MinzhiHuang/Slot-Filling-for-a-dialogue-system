# %% [markdown]
# ## 05 - Name and food type extractor
# In this notebook, we will find and extract the names (hotel names, restaurant names) and food type (asian/chinese, etc) from the text

# %%
import pandas as pd

# %%
# read train data
train_file = "./data/train.csv"
train_df = pd.read_csv(train_file)

train_df.head()
# Out:
#                                                 text  \
# 0  Guten Tag, I am staying overnight in Cambridge...
# 1  Hi there! Can you give me some info on Cityroomz?
# 2  I am looking for a hotel named alyesbray lodge...
# 3  I am looking for a restaurant. I would like so...
# 4  I'm looking for an expensive restaurant in the...
#
#                                               answer           intent  \
# 0  ['find_hotel', 'hotel-area=centre', 'hotel-int...       find_hotel
# 1             ['find_hotel', 'hotel-name=cityroomz']       find_hotel
# 2  ['find_hotel', 'hotel-name=alyesbray lodge gue...       find_hotel
# 3  ['find_restaurant', 'restaurant-food=chinese',...  find_restaurant
# 4  ['find_restaurant', 'restaurant-area=centre', ...  find_restaurant
#
#                                                slots
# 0  {'hotel-area': 'centre', 'hotel-internet': 'ye...
# 1                        {'hotel-name': 'cityroomz'}
# 2      {'hotel-name': 'alyesbray lodge guest house'}
# 3  {'restaurant-food': 'chinese', 'restaurant-pri...
# 4  {'restaurant-area': 'centre', 'restaurant-pric...

# %%
# pre-processing and covert slots to json objects
train_df["text_lower"] = train_df["text"].str.lower()
# convert slots to json objects
train_df["slots"] = train_df["slots"].apply(lambda s: eval(s))
train_df.head()
# Out:
#                                                 text  \
# 0  Guten Tag, I am staying overnight in Cambridge...
# 1  Hi there! Can you give me some info on Cityroomz?
# 2  I am looking for a hotel named alyesbray lodge...
# 3  I am looking for a restaurant. I would like so...
# 4  I'm looking for an expensive restaurant in the...
#
#                                               answer           intent  \
# 0  ['find_hotel', 'hotel-area=centre', 'hotel-int...       find_hotel
# 1             ['find_hotel', 'hotel-name=cityroomz']       find_hotel
# 2  ['find_hotel', 'hotel-name=alyesbray lodge gue...       find_hotel
# 3  ['find_restaurant', 'restaurant-food=chinese',...  find_restaurant
# 4  ['find_restaurant', 'restaurant-area=centre', ...  find_restaurant
#
#                                                slots  \
# 0  {'hotel-area': 'centre', 'hotel-internet': 'ye...
# 1                        {'hotel-name': 'cityroomz'}
# 2      {'hotel-name': 'alyesbray lodge guest house'}
# 3  {'restaurant-food': 'chinese', 'restaurant-pri...
# 4  {'restaurant-area': 'centre', 'restaurant-pric...
#
#                                           text_lower
# 0  guten tag, i am staying overnight in cambridge...
# 1  hi there! can you give me some info on cityroomz?
# 2  i am looking for a hotel named alyesbray lodge...
# 3  i am looking for a restaurant. i would like so...
# 4  i'm looking for an expensive restaurant in the...

# %%
# filter by names
kw = 'name='
names_df = train_df.query("answer.str.contains(@kw)")
print(len(names_df))
names_df.reset_index(inplace=True)
names_df.drop(columns=["index"], inplace=True)
names_df.head()
# Out:
# 556
# C:\Users\Minh UBC\AppData\Local\Temp\ipykernel_13880\2478432889.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   names_df.drop(columns=["index"], inplace=True)
#                                                 text  \
# 0  Hi there! Can you give me some info on Cityroomz?
# 1  I am looking for a hotel named alyesbray lodge...
# 2  I am looking for a particular restaurant. Its ...
# 3  Hi, what can you tell me about the bangkok cit...
# 4  I'm looking for a particular restaurant called...
#
#                                               answer           intent  \
# 0             ['find_hotel', 'hotel-name=cityroomz']       find_hotel
# 1  ['find_hotel', 'hotel-name=alyesbray lodge gue...       find_hotel
# 2  ['find_restaurant', 'restaurant-name=traveller...  find_restaurant
# 3  ['find_restaurant', 'restaurant-name=bangkok c...  find_restaurant
# 4         ['find_restaurant', 'restaurant-name=ask']  find_restaurant
#
#                                            slots  \
# 0                    {'hotel-name': 'cityroomz'}
# 1  {'hotel-name': 'alyesbray lodge guest house'}
# 2         {'restaurant-name': 'travellers rest'}
# 3            {'restaurant-name': 'bangkok city'}
# 4                     {'restaurant-name': 'ask'}
#
#                                           text_lower
# 0  hi there! can you give me some info on cityroomz?
# 1  i am looking for a hotel named alyesbray lodge...
# 2  i am looking for a particular restaurant. its ...
# 3  hi, what can you tell me about the bangkok cit...
# 4  i'm looking for a particular restaurant called...

# %%
# go through each of the item to analyze
for i in range(len(names_df)):
    item = names_df.iloc[i]
    # print(item)
    # print(type(item))
    print(item["text"])
    print(item["slots"])
    print("--------")
# Out:
# Hi there! Can you give me some info on Cityroomz?
# {'hotel-name': 'cityroomz'}
# --------
# I am looking for a hotel named alyesbray lodge guest house.
# {'hotel-name': 'alyesbray lodge guest house'}
# --------
# I am looking for a particular restaurant. Its name is called travellers rest
# {'restaurant-name': 'travellers rest'}
# --------
# Hi, what can you tell me about the bangkok city restaurant?
# {'restaurant-name': 'bangkok city'}
# --------
# I'm looking for a particular restaurant called ask. Please give me information on that restaurant.
# {'restaurant-name': 'ask'}
# --------
# I would like to find out information about a hotel called Warkworth House.
# {'hotel-name': 'warkworth house'}
# --------
# I don't know if this is possible but can you please get me some information on the alexander bed and breakfast?
# {'hotel-name': 'alexander bed and breakfast'}
# --------
# I'm looking for a hotel called Kirkwood House please.
# {'hotel-name': 'kirkwood house'}
# --------
# I'm looking for a hotel called city centre north b and b
# {'hotel-name': 'city centre north b and b'}
# --------
# I am looking for information about a hotel called the autumn house.
# {'hotel-name': 'autumn house'}
# --------
# I'm looking to get some info about a hotel called Home from Home
# {'hotel-name': 'home from home'}
# --------
# Hi! Can you give me some information on the Royal Spice restaurant?
# {'restaurant-name': 'royal spice'}
# --------
# I am looking for Warkworth House hotel. Any information on it?
# {'hotel-name': 'warkworth house'}
# --------
# Can you give me some information on the Avalon Hotel?
# {'hotel-name': 'avalon'}
# --------
# I am looking for the Limehouse hotel.
# {'hotel-name': 'limehouse'}
# --------
# i am looking for a particular restaurant. Its name is called restaurant two two.
# {'restaurant-name': 'restaurant two two'}
# --------
# Hi, I'm going to be visiting soon, and I am interested in trying a restaruant called Curry Prince. Could you give me more information about it?
# {'restaurant-name': 'curry prince'}
# --------
# Howdy, it would help me a great deal if you could please get me some information about the alexander bed and breakfast
# {'hotel-name': 'alexander bed and breakfast'}
# --------
# I am looking for information on The Varsity restaurant.
# {'restaurant-name': 'the varsity restaurant'}
# --------
# Yes I am looking for information on Michael House cafe.
# {'restaurant-name': 'michaelhouse cafe'}
# --------
# Is there a restaurant called Cocum?
# {'restaurant-name': 'cocum'}
# --------
# I'm looking for a hotel called hamilton lodge.
# {'hotel-name': 'hamilton lodge'}
# --------
# I sure hope so. A friend recommended the Alexander Bed and Breakfast. What can you tell me about it?
# {'hotel-name': 'alexander bed and breakfast'}
# --------
# I'm looking for a hotel called the a and b guest house. Can you help me out?
# {'hotel-name': 'a and b guest house'}
# --------
# I'm looking for this restaurant called city stop restaurant
# {'restaurant-name': 'city stop restaurant'}
# --------
# I am looking for a hotel call arbury lodge guesthouse.
# {'hotel-name': 'arbury lodge guesthouse'}
# --------
# I am looking for the gonville hotel. Can you help me?
# {'hotel-name': 'gonville hotel'}
# --------
# I'm looking for a place called maharajah tandoori restaurant. Do you know it? It's a restaurant.
# {'restaurant-name': 'maharajah tandoori restaurant'}
# --------
# Can you find a restaurant called Rajmahal.
# {'restaurant-name': 'rajmahal'}
# --------
# I am looking for a hotel called The Cambridge Belfry. Can you help me with this?
# {'hotel-name': 'cambridge belfry'}
# --------
# I need to find information on home from home.
# {'hotel-name': 'home from home'}
# --------
# Hello! I'm looking for the hotel called Cityroomz. Can you give me some information, please?
# {'hotel-name': 'cityroomz'}
# --------
# Yes, could you please tell me about the Alpha-Milton guest house?
# {'hotel-name': 'alpha-milton guest house'}
# --------
# I am looking for pasquale pizzeria.
# {'restaurant-name': 'pasquale pizzeria'}
# --------
# I am looking to get some information on the acorn guest house.
# {'hotel-name': 'acorn guest house'}
# --------
# Hi, I'm looking to book the Hamilton Lodge in Cambridge
# {'hotel-name': 'hamilton lodge'}
# --------
# Can you help me find a restaurant called graffiti please?
# {'restaurant-name': 'graffiti'}
# --------
# I need to find out information about a particular hotel called warkworth house
# {'hotel-name': 'warkworth house'}
# --------
# I'm looking for a restaurant called Thanh Binh. Can you help me find it?
# {'restaurant-name': 'thanh binh'}
# --------
# Hello, i'm looking for a restaurant called river bar steakhouse and grill.
# {'restaurant-name': 'river bar steakhouse and grill'}
# --------
# I'd like some information on the Hamilton Lodge hotel, please.
# {'hotel-name': 'hamilton lodge'}
# --------
# I am looking for a restaurant called Charlie Chan
# {'restaurant-name': 'charlie chan'}
# --------
# I am looking for some information on rosas's bed and breakfast.
# {'hotel-name': 'rosas bed and breakfast'}
# --------
# I'm looking for information on a hotel called hamilton lodge.
# {'hotel-name': 'hamilton lodge'}
# --------
# Yes I would like information on the Cambridge Belfry.
# {'hotel-name': 'cambridge belfry'}
# --------
# i need info about cityroomz
# {'hotel-name': 'cityroomz'}
# --------
# Hey, is curry king still open?
# {'restaurant-name': 'curry king'}
# --------
# I am looking for Golden House restaurant.
# {'restaurant-name': 'golden house'}
# --------
# I am looking for Cote restaurant.
# {'restaurant-name': 'cote'}
# --------
# Hi I am looking for some info on the Worth House hotel.
# {'hotel-name': 'worth house'}
# --------
# I am looking for a particular hotel. Its name is called autumn house
# {'hotel-name': 'autumn house'}
# --------
# Please I need a place to Stay in Cambridge and I have the express by holiday inn Cambridge in mind. Can you help book that for me?
# {'hotel-name': 'express by holiday inn cambridge'}
# --------
# Hello, can you recommend a moderately-priced hotel in the North part of town, please?
# {'hotel-area': 'north', 'hotel-name': 'dontcare', 'hotel-pricerange': 'moderate'}
# --------
# I'd like some information about the University Arms Hotel.
# {'hotel-name': 'university arms hotel'}
# --------
# I need some info on a restaurant called royal spice.
# {'restaurant-name': 'royal spice'}
# --------
# Everyone keeps telling me I have to stay at Cityroomz when I visit next. Have you heard of it?
# {'hotel-name': 'cityroomz'}
# --------
# I'd really like to get the number for the Yippee Noodle Bar restaurant if you please?
# {'restaurant-name': 'yippee noodle bar'}
# --------
# I need to find information on the Bloomsbury Restaurant.
# {'restaurant-name': 'bloomsbury restaurant'}
# --------
# I am looking for a restaurant called HK Fusion.
# {'restaurant-name': 'hk fusion'}
# --------
# Hi, I'm looking for a hotel that was recommended. It's called the Cambridge Belfry?
# {'hotel-name': 'cambridge belfry'}
# --------
# Need a certain restaurant called stazione restaurant and coffee bar.
# {'restaurant-name': 'stazione restaurant and coffee bar'}
# --------
# i need information of a hotel called allenbell.
# {'hotel-name': 'allenbell'}
# --------
# I need a restaurant. I've heard Nandos recommended, could you give me more information about it?
# {'restaurant-name': 'nandos'}
# --------
# Hi, I'd like to find out about the Hobsons House hotel.
# {'hotel-name': 'hobsons house'}
# --------
# I am looking for the price range and address of the Meze Bar Restaurant
# {'restaurant-name': 'meze bar'}
# --------
# I'm looking for a hotel called a and b quest house.
# {'hotel-name': 'a and b quest house'}
# --------
# I am looking for a place to stay that is named aylesbray lodge guest house. Could you give me some information about it?
# {'hotel-name': 'aylesbray lodge guest house', 'hotel-type': 'guesthouse'}
# --------
# Can you help me find the a and b guest house hotel?
# {'hotel-name': 'a and b guest house'}
# --------
# Could you provide me with information about the Huntingdon Marriott hotel?
# {'hotel-name': 'huntingdon marriott hotel'}
# --------
# I want to book the el shaddai hotel.
# {'hotel-name': 'el shaddai'}
# --------
# Do you have any information on a restaurant called the Golden Wok?
# {'restaurant-name': 'golden wok'}
# --------
# Hello! What can you tell me about the Shiraz restaurant?
# {'restaurant-name': 'shiraz'}
# --------
# I'm looking for information on la tasca.
# {'restaurant-name': 'la tasca'}
# --------
# I'm looking for a restaurant called the gandhi.
# {'restaurant-name': 'the gandhi'}
# --------
# Could you give me some information on a hotel named el shaddai?
# {'hotel-name': 'el shaddai'}
# --------
# I'm looking for a restaurant called restaurant two two?
# {'restaurant-name': 'restaurant two two'}
# --------
# i am looking for a particular hotel. Its name is called aylesbray lodge guest house.
# {'hotel-name': 'aylesbray lodge guest house'}
# --------
# I'm looking for a hotel named Worth House
# {'hotel-name': 'worth house'}
# --------
# I am looking for information on a restaurant called saigon city?
# {'restaurant-name': 'saigon city'}
# --------
# Hello, can you give me information about Express by Holiday Inn Cambridge, please?
# {'hotel-name': 'express by holiday inn cambridge'}
# --------
# Does Cambridge have an establishment called the Shanghai Family Restaurant?
# {'restaurant-name': 'shanghai family restaurant'}
# --------
# I'm looking for a particular restaurant called the cow pizza kitchen and bar. What do you know about it?
# {'restaurant-name': 'cow pizza kitchen and bar'}
# --------
# Hi, I'm looking for the Bridge Guest House. Can you give the information about it please?
# {'hotel-name': 'bridge guest house'}
# --------
# I am looking for a restaurant, it's called anatolia
# {'restaurant-name': 'anatolia'}
# --------
# Can you tell me more about gourmet burger kitchen? Where is it?
# {'restaurant-name': 'gourmet burger kitchen'}
# --------
# Are there any available rooms in the Autumn House?
# {'hotel-name': 'autumn house'}
# --------
# I'm trying to find a restaurant called The Slug and Lettuce. Do you know where that is?
# {'restaurant-name': 'the slug and lettuce'}
# --------
# I am looking for a restaurant called Galleria.
# {'restaurant-name': 'galleria'}
# --------
# Can you help me find information about a hotel called huntingdon marriott hotel?
# {'hotel-name': 'huntingdon marriott hotel'}
# --------
# What can you tell me about the El Shaddai?
# {'hotel-name': 'el shaddai'}
# --------
# I am looking for a hotel by the name of home from home.
# {'hotel-name': 'home from home'}
# --------
# Can you help me find a place to stay that has free parking? It doesn't need to include internet.
# {'hotel-area': 'dontcare', 'hotel-internet': 'dontcare', 'hotel-name': 'dontcare', 'hotel-parking': 'yes', 'hotel-type': 'dontcare'}
# --------
# Could you help me locate the Alpha Milton Guest House?
# {'hotel-name': 'alpha milton guest house'}
# --------
# I would like to know more about Rosa's b&b
# {'hotel-name': 'rosas bed and breakfast'}
# --------
# Do you have information about the Lovell Lodge?
# {'hotel-name': 'lovell lodge'}
# --------
# I want to find information on a restaurant called Wagamama.
# {'restaurant-name': 'wagamama'}
# --------
# Can you tell me about a particular hotel called the avalon?
# {'hotel-name': 'avalon'}
# --------
# What can you tell me about the bangkok city restaurant?
# {'restaurant-area': 'centre', 'restaurant-name': 'bangkok city'}
# --------
# I'm looking for a place called gonville hotel.
# {'hotel-name': 'gonville hotel'}
# --------
# I would like some information of the restaurant called Royal Standard.
# {'restaurant-name': 'royal standard'}
# --------
# Can you give me some information on the Bloomsbury Restaurant?
# {'restaurant-name': 'bloomsbury restaurant'}
# --------
# I'm looking for a hotel called acorn guest house
# {'hotel-name': 'acorn guest house'}
# --------
# Hi! I'm looking for information on the Rice House restaurant.
# {'restaurant-name': 'rice house'}
# --------
# I need to find a restaurant in anatolia
# {'restaurant-name': 'anatolia'}
# --------
# I am looking for a particular restaurant. It is called pizza hut city centre.
# {'restaurant-name': 'pizza hut city centre'}
# --------
# I would like to know more about a restaurant called the panahar if you could help?
# {'restaurant-name': 'panahar'}
# --------
# Can you get me information on a restaurant called golden house?
# {'restaurant-name': 'golden house'}
# --------
# I would like info about the Cityroomz hotel please
# {'hotel-name': 'cityroomz'}
# --------
# Hi, I'm looking for a hotel, the archway house?
# {'hotel-name': 'archway house'}
# --------
# Hi, I'd like information for the restaurant called Travellers Rest please.
# {'restaurant-name': 'travellers rest'}
# --------
# Hello, I'm looking for a restaurant by the name of Cote. Can you find this for me and book a reservation please?
# {'restaurant-name': 'cote'}
# --------
# Hello! My friends told me about a hotel called Alexander Bed and Breakfast. Can you get me some information about it, please?
# {'hotel-name': 'alexander bed and breakfast'}
# --------
# I would like to find a restaurant called Pipasha.
# {'restaurant-name': 'pipasha restaurant'}
# --------
# I am looking for a hotel by the name of The Lensfield Hotel.
# {'hotel-name': 'lensfield hotel'}
# --------
# I am interested in finding the Lensfield Hotel.
# {'hotel-name': 'lensfield hotel'}
# --------
# I need some information on a place to eat call the nirala.
# {'restaurant-name': 'nirala'}
# --------
# I'm looking for this hotel called home from home, please.
# {'hotel-name': 'home from home'}
# --------
# I need to get to a restaurant known as the Lucky star
# {'restaurant-name': 'the lucky star'}
# --------
# Hi, I'm trying to find a place to stay called the cambridge belfry. What can you tell me about that?
# {'hotel-name': 'cambridge belfry'}
# --------
# Is the alpha-milton guest house still in operation?
# {'hotel-name': 'alpha-milton guest house'}
# --------
# Hello, have you heard of the Royal Spice Restaurant by chance?
# {'restaurant-name': 'royal spice'}
# --------
# I am looking for directions to Jinling Noodle Bar, can you help me?
# {'restaurant-name': 'jinling noodle bar'}
# --------
# I am visiting Cambridge and would like to stay at Allenbell can you help give me some information on it?
# {'hotel-name': 'allenbell'}
# --------
# Hi, I'm looking for information on the Autumn House. It's a hotel.
# {'hotel-name': 'autumn house'}
# --------
# Hey, when I was a kid my parents took me to a place called the cow pizza kitchen and bar. Is it still around?
# {'restaurant-name': 'cow pizza kitchen and bar'}
# --------
# I am looking for a restaurant named Hakka. Can you tell me how to get there?
# {'restaurant-name': 'hakka'}
# --------
# I am looking for a particular hotel. Its name is called arbury lodge guesthouse
# {'hotel-name': 'arbury lodge guesthouse'}
# --------
# I am looking for a particular restaurant. Its name is called city stop restaurant
# {'restaurant-name': 'city stop restaurant'}
# --------
# I'm looking for yu garden, can you help me find it?
# {'restaurant-name': 'yu garden'}
# --------
# What can you dig up about the pizza express Fen Ditton?
# {'restaurant-name': 'pizza express fen ditton'}
# --------
# I'd like to find the Lensfield Hotel.
# {'hotel-name': 'lensfield hotel'}
# --------
# I am trying to find the Acorn Guest House.
# {'hotel-name': 'acorn guest house'}
# --------
# I'm looking for a particular hotel called "rosa's bed and breakfast".
# {'hotel-name': 'rosas bed and breakfast'}
# --------
# I am looking for information for Warkworth House.
# {'hotel-name': 'warkworth house'}
# --------
# Hello are you familiar with Rosa's bed and breakfast? I've been looking for this hotel for forever!
# {'hotel-name': 'rosas bed and breakfast'}
# --------
# I'm looking for info on a restaurant called La Tasca.
# {'restaurant-name': 'la tasca'}
# --------
# I need information on a hotel named,"rosa's bed and breakfast".
# {'hotel-name': 'rosas bed and breakfast'}
# --------
# Hi, Have you heard of the J Restaurant? I'd like some information about it.
# {'restaurant-name': 'j restaurant'}
# --------
# I'm trying to find a hotel called Worth House. Can you help me?
# {'hotel-name': 'worth house'}
# --------
# What can you tell me about the hotel el shaddai?
# {'hotel-name': 'el shaddai'}
# --------
# Hi, I'm looking for a particular restaurant named Bedouin. Can you help?
# {'restaurant-name': 'bedouin'}
# --------
# I'm looking for a place, I think it's called the Arbury Guesthouse and Lodge. Can you help me?
# {'hotel-name': 'arbury guesthouse and lodge'}
# --------
# Hi, what can you tell me about a restaurant called hakka?
# {'restaurant-name': 'hakka'}
# --------
# I'd like to find out more about the bloomsbury restaurant
# {'restaurant-name': 'bloomsbury restaurant'}
# --------
# Hi! Can you give me some information on the Bangkok City restaurant?
# {'restaurant-name': 'bangkok city'}
# --------
# Have you ever heard of a hotel called the Ashley Hotel?
# {'hotel-name': 'ashley hotel'}
# --------
# Yes, can you lookup the chiquito restaurant bar for me.
# {'restaurant-name': 'chiquito restaurant bar'}
# --------
# Hello I am looking for a restaurant called J restaurant
# {'restaurant-name': 'j restaurant'}
# --------
# Can you help me find a place to eat called sala thong?
# {'restaurant-name': 'sala thong'}
# --------
# I am looking for a particular hotel. Its name is called city centre north b and b
# {'hotel-name': 'city centre north b and b'}
# --------
# Hi, is there a restaurant in town called the rice boat?
# {'restaurant-name': 'rice boat'}
# --------
# I'm just looking for a hotel called Leverton House.
# {'hotel-name': 'leverton house'}
# --------
# I'm looking for the university arms hotel. Can you give me more information about it?
# {'hotel-name': 'university arms hotel'}
# --------
# I want to make a booking at the alexander bed and breakfast.
# {'hotel-name': 'alexander bed and breakfast'}
# --------
# Can I get some information on the arbury lodge guesthouse?
# {'hotel-name': 'arbury lodge guesthouse'}
# --------
# Can you find the restaurant names Loch Fyne?
# {'restaurant-name': 'loch fyne'}
# --------
# Can you give me information on a restaurant called graffiti?
# {'restaurant-name': 'graffiti'}
# --------
# I would like to stay at Rosa's bed and breakfast in cambridge. can you give tell me their contact information and location?
# {'hotel-name': 'rosas bed and breakfast'}
# --------
# I need some information on a place called Pizza express.
# {'restaurant-name': 'pizza express'}
# --------
# Hello. I'm trying to find a restaurant called Graffiti. Can you help me locate it?
# {'restaurant-name': 'graffiti'}
# --------
# Hi, I'm really looking forward to coming to Cambridge. You have an Express by Holiday Inn, right?
# {'hotel-name': 'express by holiday inn'}
# --------
# I would like information on the Gonville hotel.
# {'hotel-name': 'gonville hotel'}
# --------
# What is the address for find pizza hut city centre?
# {'restaurant-name': 'pizza hut city centre'}
# --------
# I'm looking for pizza hut fen ditton.
# {'restaurant-name': 'pizza hut fenditton'}
# --------
# Do you know where I can find the Peking Restaurant?
# {'restaurant-name': 'peking restaurant'}
# --------
# Do you have any information on a hotel called the Acorn Guesthouse?
# {'hotel-name': 'acorn guest house'}
# --------
# I'm looking for a restaurant called Meghna.
# {'restaurant-name': 'meghna'}
# --------
# Can you tell me more about the peking restaurant? Thank you.
# {'restaurant-name': 'peking restaurant'}
# --------
# Can you tell me where the restaurant Tandoori Palace is located?
# {'restaurant-name': 'tandoori palace'}
# --------
# Yes, I am looking for information for the Kirkwood House. Can you help me?
# {'hotel-name': 'kirkwood house'}
# --------
# Can you help me find a hotel called Limehouse? Thanks.
# {'hotel-name': 'limehouse'}
# --------
# I'm looking for a restaurant named hakka
# {'restaurant-name': 'hakka'}
# --------
# I'm looking for a particular restaurant called j restaurant.
# {'restaurant-name': 'j restaurant'}
# --------
# Greetings! I'm looking for the Worth House, I heard it's in Cambridge.
# {'hotel-name': 'worth house'}
# --------
# There's a place I've heard of that I'm looking for more details. Warkworth House. Do you know of it?
# {'hotel-name': 'warkworth house'}
# --------
# Can you help me find a restaurant i am looking for? Its name is the Rice Boat.
# {'restaurant-name': 'rice boat'}
# --------
# Hi, could you help me find out more information about Panahar restaurant in your area?
# {'restaurant-name': 'panahar'}
# --------
# Yes I am looking for information on a hotel called City Center North B and B.
# {'hotel-name': 'city centre north b and b'}
# --------
# I am looking for a hotel called the alpha-milton guest house.
# {'hotel-name': 'alpha-milton guest house'}
# --------
# Where is Finches Bed and Breakfast located?
# {'hotel-name': 'finches bed and breakfast'}
# --------
# I'm hoping to find Rosa's Bed and Breakfast.
# {'hotel-name': 'rosas bed and breakfast'}
# --------
# I need information on a restaurant called saffron brasserie please.
# {'restaurant-name': 'saffron brasserie'}
# --------
# I would like to book at room at alexander bed and breakfast
# {'hotel-name': 'alexander bed and breakfast'}
# --------
# Is the travellers rest restaurant still open?
# {'restaurant-name': 'travellers rest'}
# --------
# I want to book the Archway House in Cambridge.
# {'hotel-name': 'archway house'}
# --------
# I am looking for a restaurant called curry garden.
# {'restaurant-name': 'curry garden'}
# --------
# I am looking for a particular restaurant. Its name is called cafe uno.
# {'restaurant-name': 'cafe uno'}
# --------
# I am looking for ALexeander b&b.
# {'hotel-name': 'alexeander b&b'}
# --------
# Hi, I am looking for a restaurant called nandos city centre.
# {'restaurant-name': 'nandos city centre'}
# --------
# I want some information on the university arms hotel please
# {'hotel-name': 'university arms hotel', 'hotel-parking': 'yes', 'hotel-stars': '4'}
# --------
# I'm looking for a hotel called warkworth house
# {'hotel-name': 'warkworth house'}
# --------
# I am looking for information on the Warkworth House.
# {'hotel-name': 'warkworth house'}
# --------
# I was told about a great place to eat called the copper kettle.
# {'restaurant-name': 'copper kettle'}
# --------
# I'm looking for a restaurant called Loch Fyne. Can you tell me a bit about it?
# {'restaurant-name': 'loch fyne'}
# --------
# I am looking for a restaurant called Cocum.
# {'restaurant-name': 'cocum'}
# --------
# I'm looking for some information on a restaurant called the varsity restaurant.
# {'restaurant-name': 'the varsity restaurant'}
# --------
# Can you tell me some info on the Avalon hotel?
# {'hotel-name': 'avalon'}
# --------
# I am looking for information on the hamilton lodge hotel.
# {'hotel-name': 'hamilton lodge'}
# --------
# I am looking for the address and phone number for the Backstreet Bistro please.
# {'restaurant-name': 'backstreet bistro'}
# --------
# I need to get some information on a restaurant named eraina
# {'restaurant-name': 'eraina'}
# --------
# Can you tell me about the Carolina B&B?
# {'hotel-name': 'carolina b&b'}
# --------
# I need information to find the huntingdon marriott hotel.
# {'hotel-name': 'huntingdon marriott hotel'}
# --------
# I'd like some information on a restaurant called Kymmoy, please.
# {'restaurant-name': 'kymmoy'}
# --------
# i'm looking for university arms hotel
# {'hotel-name': 'university arms hotel'}
# --------
# I'm looking for some info on a hotel called the cambrdige belfry.
# {'hotel-name': 'cambridge belfry'}
# --------
# Hi! I am attempting to find a restaurant in Cambridge called Traveller's Rest. Do you know of it?
# {'restaurant-name': 'travellers rest'}
# --------
# Yes can you tell me something about the Cow Pizza Kitchen and Bar?
# {'restaurant-name': 'the cow pizza kitchen and bar'}
# --------
# Hi I am looking to get some info on the aylesbray lodge guest house
# {'hotel-name': 'aylesbray lodge guest house'}
# --------
# I am looking for a hotel called Warkworth House.
# {'hotel-name': 'warkworth house'}
# --------
# Hi, can you help me locate a hotel named City Centre B and B. Really looking forward to trying different restaurants.
# {'hotel-name': 'city centre north b and b'}
# --------
# Can you give me some information on the Alpha Milton guesthouse?
# {'hotel-area': 'north', 'hotel-name': 'alpha-milton guest house'}
# --------
# Where can I find the galleria restaurant?
# {'restaurant-name': 'galleria'}
# --------
# Have you ever heard of the hotel Avalon?
# {'hotel-name': 'avalon'}
# --------
# I am looking for a restaurant called the Slug and Lettuce.
# {'restaurant-name': 'slug and lettuce'}
# --------
# Hi, I am planning a trip. Have you heard of a particular hotel? I think it is called the Carolina Bed and Breakfast.
# {'hotel-name': 'carolina bed and breakfast'}
# --------
# Can you help me with some information on a restaurant called luca cucina and bar?
# {'restaurant-name': 'luca cucina and bar'}
# --------
# I have heard a lot of good things about the Arbury Lodge Guesthouse. Would you be able to provide any information on them?
# {'hotel-name': 'arbury lodge guesthouse', 'hotel-type': 'guesthouse'}
# --------
# I'm looking for information on the Autumn House. Can you help me out?
# {'hotel-name': 'autumn house'}
# --------
# I'm looking for a cheap restaurant that serves modern european food.
# {'restaurant-food': 'modern european', 'restaurant-name': 'dontcare', 'restaurant-pricerange': 'cheap'}
# --------
# Hello, I am looking for a certain hotel in Cambridge called the autumn house.
# {'hotel-name': 'autumn house'}
# --------
# Hello, I am going to be visiting Cambridge and am looking for a particular hotel called the Warkworth House.
# {'hotel-name': 'warkworth house'}
# --------
# I'm looking for the information on a restaurant named Rajmahal, could you provide me their info?
# {'restaurant-name': 'rajmahal'}
# --------
# I am looking for a hotel called a and b guest house.
# {'hotel-name': 'a and b guest house'}
# --------
# Where is the restaurant called Tandoori Palace?
# {'restaurant-name': 'tandoori palace'}
# --------
# I need to make a reservation at a hotel called El Shaddai
# {'hotel-name': 'el shaddai'}
# --------
# My friend recommended Little Seoul, but I need some help locating it.
# {'restaurant-name': 'little seoul'}
# --------
# I need to find the Autumn House Hotel.
# {'hotel-name': 'autumn house'}
# --------
# I want to find out more about the arbury guesthouse.
# {'hotel-name': 'arbury lodge guesthouse'}
# --------
# Hi. Have you heard of Pizza Hut City Centre by chance? I may want to eat there soon.
# {'restaurant-name': 'pizza hut city centre'}
# --------
# I am looking for information about the City Centre North B and B hotel. Can you help me with that?
# {'hotel-name': 'city centre north b and b'}
# --------
# I'm looking to get some info on a hotel called cityroomz.
# {'hotel-name': 'cityroomz'}
# --------
# Can you help me find a restaurant in Cambridge called Loch Fyne?
# {'restaurant-name': 'loch fyne'}
# --------
# I am looking for information on the Yippee Noodle bar.
# {'restaurant-name': 'yippee noodle bar'}
# --------
# Yes, I'm looking for the hotel Limehouse.
# {'hotel-name': 'limehouse'}
# --------
# I am looking for a restaurant called J Restaurant.
# {'restaurant-name': 'j restaurant'}
# --------
# Hi, I'm trying to find a restaurant called HK Fusion. What info can you get me for that?
# {'restaurant-name': 'hk fusion'}
# --------
# What type of food does the Oak Bistro in Cambridge serve?
# {'restaurant-name': 'the oak bistro'}
# --------
# I am interested in staying at the A and B Guest House, could you help me book my stay?
# {'hotel-name': 'a and b guest house'}
# --------
# looking for arbury lodge guesthouse
# {'hotel-name': 'arbury lodge guesthouse'}
# --------
# Howdy! Is the City Centre North B And B still in business?
# {'hotel-area': 'centre', 'hotel-name': 'city centre north b and b'}
# --------
# I am looking for a restaurant called lan hong house. Can you get me more information about it please?
# {'restaurant-name': 'lan hong house'}
# --------
# Hello I'm looking for the shanghai family restaurant.
# {'restaurant-name': 'shanghai family restaurant'}
# --------
# I am looking for a particular restaurant. Its name is called royal standard
# {'restaurant-name': 'royal standard'}
# --------
# I'm trying to find the Alexander Bed and Breakfast.
# {'hotel-name': 'alexander bed and breakfast'}
# --------
# I'd like to find information for the restaurant called The Missing Sock.
# {'restaurant-name': 'the missing sock'}
# --------
# Can you help me find information on a hotel called allenbell?
# {'hotel-name': 'allenbell'}
# --------
# Hi, could you help me find a restaurant called ask.
# {'restaurant-name': 'ask'}
# --------
# I am looking for a restaurant sitar tandoori. Can you give me more information?
# {'restaurant-name': 'sitar tandoori'}
# --------
# Hello, I am looking for a restaurant name taj tandoori.
# {'restaurant-name': 'taj tandoori'}
# --------
# I am looking for information on a restaurant, the name of the place is ask. Can you tell me about it?
# {'restaurant-name': 'ask'}
# --------
# Yes, I need some help and information pertaining to a particular restaurant. The name of the restaurant is Sitar Tandoori. I'd like some information on the place if you can help.
# {'restaurant-name': 'sitar tandoori'}
# --------
# I'm looking for information on a hotel, the carolina bed and breakfast.
# {'hotel-name': 'carolina bed and breakfast'}
# --------
# I'm looking for a restaurant called The Nirala. Can you tell me where it is?
# {'restaurant-name': 'nirala'}
# --------
# Can you let me know if a place called the Gonville hotel is still around?
# {'hotel-name': 'gonville hotel'}
# --------
# I'm looking for a restaurant called graffiti.
# {'restaurant-name': 'graffiti'}
# --------
# I would like to find some info on the warkworth house hotel.
# {'hotel-name': 'warkworth house'}
# --------
# I heard cityroomz is a good hotel. Can you give me some information on this hotel?
# {'hotel-name': 'cityroomz'}
# --------
# I'll be in there next week and my friend told me about a restaurant called The Missing Sock. Could you tell me where they are located?
# {'restaurant-name': 'the missing sock'}
# --------
# I'm looking for a hotel called home from home.
# {'hotel-name': 'home from home'}
# --------
# I need to find a certain restaurant called the slug and lettuce.
# {'restaurant-name': 'the slug and lettuce'}
# --------
# I'm looking for a particular restaurant called the Pizza Express
# {'restaurant-name': 'pizza express'}
# --------
# I'd like some information about the El Shaddai.
# {'hotel-name': 'el shaddai'}
# --------
# Can you help me find a hotel called limehouse and tell me a little about it?
# {'hotel-name': 'limehouse'}
# --------
# I'd like some information about the El Shaddai.
# {'hotel-name': 'el shaddai'}
# --------
# Hi, I am looking for information on a restaurant it's called saffron brasserie.
# {'restaurant-name': 'saffron brasserie'}
# --------
# Hi, I'm looking for the location of the Carolina Bed and Breakfast please?
# {'hotel-name': 'carolina bed and breakfast'}
# --------
# I am looking for a restaurant called Panahar.
# {'restaurant-name': 'panahar'}
# --------
# I am looking for a hotel called alpha-milton guest house
# {'hotel-name': 'alpha-milton guest house'}
# --------
# Yes, I am trying to find a hotel by the name of allenbell. Can you help me?
# {'hotel-name': 'allenbell'}
# --------
# Hi! What can you tell me about the Lensfield Hotel?
# {'hotel-name': 'lensfield hotel'}
# --------
# I need information on the hotel Limehouse please.
# {'hotel-name': 'limehouse'}
# --------
# I am looking for a place for a restaurant called anatolia. Can you help me?
# {'restaurant-name': 'anatolia'}
# --------
# Yes, I'd like some help looking for a particular restaurant. The name of the restaurant is Darrys Cookhouse and Wine Shop. I'd like to know where it's located and how expensive.
# {'restaurant-name': 'darrys cookhouse and wine shop'}
# --------
# I'm interested in a place called restaurant one seven. What can you tell me about it?
# {'restaurant-name': 'restaurant one seven'}
# --------
# I'm looking for a restaurant named Panahar.
# {'restaurant-name': 'panahar'}
# --------
# I am looking for a certain hotel. I think that it is called something like Allenball
# {'hotel-name': 'allenbell'}
# --------
# I'm looking for information on a restaurant called mahal of cambridge.
# {'restaurant-name': 'mahal of cambridge'}
# --------
# I am interested in the Express by Holiday Inn - Cambridge.
# {'hotel-name': 'express by holiday inn - cambridge'}
# --------
# Can I have the contact information for the Fitzbillies Restaurant.
# {'restaurant-name': 'fitzbillies restaurant'}
# --------
# I'm looking for a hotel called city centre north b and b
# {'hotel-name': 'city centre north b and b'}
# --------
# I am looking for a hotel by the name of home from home.
# {'hotel-name': 'home from home'}
# --------
# I am looking for a particular hotel. Its name is called cityroomz
# {'hotel-name': 'cityroomz'}
# --------
# I'm looking for a hotel named Express by Holiday Inn Cambridge. Do you have any information on that?
# {'hotel-name': 'express by holiday inn cambridge'}
# --------
# Can you get me information on a hotel called city centre north b and b?
# {'hotel-name': 'city centre north b and b'}
# --------
# I am looking for a place called tang chinese
# {'restaurant-name': 'tang chinese'}
# --------
# I need to know more about the Alexander bed and breakfast.
# {'hotel-name': 'alexander bed and breakfast'}
# --------
# I am looking for Home from Home hotel
# {'hotel-name': 'home from home'}
# --------
# Howdy, I was wondering if the alpha-milton guest house still does business?
# {'hotel-name': 'alpha-milton guest house', 'hotel-type': 'guesthouse'}
# --------
# Please send me general information about a particular hotel called the lensfield hotel.
# {'hotel-name': 'lensfield hotel'}
# --------
# I am looking for a hotel called Aylesbray Lodge Guest House.
# {'hotel-name': 'aylesbray lodge guest house'}
# --------
# Could you give me information on a hotel called alpha-milton guest house?
# {'hotel-name': 'alpha-milton guest house'}
# --------
# I'd like to find some information about the Allenbell hotel.
# {'hotel-name': 'allenbell'}
# --------
# Hello! I am looking for information about a hotel called aylesbray lodge guest house. Can you help me?
# {'hotel-name': 'aylesbray lodge guest house'}
# --------
# I am looking for info about a hotel called city centre north b and b. Can you help?
# {'hotel-name': 'city centre north b and b'}
# --------
# I'm looking for the Lensfield Hotel. Can you help me find it?
# {'hotel-name': 'lensfield hotel'}
# --------
# I am looking for the restaurant kymmoy.
# {'restaurant-name': 'kymmoy'}
# --------
# I am looking for some info on rice house restaurant.
# {'restaurant-name': 'rice house'}
# --------
# Hello, I am looking for a restaurant by the name of Royal Standard. Do you know where it is?
# {'restaurant-name': 'royal standard'}
# --------
# Can you tell me if warkworth house hotel has wifi.
# {'hotel-internet': 'yes', 'hotel-name': 'warkworth house'}
# --------
# Hi, I am looking for a restaurant called Yu garden.
# {'restaurant-name': 'yu garden'}
# --------
# I am looking for a certain hotel. I think it is called Rosa's Bed and Breakfast
# {'hotel-name': 'rosas bed and breakfast'}
# --------
# I am looking for information on the kirkwood house.
# {'hotel-name': 'kirkwood house'}
# --------
# I am looking for information about city stop restaurant?
# {'restaurant-name': 'city stop restaurant'}
# --------
# I'm looking for a restaurant called Thanh Binh.
# {'restaurant-name': 'thanh binh'}
# --------
# I am looking for the price range of a restaurant called Rice boat.
# {'restaurant-name': 'rice boat'}
# --------
# Hello, I'm planning my trip to cambridge, and I'm trying to find a hotel called alpha-milton guest house. Can you help?
# {'hotel-name': 'alpha-milton guest house'}
# --------
# Howdy! Is the Hamilton Lodge still open?
# {'hotel-name': 'hamilton lodge'}
# --------
# Hello, are you familiar with Warkworth House?
# {'hotel-name': 'warkworth house'}
# --------
# Can you give me the price for a large pizza and what type of pizzas they offer at Pizza Express fen ditton please
# {'restaurant-name': 'pizza express fen ditton'}
# --------
# Hi there. I'm looking for a particular hotel called the A and B Guest House.
# {'hotel-name': 'a and b guest house'}
# --------
# I would like to book a room at the Worth House.
# {'hotel-name': 'worth house'}
# --------
# Hi, could you give me the location of the Saint Johns Chop House?
# {'restaurant-name': 'saint johns chop house'}
# --------
# Hi, are you familiar with the Avalon hotel?
# {'hotel-name': 'avalon'}
# --------
# I'm looking for a restaurant called Mahal of Cambridge.
# {'restaurant-name': 'mahal of cambridge'}
# --------
# I want to find a place to eat called saigon city.
# {'restaurant-name': 'saigon city'}
# --------
# I am looking for information on a restaurant called cafe uno
# {'restaurant-name': 'cafe uno'}
# --------
# I'm looking for information on the cambridge belfry hotel.
# {'hotel-name': 'cambridge belfry'}
# --------
# I am looking for yippee noodle bar.
# {'restaurant-name': 'yippee noodle bar'}
# --------
# I am looking for a restaurant called the Gandhi.
# {'restaurant-name': 'the gandhi'}
# --------
# I need some tourist information please. I need to know about a hotel called the arbury lodge guest house.
# {'hotel-name': 'arbury lodge'}
# --------
# I am looking for information on a place called Bridge Guest House. Can you help me?
# {'hotel-name': 'bridge guest house'}
# --------
# i am looking for a place to dine. the restaurant should be in the cheap price range and should serve swedish food.
# {'restaurant-area': 'dontcare', 'restaurant-food': 'swedish', 'restaurant-name': 'dontcare', 'restaurant-pricerange': 'dontcare'}
# --------
# Hello, I would like some information on a hotel called The Bridge guest house, please.
# {'hotel-name': 'bridge guest house'}
# --------
# Please tell me where the restaurant HK Fusion is located. Thanks.
# {'restaurant-name': 'hk fusion'}
# --------
# Hello, I am looking for a hotel called the worth house. Can you help me find it?
# {'hotel-name': 'worth house'}
# --------
# I hope so. My brother recommended an eatery called Curry Prince. Can you help me find it?
# {'restaurant-name': 'curry prince'}
# --------
# Hi, I'm looking to book a room in the ashley hotel.
# {'hotel-name': 'ashley hotel'}
# --------
# I am looking for the university arms hotel please.
# {'hotel-name': 'university arms hotel'}
# --------
# Hi, do you have a listing for the copper kettle? It's a restaurant.
# {'restaurant-name': 'copper kettle'}
# --------
# I need some info on the acorn guest house.
# {'hotel-name': 'acorn guest house'}
# --------
# Can you help me find a restaurant by the name of Loch Fyne?
# {'restaurant-name': 'loch fyne'}
# --------
# I am going to visit and was told about the a and b guest house. Could you help me with that?
# {'hotel-name': 'a and b guest house'}
# --------
# i am looking for the gonville hotel
# {'hotel-name': 'gonville hotel'}
# --------
# Can you help me find a hotel called El Shaddai? Thanks.
# {'hotel-name': 'el shaddai'}
# --------
# Can you get me information on a hotel called a and b guest house?
# {'hotel-name': 'a and b guest house'}
# --------
# I need to find a particular hotel called cityroomz. Please send me all information you have.
# {'hotel-name': 'cityroomz'}
# --------
# Hello, I am looking for the address and phone number of the hotel Cambridge Belfry.
# {'hotel-name': 'cambridge belfry'}
# --------
# I'm wondering if you have information about a particular restaurant called the curry queen?
# {'restaurant-name': 'curry queen'}
# --------
# i'm looking for a hotel called alexander bed and breakfast
# {'hotel-name': 'alexander bed and breakfast'}
# --------
# Please help me find a restaurant called Frankie and Bennys. Thanks.
# {'restaurant-name': 'frankie and bennys'}
# --------
# I would like to find out information about a hotel called Warkworth House.
# {'hotel-name': 'warkworth house'}
# --------
# I'm looking for a hotel called Worth House.
# {'hotel-name': 'worth house'}
# --------
# Hello, I'm looking for information on a hotel called Hobsons House.
# {'hotel-name': 'hobsons house'}
# --------
# I am looking for a hotel called the leverton house.
# {'hotel-name': 'leverton house'}
# --------
# Hello. I've been recommended a restaurant called The Missing Sock. Can you direct me to where it is located?
# {'restaurant-name': 'the missing sock'}
# --------
# I need to know more about a hotel called home from home.
# {'hotel-name': 'home from home'}
# --------
# Can you tell me if there is a restaurant named Kohinoor in Cambridge?
# {'restaurant-name': 'kohinoor'}
# --------
# I'm looking for this particular hotel called carolina bed and breakfast
# {'hotel-name': 'carolina bed and breakfast'}
# --------
# I am looking for kirkwood house.
# {'hotel-name': 'kirkwood house'}
# --------
# I'm looking for a particular restaurant. Its name is called city stop restaurant.
# {'restaurant-name': 'city stop restaurant'}
# --------
# I am looking for a hotel called Avalon, can you help?
# {'hotel-name': 'avalon'}
# --------
# I am looking for the chiquito restaurant bar can you help me find it?
# {'restaurant-name': 'chiquito restaurant bar'}
# --------
# I'm looking for cafe uno, can you help me find where it is?
# {'restaurant-name': 'cafe uno'}
# --------
# I am looking for a particular restaurant. Its name is called prezzo
# {'restaurant-name': 'prezzo'}
# --------
# Where can I find the Express by Holiday Inn in Cambridge?
# {'hotel-name': 'express by holiday inn in cambridge'}
# --------
# I'm looking to find out some information about a restaurant called Travellers Rest.
# {'restaurant-name': 'travellers rest'}
# --------
# Hi! My friends told me about a restaurant called the nirala. What can you tell me about it?
# {'restaurant-name': 'nirala'}
# --------
# Hi, I'm looking for a hotel by the name of Acorn Guest House.
# {'hotel-name': 'acorn guest house'}
# --------
# I'm looking for info about the curry king restaurant.
# {'restaurant-name': 'curry king'}
# --------
# I'm looking for a particular hotel called the kirkwood house. Where is it, and what other information do you have about it?
# {'hotel-name': 'kirkwood house'}
# --------
# I need to find a restaurant call the nirala.
# {'restaurant-name': 'nirala'}
# --------
# What can you tell me about the Lovell Lodge?
# {'hotel-name': 'lovell lodge'}
# --------
# I want to try a local restaurant called Jinling noodle bar, can you help?
# {'restaurant-name': 'jinling noodle bar'}
# --------
# Hello, I am wondering if you can help me with some information on a hotel called city centre north b and b?
# {'hotel-name': 'city centre north b and b'}
# --------
# Hello, I'm looking for some information about a particular restaurant. The name of it is Dojo Noodle Bar.
# {'restaurant-name': 'dojo noodle bar'}
# --------
# I'm looking for da vinci pizzeria.
# {'restaurant-name': 'da vinci pizzeria'}
# --------
# Hi, can you look up Darrys Cookhouse and Wine Shop for me?
# {'restaurant-name': 'darrys cookhouse and wine shop'}
# --------
# Can you help me find a restaurant called little seoul?
# {'restaurant-name': 'little seoul'}
# --------
# Hi, I am looking for a restaurant called the hotspot.
# {'restaurant-name': 'the hotpot'}
# --------
# Could you help me find the Cambridge Belfry?
# {'hotel-name': 'cambridge belfry'}
# --------
# I am looking for a restaurant called Saint Johns Chop House, can you help me find it?
# {'restaurant-name': 'saint johns chop house'}
# --------
# Can you find a restaurant called Panahar?
# {'restaurant-name': 'panahar'}
# --------
# I am looking for fitzbillies in Cambridge.
# {'restaurant-name': 'fitzbillies restaurant'}
# --------
# I've heard about a hotel called Kirkwood House, but the only thing I know about it is the name. Can you tell me more?
# {'hotel-name': 'kirkwood house'}
# --------
# I'm looking for a particular restaurant called michaelhouse cafe.
# {'restaurant-name': 'michaelhouse cafe'}
# --------
# I am looking for information on the leverton house hotel
# {'hotel-name': 'leverton house'}
# --------
# My friends told me to look into a restaurant called The Gandhi, could you please give me some information on it?
# {'restaurant-name': 'the gandhi'}
# --------
# I'm looking for the Huntingdon Marriott Hotel.
# {'hotel-name': 'huntingdon marriott hotel'}
# --------
# While in Cambridge I need to find a restaurant called the rice boat.
# {'restaurant-name': 'rice boat'}
# --------
# I would like to find a certain restaurant called the Maharajah Tandoori Restaurant. Can you find it for me?
# {'restaurant-name': 'maharajah tandoori restaurant'}
# --------
# I'm visiting the area and want to stay at rosa's bed and breakfast.
# {'hotel-name': 'rosas bed and breakfast'}
# --------
# I am looking for the Warkworth House hotel.
# {'hotel-name': 'warkworth house'}
# --------
# I am looking for a hotel called Hobsons House.
# {'hotel-name': 'hobsons house'}
# --------
# I need your help in finding a particular restaurant. I don't know much about the restaurant, unfortunately I don't even know the food served. I do know the name: cafe uno.
# {'restaurant-name': 'cafe uno'}
# --------
# Hi. I am trying to find some information on a restaurant called India House. Have you heard of it?
# {'restaurant-name': 'india house'}
# --------
# I need help finding a place to eat called curry garden.
# {'restaurant-name': 'curry garden'}
# --------
# I would like to find a restaurant named Tandoori Palace. Do you know of that restaurant?
# {'restaurant-name': 'tandoori palace'}
# --------
# Can you help me find a restaurant by the name of Bangkok City?
# {'restaurant-name': 'bangkok city'}
# --------
# I need information on a restaurant called panahar.
# {'restaurant-name': 'panahar'}
# --------
# I would like more information on a hotel called cityroomz for my trip to Cambridge.
# {'hotel-name': 'cityroomz'}
# --------
# I am looking for the acorn guest house.
# {'hotel-name': 'acorn guest house'}
# --------
# I need to find a restaurant called taj tandoori
# {'restaurant-name': 'taj tandoori'}
# --------
# I'm looking for a restaurant called de luca cucina and bar
# {'restaurant-name': 'de luca cucina and bar'}
# --------
# Yeah, what can you tell me about Archway House?
# {'hotel-name': 'archway house'}
# --------
# Hi I am looking to get some information on autumn house hotel.
# {'hotel-name': 'autumn house'}
# --------
# Can you help me find a restaurant called "Cotto"?
# {'restaurant-name': 'cotto'}
# --------
# i'm looking for rosa's bed and breakfast
# {'hotel-name': 'rosas bed and breakfast'}
# --------
# I'm looking for a place called hakka.
# {'restaurant-name': 'hakka'}
# --------
# I'm looking to get some information on the alpha-milton guest house
# {'hotel-name': 'alpha-milton guest house'}
# --------
# I am looking for a particular hotel. Its name is called worth house.
# {'hotel-name': 'worth house'}
# --------
# I am looking for a restaurant called Efes Restaurant.
# {'restaurant-name': 'efes restaurant'}
# --------
# Hi. I am looking for information about a hotel called Home from home.
# {'hotel-name': 'home from home'}
# --------
# I would like the address to the Carolina Bed and Breakfast hotel in Cambridge.
# {'hotel-name': 'carolina bed and breakfast'}
# --------
# I am traveling to Cambridge and am super excited to see some of the local tourist attractions and I am looking for a restaurant call The Varsity Restaurant.
# {'restaurant-name': 'the varsity restaurant'}
# --------
# Hi there. I heard someone mention the Bloomsbury Restaurant and I was wondering if you could give me some information for them.
# {'restaurant-name': 'bloomsbury restaurant'}
# --------
# Could you give me some details for Carolina bed and breakfast?
# {'hotel-name': 'carolina bed and breakfast'}
# --------
# I would like to find a restuarant called La Raza. Will you help me?
# {'restaurant-name': 'la raza'}
# --------
# I am trying to find the cityroomz hotel.
# {'hotel-name': 'cityroomz'}
# --------
# I need information on the Aylesbray Lodge Guest House, please.
# {'hotel-name': 'aylesbray lodge guest house'}
# --------
# I need information on the university arms hotel.
# {'hotel-name': 'university arms hotel'}
# --------
# I need help finding a hotel called lovell lodge.
# {'hotel-name': 'lovell lodge'}
# --------
# Hi! I'm looking for a restaurant called Stazione Restaurant and Coffee Bar.
# {'restaurant-name': 'stazione restaurant and coffee bar'}
# --------
# Have you ever heard of alexander bed and breakfast?
# {'hotel-name': 'alexander bed and breakfast'}
# --------
# Finches Bed and Breakfast was recommended to me highly. Could you help me find it?
# {'hotel-name': 'finches bed and breakfast'}
# --------
# I need information on the home from home hotel.
# {'hotel-name': 'home from home'}
# --------
# I need some information on the Carolina Bed and Breakfast. Can you help me with that?
# {'hotel-name': 'carolina bed and breakfast'}
# --------
# Hi, I'm looking for a hotel called finches? It's a bed and breakfast.
# {'hotel-name': 'finches'}
# --------
# I've heard some buzz about the Hamilton Lodge. Can you tell me about it?
# {'hotel-name': 'hamilton lodge'}
# --------
# I am looking for a restaurant called yippee noodle bar.
# {'restaurant-name': 'yippee noodle bar'}
# --------
# I am looking for a hotel called huntingdon marriott hotel.
# {'hotel-name': 'huntingdon marriott hotel'}
# --------
# I am looking forward to try a local restaurant in Cambridge and I have clowns cafe particularly in my mind. Can you assist to book a table for me?
# {'restaurant-name': 'clowns cafe'}
# --------
# Hi, I'd like to stay at the warkworth house please.
# {'hotel-name': 'warkworth house'}
# --------
# Can I get some information on the Ali Baba restaurant?
# {'restaurant-name': 'ali baba'}
# --------
# Hi! I've heard of a great hotel called Hobsons House and I'd like to stay there. Can you help me locate it?
# {'hotel-name': 'hobsons house'}
# --------
# Can you help me find Arbury Lodge Guesthouse? Thanks.
# {'hotel-name': 'arbury lodge guesthouse'}
# --------
# Do you have information on Taj Tandoori?
# {'restaurant-name': 'taj tandoori'}
# --------
# Can you give me information about the Yu Garden? It's a restaurant my sister recommended.
# {'restaurant-name': 'yu garden'}
# --------
# Hello, I'm looking for a hotel named cityroomz. Can you provide me information about it please?
# {'hotel-name': 'cityroomz'}
# --------
# Yes, I need help locating Pizza Hut City Centre.
# {'restaurant-name': 'pizza hut city centre'}
# --------
# Hello, can you give me information about the hotel Express by Holiday Inn Cambridge, please?
# {'hotel-name': 'express by holiday inn cambridge'}
# --------
# Can you tell me about the J Restaurant?
# {'restaurant-name': 'j restaurant'}
# --------
# Yes, I need information on the restaurant Ali Baba.
# {'restaurant-name': 'ali baba'}
# --------
# I'm looking for information on the Leverton House hotel.
# {'hotel-name': 'leverton house'}
# --------
# Hi there, I'm looking for information on Darry's Cookhouse and Wine Shop.
# {'restaurant-name': 'darrys cookhouse and wine shop'}
# --------
# Could you please be kind enough and get me information on the autumn house?
# {'hotel-name': 'autumn house'}
# --------
# I'm looking for a place called riverside brasserie
# {'restaurant-name': 'riverside brasserie'}
# --------
# I'm trying to find more information on a particular hotel called the Alexander bed and breakfast.
# {'hotel-name': 'alexander bed and breakfast'}
# --------
# I am looking for a hotel named,"the lensfield hotel".
# {'hotel-name': 'lensfield hotel'}
# --------
# Hi, can you please give me information on the restaurant The Gardenia?
# {'restaurant-name': 'the gardenia'}
# --------
# Hello! I'm looking for information on Restaurant One Seven.
# {'restaurant-name': 'restaurant one seven'}
# --------
# Can you please tell me how to get to the Curry King restaurant please?
# {'restaurant-name': 'curry king'}
# --------
# Hi! Can you give me some information on the Golden Curry restaurant?
# {'restaurant-name': 'golden curry'}
# --------
# Hi, what can you tell me about a restaurant called the golden curry?
# {'restaurant-name': 'golden curry'}
# --------
# I'm hoping you can help me dig up some information about darrys cookhouse and wine shop.
# {'restaurant-name': 'darrys cookhouse and wine shop'}
# --------
# I am looking for a hotel in the Cambridge area called the limehouse.
# {'hotel-name': 'limehouse'}
# --------
# I want to find a place called Shiraz Restaurant please.
# {'restaurant-name': 'shiraz'}
# --------
# Can you help me find a hotel called Bridge Guest House?
# {'hotel-name': 'bridge guest house'}
# --------
# I'm looking for the Avalon.
# {'hotel-name': 'avalon'}
# --------
# I am looking for Ian hong house
# {'restaurant-name': 'ian hong house'}
# --------
# I've heard about Royal Spice, is it a very good restaurant? What is the price like?
# {'restaurant-name': 'royal spice'}
# --------
# I need a particular hotel called the Leverton House.
# {'hotel-name': 'leverton house'}
# --------
# Could you book me a room at the Huntingdon Marriott Hotel for tomorrow?
# {'hotel-name': 'huntingdon marriott hotel'}
# --------
# Hi there! I need some information on the Hamilton Lodge, please.
# {'hotel-name': 'hamilton lodge'}
# --------
# Hi there. I've heard great things about the Grafton Hotel Restaurant. Can you find me some details about it, please?
# {'restaurant-name': 'grafton hotel restaurant'}
# --------
# Can you help me find the hotel Worth House?
# {'hotel-name': 'worth house'}
# --------
# I am looking for Nandos city centre in Cambridge, can you give me directions?
# {'restaurant-name': 'nandos city centre'}
# --------
# I'm looking for a particular restaurant called charlie chan.
# {'restaurant-name': 'charlie chan'}
# --------
# I'm looking for a restaurant called pizza express Fen Ditton, do you have any information on it?
# {'restaurant-name': 'pizza express fen ditton'}
# --------
# Can you tell me more information on the avalon?
# {'hotel-name': 'avalon'}
# --------
# I am looking for information about the kirkwood hotel.
# {'hotel-name': 'kirkwood'}
# --------
# I'm looking for a hotel called the Leverton house. Can you help me find it?
# {'hotel-name': 'leverton house'}
# --------
# Can you give me some information on the Allenbell? It's a hotel.
# {'hotel-name': 'allenbell'}
# --------
# Please provide me information on the restaurant one seven.
# {'restaurant-name': 'restaurant one seven'}
# --------
# I'm looking for some info on kohinoor.
# {'restaurant-name': 'kohinoor'}
# --------
# I need to book a room at alexander bed and breakfast and also what restaurants are near there ?
# {'hotel-name': 'alexander bed and breakfast'}
# --------
# Hi I am looking for some information on the good luck chinese food takeaway.
# {'restaurant-food': 'chinese', 'restaurant-name': 'good luck'}
# --------
# I am looking for a particular restaurant. Its name is called restaurant one seven
# {'restaurant-name': 'restaurant one seven'}
# --------
# Can you find the A & B Guesthouse?
# {'hotel-name': 'b guesthouse'}
# --------
# Help me find a restaurant called hakka please
# {'restaurant-name': 'hakka'}
# --------
# I am looking for a particular hotel. Its name is called kirkwood house
# {'hotel-name': 'kirkwood house'}
# --------
# Hi, do you know of a hotel called finches bed and breakfast?
# {'hotel-name': 'finches bed and breakfast'}
# --------
# Where is this saffron brasserie located?
# {'restaurant-name': 'saffron brasserie'}
# --------
# Hi, I'm trying to find a restaurant called sala thong.
# {'restaurant-name': 'sala thong'}
# --------
# I'm looking for a certain hotel someone recommended, I think it's called the Gonville?
# {'hotel-name': 'gonville'}
# --------
# Can you give me some information on the Worth House?
# {'hotel-name': 'worth house'}
# --------
# Can you help me locate a restaurant called Pizza Express Fen Ditton?
# {'restaurant-name': 'pizza express fen ditton'}
# --------
# Im looking for a restaurant called sitar tandoori, can you help?
# {'restaurant-name': 'sitar tandoori'}
# --------
# I am looking for a hotel, the Alpha-Milton Guest House.
# {'hotel-name': 'alpha-milton guest house'}
# --------
# I'm trying to find information on a particular restaurant, it is called la margherita.
# {'restaurant-name': 'la margherita'}
# --------
# i am looking for a hotel in Cambridge called the cambridge belfry
# {'hotel-name': 'cambridge belfry'}
# --------
# I wanted to visit the restaurant named La Raza, could you tell me the hours it is open, and if I should try to book a reservation?
# {'restaurant-name': 'la raza'}
# --------
# I'm looking for information about a hotel in Cambridge called Warkworth House.
# {'hotel-name': 'warkworth house'}
# --------
# Hello! Can you please give me information about Dojo Noodle Bar?
# {'restaurant-name': 'dojo noodle bar'}
# --------
# Can you please help me get information on cityroomz?
# {'hotel-name': 'cityroomz'}
# --------
# Hello, I'm planning a trip to Cambridge and looking to make a reservation at a restaurant called the "Royal Standard". Can you get me the information for that restaurant please?
# {'restaurant-name': 'royal standard'}
# --------
# Yeah, what can you tell me about Archway House?
# {'hotel-name': 'archway house'}
# --------
# Hi, I'm looking for information on a particular restaurant called Galleria.
# {'restaurant-name': 'galleria'}
# --------
# I am looking fot a hotel, Allenbell.
# {'hotel-name': 'allenbell'}
# --------
# I am looking to eat at Rajmahal.
# {'restaurant-name': 'rajmahal'}
# --------
# I am in Cambridge and would like to try the restaurant City Stop Restaurant.
# {'restaurant-name': 'city stop restaurant'}
# --------
# I'm looking for a hotel called the autumn house, can you give me some information about it?
# {'hotel-name': 'autumn house'}
# --------
# I would like to get information on the bridge guest house.
# {'hotel-name': 'bridge guest house'}
# --------
# Hello, what can you tell me about de luca cucina and bar?
# {'restaurant-name': 'de luca cucina and bar'}
# --------
# Hello, I am looking for a restaurant called hotel du vin bistro.
# {'restaurant-name': 'hotel du vin and bistro'}
# --------
# Hello, I would like to find the el shaddai hotel. Can you help me?
# {'hotel-name': 'el shaddai'}
# --------
# Yes, I am searching for a hotel named the Aylesbray Lodge Guest House?
# {'hotel-name': 'aylesbray lodge guest house'}
# --------
# Can you help me find Restaurant One Seven?
# {'restaurant-name': 'restaurant one seven'}
# --------
# I am looking for the restaurant Nandos.
# {'restaurant-area': 'dontcare', 'restaurant-name': 'nandos'}
# --------
# Hello. I am looking for a hotel called gonville hotel.
# {'hotel-name': 'gonville hotel'}
# --------
# Hi there. Can you tell me if you have any information on the Bridge Guest House?
# {'hotel-name': 'bridge guest house'}
# --------
# Hi, where can I find the Autumn House hotel?
# {'hotel-name': 'autumn house'}
# --------
# Hi, I'm looking for a hotel called Leverton House.
# {'hotel-name': 'leverton house'}
# --------
# I want the address to the Autumn House hotel in Cambridge.
# {'hotel-name': 'autumn house'}
# --------
# I want to find some information about a hotel called alexander bed and breakfast.
# {'hotel-name': 'alexander bed and breakfast'}
# --------
# I'm looking for information on a restaurant called La Margherita.
# {'restaurant-name': 'la margherita'}
# --------
# I want to find some information on da vinci pizzeria
# {'restaurant-name': 'da vinci pizzeria'}
# --------
# I'm looking for a particular restaurant. Its name is called rice boat.
# {'restaurant-name': 'rice boat'}
# --------
# I'm looking for a particular restaurant. Its name is called panahar.
# {'restaurant-name': 'panahar'}
# --------
# I'm trying to find a hotel called Worth House. Can you help me?
# {'hotel-name': 'worth house'}
# --------
# I'm looking for the hotel called Kirkwood House.
# {'hotel-name': 'kirkwood house'}
# --------
# I would like to book a reservation at the cambridge lodge restaurant
# {'restaurant-name': 'cambridge lodge restaurant'}
# --------
# I'm looking for information about a restaurant named the golden wok.
# {'restaurant-name': 'golden wok'}
# --------
# I'm looking for a hotel called kirkwood house
# {'hotel-name': 'kirkwood house'}
# --------
# I am looking for details on the yu garden restaurant.
# {'restaurant-name': 'yu garden'}
# --------
# I would like to find the Anatolia restaurant please.
# {'restaurant-name': 'anatolia'}
# --------
# Can you get me information on a restaurant called j restaurant?
# {'restaurant-name': 'j restaurant'}
# --------
# I am looking for a hotel, the Alpha-Milton Guest House.
# {'hotel-name': 'alpha-milton guest house'}
# --------
# Can you get me information on a place called kymmoy?
# {'restaurant-name': 'kymmoy'}
# --------
# I would like some information on the gonville hotel
# {'hotel-name': 'gonville hotel'}
# --------
# Can you help direct me a restaurant called Golden House?
# {'restaurant-name': 'golden house'}
# --------
# I am looking for more information regarding the cambridge chop house.
# {'restaurant-name': 'cambridge chop house'}
# --------
# I'd like more information about the Ashley Hotel, can you help?
# {'hotel-name': 'ashley hotel'}
# --------
# Need a restaurant called the golden curry
# {'restaurant-name': 'golden curry'}
# --------
# I'm looking for information on a hotel called alexander bed and breakfast.
# {'hotel-name': 'alexander bed and breakfast'}
# --------
# I'm looking for a restaurant called the copper kettle.
# {'restaurant-name': 'copper kettle'}
# --------
# Hi there. I was wondering if you could provide some information on the Bridge Guest House hotel.
# {'hotel-name': 'bridge guest house'}
# --------
# I'm looking for a certain hotel called the cityroomz. Can you tell me more about it?
# {'hotel-name': 'cityroomz'}
# --------
# Hi I am looking for a hotel called limehouse.
# {'hotel-name': 'limehouse'}
# --------
# I am looking for a place called stazione restaurant and coffee bar. Can you help me?
# {'restaurant-name': 'stazione restaurant and coffee bar'}
# --------
# I am looking for a hotel called finches bed and breakfast.
# {'hotel-name': 'finches bed and breakfast'}
# --------
# Hello, I'd like some information about a hotel called the hamilton lodge, please.
# {'hotel-name': 'hamilton lodge'}
# --------
# I want information on a particular hotel called home from home. Can you send me what you have on that?
# {'hotel-name': 'home from home'}
# --------
# I don't know if you've heard of it but can you please get me some information on the la tasca restaurant?
# {'restaurant-name': 'la tasca'}
# --------
# I'm looking for a restaurant called little seoul?
# {'restaurant-name': 'little seoul'}
# --------
# Can you find a hotel by the name of Leverton House?
# {'hotel-name': 'leverton house'}
# --------
# I'm looking for a restaurant called ask. Do you know of it?
# {'restaurant-name': 'ask'}
# --------
# Hey, I'm trying to find a restaurant called Taj Tandoori. What do you know about that?
# {'restaurant-name': 'taj tandoori'}
# --------
# Please find a restaurant called Galleria.
# {'restaurant-name': 'galleria'}
# --------
# While in Cambridge I would really like to know where to find a place to eat called meghna.
# {'restaurant-name': 'meghna'}
# --------
# Hello, I am looking for information on a restaurant name Rice House.
# {'restaurant-name': 'rice house'}
# --------
# I am looking for a restaurant called shanghai family restaurant.
# {'restaurant-name': 'shanghai family restaurant'}
# --------
# Find me a place called maharajah tandoori restaurant, please
# {'restaurant-name': 'maharajah tandoori restaurant'}
# --------
# I'm looking for a hotel called avalon.
# {'hotel-name': 'avalon'}
# --------
# Could you help me find Cityroomz, please?
# {'hotel-name': 'cityroomz'}
# --------
# I am looking for some info on India House
# {'restaurant-area': 'dontcare', 'restaurant-food': 'dontcare', 'restaurant-name': 'india house', 'restaurant-pricerange': 'dontcare'}
# --------
# Can you get me information on a hotel called cityroomz?
# {'hotel-name': 'cityroomz'}
# --------
# While I am visiting Cambridge, I would like to stay at the Ashley Hotel. Where is it located?
# {'hotel-name': 'ashley hotel'}
# --------
# I've heard good things about the Acorn guest house. Could you find it for me?
# {'hotel-name': 'acorn guest house'}
# --------
# I am looking for a restaurant called thanh binh in Cambridge.
# {'restaurant-name': 'thanh binh'}
# --------
# I am looking for information on a hotel called Carolina Bed and Breakfast.
# {'hotel-name': 'carolina bed and breakfast'}
# --------
# I am looking for the price range of the hotel Finches bed and breakfast.
# {'hotel-name': 'finches bed and breakfast'}
# --------
# What can you tell me about the bangkok city restaurant?
# {'restaurant-name': 'bangkok city'}
# --------
# I'm looking for information on a hotel called the lensfield hotel.
# {'hotel-name': 'lensfield hotel'}
# --------
# Hello. I would like some information about the Aylesbray lodge guest house.
# {'hotel-name': 'aylesbray lodge guest house'}
# --------
# I'm looking for a restaurant my friend recommended, I think she called it the Curry Prince.
# {'restaurant-name': 'curry prince'}
# --------
# Can you find a hotel named Worth House for me? Thanks.
# {'hotel-name': 'worth house'}
# --------

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline

model_name = "deepset/roberta-base-squad2"
# model_name = "consciousAI/question-answering-roberta-base-s-v2"


# a) Get predictions
model = pipeline('question-answering', model=model_name, tokenizer=model_name)
QA_input = {
    'question': 'What is the name?',
    'context': """I'm looking to go to dinner tonight and am in the mood for some good Bistro in the centre of town, can you find me some options?"""
}
res = model(QA_input)
# Out:
# C:\Users\Minh UBC\miniconda3\Lib\site-packages\transformers\utils\generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# C:\Users\Minh UBC\miniconda3\Lib\site-packages\transformers\utils\generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# C:\Users\Minh UBC\miniconda3\Lib\site-packages\transformers\utils\generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(

# %%
print(res)
# Out:
# {'score': 0.05401258170604706, 'start': 69, 'end': 75, 'answer': 'Bistro'}

# %%
def get_name(text, nlp_model=model):
    """
        extract the name (hote/restaurant) from the text
    """
    query = {
    'question': 'What is the name?',
    'context': text
    }
    res = nlp_model(query)
    return res["answer"]

s = """I'm looking for a hotel called the a and b guest house. Can you help me out?"""
get_name(s)
# Out:
# 'a and b guest house'

# %%
# go through each of the item to analyze and predict name
gold_names = []
sys_names = []
correct_count = 0
wrong_preds = []

n = len(names_df)
max_row = n # set to n for full set
for i in range(max_row):
    item = names_df.iloc[i]

    txt = item["text"]

    print(txt)
    print(item["slots"])
    # extract gold name
    gold_name = ""
    if item["slots"].get("hotel-name", "") != "":
        gold_name = item["slots"].get("hotel-name", "")
    else:
        gold_name = item["slots"].get("restaurant-name", "")
    print("Gold name =", gold_name)
        
    pred_name = get_name(txt).lower()
    
    # apply some post-processing (remove 'the', 'restaurant', etc)
    print("Extracted =", pred_name)
    pred_name = (pred_name
                 # .replace("the", "")
                 # .replace("restaurant", "")
                 # .replace("hotel", "")
                 .replace("'s", "")
                 .replace(".", "")
                 .replace(",", "")
                 .strip()
                )
    print("Post-processed extracted =", pred_name)

    if gold_name == pred_name:
        print("Correct")
        correct_count += 1
    else:
        wrong_preds.append([txt, pred_name, gold_name])
    
    print("--------")

print("Completed")
# Out:
# Hi there! Can you give me some info on Cityroomz?
# {'hotel-name': 'cityroomz'}
# Gold name = cityroomz
# Extracted = cityroomz
# Post-processed extracted = cityroomz
# Correct
# --------
# I am looking for a hotel named alyesbray lodge guest house.
# {'hotel-name': 'alyesbray lodge guest house'}
# Gold name = alyesbray lodge guest house
# Extracted = alyesbray lodge guest house
# Post-processed extracted = alyesbray lodge guest house
# Correct
# --------
# I am looking for a particular restaurant. Its name is called travellers rest
# {'restaurant-name': 'travellers rest'}
# Gold name = travellers rest
# Extracted = travellers rest
# Post-processed extracted = travellers rest
# Correct
# --------
# Hi, what can you tell me about the bangkok city restaurant?
# {'restaurant-name': 'bangkok city'}
# Gold name = bangkok city
# Extracted = bangkok city restaurant
# Post-processed extracted = bangkok city restaurant
# --------
# I'm looking for a particular restaurant called ask. Please give me information on that restaurant.
# {'restaurant-name': 'ask'}
# Gold name = ask
# Extracted = ask
# Post-processed extracted = ask
# Correct
# --------
# I would like to find out information about a hotel called Warkworth House.
# {'hotel-name': 'warkworth house'}
# Gold name = warkworth house
# Extracted = warkworth house
# Post-processed extracted = warkworth house
# Correct
# --------
# I don't know if this is possible but can you please get me some information on the alexander bed and breakfast?
# {'hotel-name': 'alexander bed and breakfast'}
# Gold name = alexander bed and breakfast
# Extracted = alexander bed and breakfast
# Post-processed extracted = alexander bed and breakfast
# Correct
# --------
# I'm looking for a hotel called Kirkwood House please.
# {'hotel-name': 'kirkwood house'}
# Gold name = kirkwood house
# Extracted = kirkwood house
# Post-processed extracted = kirkwood house
# Correct
# --------
# I'm looking for a hotel called city centre north b and b
# {'hotel-name': 'city centre north b and b'}
# Gold name = city centre north b and b
# Extracted = city centre north b
# Post-processed extracted = city centre north b
# --------
# I am looking for information about a hotel called the autumn house.
# {'hotel-name': 'autumn house'}
# Gold name = autumn house
# Extracted = the autumn house
# Post-processed extracted = the autumn house
# --------
# I'm looking to get some info about a hotel called Home from Home
# {'hotel-name': 'home from home'}
# Gold name = home from home
# Extracted = home from home
# Post-processed extracted = home from home
# Correct
# --------
# Hi! Can you give me some information on the Royal Spice restaurant?
# {'restaurant-name': 'royal spice'}
# Gold name = royal spice
# Extracted = royal spice
# Post-processed extracted = royal spice
# Correct
# --------
# I am looking for Warkworth House hotel. Any information on it?
# {'hotel-name': 'warkworth house'}
# Gold name = warkworth house
# Extracted = warkworth house
# Post-processed extracted = warkworth house
# Correct
# --------
# Can you give me some information on the Avalon Hotel?
# {'hotel-name': 'avalon'}
# Gold name = avalon
# Extracted = avalon hotel
# Post-processed extracted = avalon hotel
# --------
# I am looking for the Limehouse hotel.
# {'hotel-name': 'limehouse'}
# Gold name = limehouse
# Extracted = limehouse
# Post-processed extracted = limehouse
# Correct
# --------
# i am looking for a particular restaurant. Its name is called restaurant two two.
# {'restaurant-name': 'restaurant two two'}
# Gold name = restaurant two two
# Extracted = restaurant two two
# Post-processed extracted = restaurant two two
# Correct
# --------
# Hi, I'm going to be visiting soon, and I am interested in trying a restaruant called Curry Prince. Could you give me more information about it?
# {'restaurant-name': 'curry prince'}
# Gold name = curry prince
# Extracted = curry prince
# Post-processed extracted = curry prince
# Correct
# --------
# Howdy, it would help me a great deal if you could please get me some information about the alexander bed and breakfast
# {'hotel-name': 'alexander bed and breakfast'}
# Gold name = alexander bed and breakfast
# Extracted = alexander
# Post-processed extracted = alexander
# --------
# I am looking for information on The Varsity restaurant.
# {'restaurant-name': 'the varsity restaurant'}
# Gold name = the varsity restaurant
# Extracted = the varsity
# Post-processed extracted = the varsity
# --------
# Yes I am looking for information on Michael House cafe.
# {'restaurant-name': 'michaelhouse cafe'}
# Gold name = michaelhouse cafe
# Extracted = michael house cafe
# Post-processed extracted = michael house cafe
# --------
# Is there a restaurant called Cocum?
# {'restaurant-name': 'cocum'}
# Gold name = cocum
# Extracted = cocum
# Post-processed extracted = cocum
# Correct
# --------
# I'm looking for a hotel called hamilton lodge.
# {'hotel-name': 'hamilton lodge'}
# Gold name = hamilton lodge
# Extracted = hamilton lodge
# Post-processed extracted = hamilton lodge
# Correct
# --------
# I sure hope so. A friend recommended the Alexander Bed and Breakfast. What can you tell me about it?
# {'hotel-name': 'alexander bed and breakfast'}
# Gold name = alexander bed and breakfast
# Extracted = alexander bed and breakfast
# Post-processed extracted = alexander bed and breakfast
# Correct
# --------
# I'm looking for a hotel called the a and b guest house. Can you help me out?
# {'hotel-name': 'a and b guest house'}
# Gold name = a and b guest house
# Extracted = a and b guest house
# Post-processed extracted = a and b guest house
# Correct
# --------
# I'm looking for this restaurant called city stop restaurant
# {'restaurant-name': 'city stop restaurant'}
# Gold name = city stop restaurant
# Extracted = city stop restaurant
# Post-processed extracted = city stop restaurant
# Correct
# --------
# I am looking for a hotel call arbury lodge guesthouse.
# {'hotel-name': 'arbury lodge guesthouse'}
# Gold name = arbury lodge guesthouse
# Extracted = arbury lodge guesthouse
# Post-processed extracted = arbury lodge guesthouse
# Correct
# --------
# I am looking for the gonville hotel. Can you help me?
# {'hotel-name': 'gonville hotel'}
# Gold name = gonville hotel
# Extracted = gonville hotel
# Post-processed extracted = gonville hotel
# Correct
# --------
# I'm looking for a place called maharajah tandoori restaurant. Do you know it? It's a restaurant.
# {'restaurant-name': 'maharajah tandoori restaurant'}
# Gold name = maharajah tandoori restaurant
# Extracted = maharajah tandoori restaurant
# Post-processed extracted = maharajah tandoori restaurant
# Correct
# --------
# Can you find a restaurant called Rajmahal.
# {'restaurant-name': 'rajmahal'}
# Gold name = rajmahal
# Extracted = rajmahal
# Post-processed extracted = rajmahal
# Correct
# --------
# I am looking for a hotel called The Cambridge Belfry. Can you help me with this?
# {'hotel-name': 'cambridge belfry'}
# Gold name = cambridge belfry
# Extracted = the cambridge belfry
# Post-processed extracted = the cambridge belfry
# --------
# I need to find information on home from home.
# {'hotel-name': 'home from home'}
# Gold name = home from home
# Extracted = home from home.
# Post-processed extracted = home from home
# Correct
# --------
# Hello! I'm looking for the hotel called Cityroomz. Can you give me some information, please?
# {'hotel-name': 'cityroomz'}
# Gold name = cityroomz
# Extracted = cityroomz
# Post-processed extracted = cityroomz
# Correct
# --------
# Yes, could you please tell me about the Alpha-Milton guest house?
# {'hotel-name': 'alpha-milton guest house'}
# Gold name = alpha-milton guest house
# Extracted = alpha-milton
# Post-processed extracted = alpha-milton
# --------
# I am looking for pasquale pizzeria.
# {'restaurant-name': 'pasquale pizzeria'}
# Gold name = pasquale pizzeria
# Extracted = pasquale pizzeria
# Post-processed extracted = pasquale pizzeria
# Correct
# --------
# I am looking to get some information on the acorn guest house.
# {'hotel-name': 'acorn guest house'}
# Gold name = acorn guest house
# Extracted = acorn
# Post-processed extracted = acorn
# --------
# Hi, I'm looking to book the Hamilton Lodge in Cambridge
# {'hotel-name': 'hamilton lodge'}
# Gold name = hamilton lodge
# Extracted = hamilton lodge
# Post-processed extracted = hamilton lodge
# Correct
# --------
# Can you help me find a restaurant called graffiti please?
# {'restaurant-name': 'graffiti'}
# Gold name = graffiti
# Extracted = restaurant called graffiti
# Post-processed extracted = restaurant called graffiti
# --------
# I need to find out information about a particular hotel called warkworth house
# {'hotel-name': 'warkworth house'}
# Gold name = warkworth house
# Extracted = warkworth house
# Post-processed extracted = warkworth house
# Correct
# --------
# I'm looking for a restaurant called Thanh Binh. Can you help me find it?
# {'restaurant-name': 'thanh binh'}
# Gold name = thanh binh
# Extracted = thanh binh
# Post-processed extracted = thanh binh
# Correct
# --------
# Hello, i'm looking for a restaurant called river bar steakhouse and grill.
# {'restaurant-name': 'river bar steakhouse and grill'}
# Gold name = river bar steakhouse and grill
# Extracted = river bar
# Post-processed extracted = river bar
# --------
# I'd like some information on the Hamilton Lodge hotel, please.
# {'hotel-name': 'hamilton lodge'}
# Gold name = hamilton lodge
# Extracted = hamilton lodge
# Post-processed extracted = hamilton lodge
# Correct
# --------
# I am looking for a restaurant called Charlie Chan
# {'restaurant-name': 'charlie chan'}
# Gold name = charlie chan
# Extracted = charlie chan
# Post-processed extracted = charlie chan
# Correct
# --------
# I am looking for some information on rosas's bed and breakfast.
# {'hotel-name': 'rosas bed and breakfast'}
# Gold name = rosas bed and breakfast
# Extracted = rosas's bed and breakfast
# Post-processed extracted = rosas bed and breakfast
# Correct
# --------
# I'm looking for information on a hotel called hamilton lodge.
# {'hotel-name': 'hamilton lodge'}
# Gold name = hamilton lodge
# Extracted = hamilton lodge
# Post-processed extracted = hamilton lodge
# Correct
# --------
# Yes I would like information on the Cambridge Belfry.
# {'hotel-name': 'cambridge belfry'}
# Gold name = cambridge belfry
# Extracted = cambridge belfry
# Post-processed extracted = cambridge belfry
# Correct
# --------
# i need info about cityroomz
# {'hotel-name': 'cityroomz'}
# Gold name = cityroomz
# Extracted = cityroomz
# Post-processed extracted = cityroomz
# Correct
# --------
# Hey, is curry king still open?
# {'restaurant-name': 'curry king'}
# Gold name = curry king
# Extracted = curry king
# Post-processed extracted = curry king
# Correct
# --------
# I am looking for Golden House restaurant.
# {'restaurant-name': 'golden house'}
# Gold name = golden house
# Extracted = golden house
# Post-processed extracted = golden house
# Correct
# --------
# I am looking for Cote restaurant.
# {'restaurant-name': 'cote'}
# Gold name = cote
# Extracted = cote restaurant
# Post-processed extracted = cote restaurant
# --------
# Hi I am looking for some info on the Worth House hotel.
# {'hotel-name': 'worth house'}
# Gold name = worth house
# Extracted = worth house
# Post-processed extracted = worth house
# Correct
# --------
# I am looking for a particular hotel. Its name is called autumn house
# {'hotel-name': 'autumn house'}
# Gold name = autumn house
# Extracted = autumn house
# Post-processed extracted = autumn house
# Correct
# --------
# Please I need a place to Stay in Cambridge and I have the express by holiday inn Cambridge in mind. Can you help book that for me?
# {'hotel-name': 'express by holiday inn cambridge'}
# Gold name = express by holiday inn cambridge
# Extracted = the express by holiday inn cambridge
# Post-processed extracted = the express by holiday inn cambridge
# --------
# Hello, can you recommend a moderately-priced hotel in the North part of town, please?
# {'hotel-area': 'north', 'hotel-name': 'dontcare', 'hotel-pricerange': 'moderate'}
# Gold name = dontcare
# Extracted = moderately-priced hotel
# Post-processed extracted = moderately-priced hotel
# --------
# I'd like some information about the University Arms Hotel.
# {'hotel-name': 'university arms hotel'}
# Gold name = university arms hotel
# Extracted = university arms hotel
# Post-processed extracted = university arms hotel
# Correct
# --------
# I need some info on a restaurant called royal spice.
# {'restaurant-name': 'royal spice'}
# Gold name = royal spice
# Extracted = royal spice
# Post-processed extracted = royal spice
# Correct
# --------
# Everyone keeps telling me I have to stay at Cityroomz when I visit next. Have you heard of it?
# {'hotel-name': 'cityroomz'}
# Gold name = cityroomz
# Extracted = cityroomz
# Post-processed extracted = cityroomz
# Correct
# --------
# I'd really like to get the number for the Yippee Noodle Bar restaurant if you please?
# {'restaurant-name': 'yippee noodle bar'}
# Gold name = yippee noodle bar
# Extracted = yippee noodle bar
# Post-processed extracted = yippee noodle bar
# Correct
# --------
# I need to find information on the Bloomsbury Restaurant.
# {'restaurant-name': 'bloomsbury restaurant'}
# Gold name = bloomsbury restaurant
# Extracted = bloomsbury restaurant
# Post-processed extracted = bloomsbury restaurant
# Correct
# --------
# I am looking for a restaurant called HK Fusion.
# {'restaurant-name': 'hk fusion'}
# Gold name = hk fusion
# Extracted = hk fusion
# Post-processed extracted = hk fusion
# Correct
# --------
# Hi, I'm looking for a hotel that was recommended. It's called the Cambridge Belfry?
# {'hotel-name': 'cambridge belfry'}
# Gold name = cambridge belfry
# Extracted = cambridge belfry
# Post-processed extracted = cambridge belfry
# Correct
# --------
# Need a certain restaurant called stazione restaurant and coffee bar.
# {'restaurant-name': 'stazione restaurant and coffee bar'}
# Gold name = stazione restaurant and coffee bar
# Extracted = stazione restaurant
# Post-processed extracted = stazione restaurant
# --------
# i need information of a hotel called allenbell.
# {'hotel-name': 'allenbell'}
# Gold name = allenbell
# Extracted = allenbell
# Post-processed extracted = allenbell
# Correct
# --------
# I need a restaurant. I've heard Nandos recommended, could you give me more information about it?
# {'restaurant-name': 'nandos'}
# Gold name = nandos
# Extracted = nandos
# Post-processed extracted = nandos
# Correct
# --------
# Hi, I'd like to find out about the Hobsons House hotel.
# {'hotel-name': 'hobsons house'}
# Gold name = hobsons house
# Extracted = hobsons house
# Post-processed extracted = hobsons house
# Correct
# --------
# I am looking for the price range and address of the Meze Bar Restaurant
# {'restaurant-name': 'meze bar'}
# Gold name = meze bar
# Extracted = meze bar restaurant
# Post-processed extracted = meze bar restaurant
# --------
# I'm looking for a hotel called a and b quest house.
# {'hotel-name': 'a and b quest house'}
# Gold name = a and b quest house
# Extracted = a and b quest house
# Post-processed extracted = a and b quest house
# Correct
# --------
# I am looking for a place to stay that is named aylesbray lodge guest house. Could you give me some information about it?
# {'hotel-name': 'aylesbray lodge guest house', 'hotel-type': 'guesthouse'}
# Gold name = aylesbray lodge guest house
# Extracted = aylesbray lodge guest house
# Post-processed extracted = aylesbray lodge guest house
# Correct
# --------
# Can you help me find the a and b guest house hotel?
# {'hotel-name': 'a and b guest house'}
# Gold name = a and b guest house
# Extracted = a and b guest house hotel
# Post-processed extracted = a and b guest house hotel
# --------
# Could you provide me with information about the Huntingdon Marriott hotel?
# {'hotel-name': 'huntingdon marriott hotel'}
# Gold name = huntingdon marriott hotel
# Extracted = huntingdon marriott hotel
# Post-processed extracted = huntingdon marriott hotel
# Correct
# --------
# I want to book the el shaddai hotel.
# {'hotel-name': 'el shaddai'}
# Gold name = el shaddai
# Extracted = el shaddai hotel
# Post-processed extracted = el shaddai hotel
# --------
# Do you have any information on a restaurant called the Golden Wok?
# {'restaurant-name': 'golden wok'}
# Gold name = golden wok
# Extracted = golden wok
# Post-processed extracted = golden wok
# Correct
# --------
# Hello! What can you tell me about the Shiraz restaurant?
# {'restaurant-name': 'shiraz'}
# Gold name = shiraz
# Extracted = shiraz restaurant
# Post-processed extracted = shiraz restaurant
# --------
# I'm looking for information on la tasca.
# {'restaurant-name': 'la tasca'}
# Gold name = la tasca
# Extracted = la tasca
# Post-processed extracted = la tasca
# Correct
# --------
# I'm looking for a restaurant called the gandhi.
# {'restaurant-name': 'the gandhi'}
# Gold name = the gandhi
# Extracted = gandhi
# Post-processed extracted = gandhi
# --------
# Could you give me some information on a hotel named el shaddai?
# {'hotel-name': 'el shaddai'}
# Gold name = el shaddai
# Extracted = el shaddai
# Post-processed extracted = el shaddai
# Correct
# --------
# I'm looking for a restaurant called restaurant two two?
# {'restaurant-name': 'restaurant two two'}
# Gold name = restaurant two two
# Extracted = restaurant two two
# Post-processed extracted = restaurant two two
# Correct
# --------
# i am looking for a particular hotel. Its name is called aylesbray lodge guest house.
# {'hotel-name': 'aylesbray lodge guest house'}
# Gold name = aylesbray lodge guest house
# Extracted = aylesbray lodge guest house
# Post-processed extracted = aylesbray lodge guest house
# Correct
# --------
# I'm looking for a hotel named Worth House
# {'hotel-name': 'worth house'}
# Gold name = worth house
# Extracted = worth house
# Post-processed extracted = worth house
# Correct
# --------
# I am looking for information on a restaurant called saigon city?
# {'restaurant-name': 'saigon city'}
# Gold name = saigon city
# Extracted = saigon city
# Post-processed extracted = saigon city
# Correct
# --------
# Hello, can you give me information about Express by Holiday Inn Cambridge, please?
# {'hotel-name': 'express by holiday inn cambridge'}
# Gold name = express by holiday inn cambridge
# Extracted = express by holiday inn cambridge
# Post-processed extracted = express by holiday inn cambridge
# Correct
# --------
# Does Cambridge have an establishment called the Shanghai Family Restaurant?
# {'restaurant-name': 'shanghai family restaurant'}
# Gold name = shanghai family restaurant
# Extracted = shanghai family restaurant
# Post-processed extracted = shanghai family restaurant
# Correct
# --------
# I'm looking for a particular restaurant called the cow pizza kitchen and bar. What do you know about it?
# {'restaurant-name': 'cow pizza kitchen and bar'}
# Gold name = cow pizza kitchen and bar
# Extracted = cow pizza kitchen and bar
# Post-processed extracted = cow pizza kitchen and bar
# Correct
# --------
# Hi, I'm looking for the Bridge Guest House. Can you give the information about it please?
# {'hotel-name': 'bridge guest house'}
# Gold name = bridge guest house
# Extracted = bridge guest house
# Post-processed extracted = bridge guest house
# Correct
# --------
# I am looking for a restaurant, it's called anatolia
# {'restaurant-name': 'anatolia'}
# Gold name = anatolia
# Extracted = anatolia
# Post-processed extracted = anatolia
# Correct
# --------
# Can you tell me more about gourmet burger kitchen? Where is it?
# {'restaurant-name': 'gourmet burger kitchen'}
# Gold name = gourmet burger kitchen
# Extracted = gourmet burger kitchen
# Post-processed extracted = gourmet burger kitchen
# Correct
# --------
# Are there any available rooms in the Autumn House?
# {'hotel-name': 'autumn house'}
# Gold name = autumn house
# Extracted = autumn house
# Post-processed extracted = autumn house
# Correct
# --------
# I'm trying to find a restaurant called The Slug and Lettuce. Do you know where that is?
# {'restaurant-name': 'the slug and lettuce'}
# Gold name = the slug and lettuce
# Extracted = the slug and lettuce
# Post-processed extracted = the slug and lettuce
# Correct
# --------
# I am looking for a restaurant called Galleria.
# {'restaurant-name': 'galleria'}
# Gold name = galleria
# Extracted = galleria
# Post-processed extracted = galleria
# Correct
# --------
# Can you help me find information about a hotel called huntingdon marriott hotel?
# {'hotel-name': 'huntingdon marriott hotel'}
# Gold name = huntingdon marriott hotel
# Extracted = huntingdon marriott hotel
# Post-processed extracted = huntingdon marriott hotel
# Correct
# --------
# What can you tell me about the El Shaddai?
# {'hotel-name': 'el shaddai'}
# Gold name = el shaddai
# Extracted = el shaddai
# Post-processed extracted = el shaddai
# Correct
# --------
# I am looking for a hotel by the name of home from home.
# {'hotel-name': 'home from home'}
# Gold name = home from home
# Extracted = home from home
# Post-processed extracted = home from home
# Correct
# --------
# Can you help me find a place to stay that has free parking? It doesn't need to include internet.
# {'hotel-area': 'dontcare', 'hotel-internet': 'dontcare', 'hotel-name': 'dontcare', 'hotel-parking': 'yes', 'hotel-type': 'dontcare'}
# Gold name = dontcare
# Extracted = a place to stay
# Post-processed extracted = a place to stay
# --------
# Could you help me locate the Alpha Milton Guest House?
# {'hotel-name': 'alpha milton guest house'}
# Gold name = alpha milton guest house
# Extracted = alpha milton
# Post-processed extracted = alpha milton
# --------
# I would like to know more about Rosa's b&b
# {'hotel-name': 'rosas bed and breakfast'}
# Gold name = rosas bed and breakfast
# Extracted = rosa's b&b
# Post-processed extracted = rosa b&b
# --------
# Do you have information about the Lovell Lodge?
# {'hotel-name': 'lovell lodge'}
# Gold name = lovell lodge
# Extracted = lovell lodge
# Post-processed extracted = lovell lodge
# Correct
# --------
# I want to find information on a restaurant called Wagamama.
# {'restaurant-name': 'wagamama'}
# Gold name = wagamama
# Extracted = wagamama
# Post-processed extracted = wagamama
# Correct
# --------
# Can you tell me about a particular hotel called the avalon?
# {'hotel-name': 'avalon'}
# Gold name = avalon
# Extracted = avalon
# Post-processed extracted = avalon
# Correct
# --------
# What can you tell me about the bangkok city restaurant?
# {'restaurant-area': 'centre', 'restaurant-name': 'bangkok city'}
# Gold name = bangkok city
# Extracted = bangkok city restaurant
# Post-processed extracted = bangkok city restaurant
# --------
# I'm looking for a place called gonville hotel.
# {'hotel-name': 'gonville hotel'}
# Gold name = gonville hotel
# Extracted = gonville hotel
# Post-processed extracted = gonville hotel
# Correct
# --------
# I would like some information of the restaurant called Royal Standard.
# {'restaurant-name': 'royal standard'}
# Gold name = royal standard
# Extracted = royal standard
# Post-processed extracted = royal standard
# Correct
# --------
# Can you give me some information on the Bloomsbury Restaurant?
# {'restaurant-name': 'bloomsbury restaurant'}
# Gold name = bloomsbury restaurant
# Extracted = bloomsbury restaurant
# Post-processed extracted = bloomsbury restaurant
# Correct
# --------
# I'm looking for a hotel called acorn guest house
# {'hotel-name': 'acorn guest house'}
# Gold name = acorn guest house
# Extracted = acorn guest house
# Post-processed extracted = acorn guest house
# Correct
# --------
# Hi! I'm looking for information on the Rice House restaurant.
# {'restaurant-name': 'rice house'}
# Gold name = rice house
# Extracted = rice house
# Post-processed extracted = rice house
# Correct
# --------
# I need to find a restaurant in anatolia
# {'restaurant-name': 'anatolia'}
# Gold name = anatolia
# Extracted = restaurant
# Post-processed extracted = restaurant
# --------
# I am looking for a particular restaurant. It is called pizza hut city centre.
# {'restaurant-name': 'pizza hut city centre'}
# Gold name = pizza hut city centre
# Extracted = pizza hut city centre
# Post-processed extracted = pizza hut city centre
# Correct
# --------
# I would like to know more about a restaurant called the panahar if you could help?
# {'restaurant-name': 'panahar'}
# Gold name = panahar
# Extracted = panahar
# Post-processed extracted = panahar
# Correct
# --------
# Can you get me information on a restaurant called golden house?
# {'restaurant-name': 'golden house'}
# Gold name = golden house
# Extracted = golden house
# Post-processed extracted = golden house
# Correct
# --------
# I would like info about the Cityroomz hotel please
# {'hotel-name': 'cityroomz'}
# Gold name = cityroomz
# Extracted = cityroomz
# Post-processed extracted = cityroomz
# Correct
# --------
# Hi, I'm looking for a hotel, the archway house?
# {'hotel-name': 'archway house'}
# Gold name = archway house
# Extracted = hotel
# Post-processed extracted = hotel
# --------
# Hi, I'd like information for the restaurant called Travellers Rest please.
# {'restaurant-name': 'travellers rest'}
# Gold name = travellers rest
# Extracted = travellers rest
# Post-processed extracted = travellers rest
# Correct
# --------
# Hello, I'm looking for a restaurant by the name of Cote. Can you find this for me and book a reservation please?
# {'restaurant-name': 'cote'}
# Gold name = cote
# Extracted = cote
# Post-processed extracted = cote
# Correct
# --------
# Hello! My friends told me about a hotel called Alexander Bed and Breakfast. Can you get me some information about it, please?
# {'hotel-name': 'alexander bed and breakfast'}
# Gold name = alexander bed and breakfast
# Extracted = alexander bed and breakfast
# Post-processed extracted = alexander bed and breakfast
# Correct
# --------
# I would like to find a restaurant called Pipasha.
# {'restaurant-name': 'pipasha restaurant'}
# Gold name = pipasha restaurant
# Extracted = pipasha
# Post-processed extracted = pipasha
# --------
# I am looking for a hotel by the name of The Lensfield Hotel.
# {'hotel-name': 'lensfield hotel'}
# Gold name = lensfield hotel
# Extracted = the lensfield hotel
# Post-processed extracted = the lensfield hotel
# --------
# I am interested in finding the Lensfield Hotel.
# {'hotel-name': 'lensfield hotel'}
# Gold name = lensfield hotel
# Extracted = lensfield hotel
# Post-processed extracted = lensfield hotel
# Correct
# --------
# I need some information on a place to eat call the nirala.
# {'restaurant-name': 'nirala'}
# Gold name = nirala
# Extracted = nirala
# Post-processed extracted = nirala
# Correct
# --------
# I'm looking for this hotel called home from home, please.
# {'hotel-name': 'home from home'}
# Gold name = home from home
# Extracted = home from home
# Post-processed extracted = home from home
# Correct
# --------
# I need to get to a restaurant known as the Lucky star
# {'restaurant-name': 'the lucky star'}
# Gold name = the lucky star
# Extracted = the lucky star
# Post-processed extracted = the lucky star
# Correct
# --------
# Hi, I'm trying to find a place to stay called the cambridge belfry. What can you tell me about that?
# {'hotel-name': 'cambridge belfry'}
# Gold name = cambridge belfry
# Extracted = cambridge belfry
# Post-processed extracted = cambridge belfry
# Correct
# --------
# Is the alpha-milton guest house still in operation?
# {'hotel-name': 'alpha-milton guest house'}
# Gold name = alpha-milton guest house
# Extracted = alpha-milton
# Post-processed extracted = alpha-milton
# --------
# Hello, have you heard of the Royal Spice Restaurant by chance?
# {'restaurant-name': 'royal spice'}
# Gold name = royal spice
# Extracted = royal spice restaurant
# Post-processed extracted = royal spice restaurant
# --------
# I am looking for directions to Jinling Noodle Bar, can you help me?
# {'restaurant-name': 'jinling noodle bar'}
# Gold name = jinling noodle bar
# Extracted = jinling noodle bar
# Post-processed extracted = jinling noodle bar
# Correct
# --------
# I am visiting Cambridge and would like to stay at Allenbell can you help give me some information on it?
# {'hotel-name': 'allenbell'}
# Gold name = allenbell
# Extracted = allenbell
# Post-processed extracted = allenbell
# Correct
# --------
# Hi, I'm looking for information on the Autumn House. It's a hotel.
# {'hotel-name': 'autumn house'}
# Gold name = autumn house
# Extracted = autumn house
# Post-processed extracted = autumn house
# Correct
# --------
# Hey, when I was a kid my parents took me to a place called the cow pizza kitchen and bar. Is it still around?
# {'restaurant-name': 'cow pizza kitchen and bar'}
# Gold name = cow pizza kitchen and bar
# Extracted = cow pizza kitchen and bar
# Post-processed extracted = cow pizza kitchen and bar
# Correct
# --------
# I am looking for a restaurant named Hakka. Can you tell me how to get there?
# {'restaurant-name': 'hakka'}
# Gold name = hakka
# Extracted = hakka
# Post-processed extracted = hakka
# Correct
# --------
# I am looking for a particular hotel. Its name is called arbury lodge guesthouse
# {'hotel-name': 'arbury lodge guesthouse'}
# Gold name = arbury lodge guesthouse
# Extracted = arbury lodge guesthouse
# Post-processed extracted = arbury lodge guesthouse
# Correct
# --------
# I am looking for a particular restaurant. Its name is called city stop restaurant
# {'restaurant-name': 'city stop restaurant'}
# Gold name = city stop restaurant
# Extracted = city stop restaurant
# Post-processed extracted = city stop restaurant
# Correct
# --------
# I'm looking for yu garden, can you help me find it?
# {'restaurant-name': 'yu garden'}
# Gold name = yu garden
# Extracted = yu garden
# Post-processed extracted = yu garden
# Correct
# --------
# What can you dig up about the pizza express Fen Ditton?
# {'restaurant-name': 'pizza express fen ditton'}
# Gold name = pizza express fen ditton
# Extracted = fen ditton
# Post-processed extracted = fen ditton
# --------
# I'd like to find the Lensfield Hotel.
# {'hotel-name': 'lensfield hotel'}
# Gold name = lensfield hotel
# Extracted = lensfield hotel
# Post-processed extracted = lensfield hotel
# Correct
# --------
# I am trying to find the Acorn Guest House.
# {'hotel-name': 'acorn guest house'}
# Gold name = acorn guest house
# Extracted = acorn guest house
# Post-processed extracted = acorn guest house
# Correct
# --------
# I'm looking for a particular hotel called "rosa's bed and breakfast".
# {'hotel-name': 'rosas bed and breakfast'}
# Gold name = rosas bed and breakfast
# Extracted = rosa's bed and breakfast
# Post-processed extracted = rosa bed and breakfast
# --------
# I am looking for information for Warkworth House.
# {'hotel-name': 'warkworth house'}
# Gold name = warkworth house
# Extracted = warkworth house
# Post-processed extracted = warkworth house
# Correct
# --------
# Hello are you familiar with Rosa's bed and breakfast? I've been looking for this hotel for forever!
# {'hotel-name': 'rosas bed and breakfast'}
# Gold name = rosas bed and breakfast
# Extracted = rosa's bed and breakfast
# Post-processed extracted = rosa bed and breakfast
# --------
# I'm looking for info on a restaurant called La Tasca.
# {'restaurant-name': 'la tasca'}
# Gold name = la tasca
# Extracted = la tasca
# Post-processed extracted = la tasca
# Correct
# --------
# I need information on a hotel named,"rosa's bed and breakfast".
# {'hotel-name': 'rosas bed and breakfast'}
# Gold name = rosas bed and breakfast
# Extracted = rosa's bed and breakfast
# Post-processed extracted = rosa bed and breakfast
# --------
# Hi, Have you heard of the J Restaurant? I'd like some information about it.
# {'restaurant-name': 'j restaurant'}
# Gold name = j restaurant
# Extracted = j restaurant
# Post-processed extracted = j restaurant
# Correct
# --------
# I'm trying to find a hotel called Worth House. Can you help me?
# {'hotel-name': 'worth house'}
# Gold name = worth house
# Extracted = worth house
# Post-processed extracted = worth house
# Correct
# --------
# What can you tell me about the hotel el shaddai?
# {'hotel-name': 'el shaddai'}
# Gold name = el shaddai
# Extracted = hotel el shaddai
# Post-processed extracted = hotel el shaddai
# --------
# Hi, I'm looking for a particular restaurant named Bedouin. Can you help?
# {'restaurant-name': 'bedouin'}
# Gold name = bedouin
# Extracted = bedouin
# Post-processed extracted = bedouin
# Correct
# --------
# I'm looking for a place, I think it's called the Arbury Guesthouse and Lodge. Can you help me?
# {'hotel-name': 'arbury guesthouse and lodge'}
# Gold name = arbury guesthouse and lodge
# Extracted = arbury guesthouse and lodge
# Post-processed extracted = arbury guesthouse and lodge
# Correct
# --------
# Hi, what can you tell me about a restaurant called hakka?
# {'restaurant-name': 'hakka'}
# Gold name = hakka
# Extracted = hakka
# Post-processed extracted = hakka
# Correct
# --------
# I'd like to find out more about the bloomsbury restaurant
# {'restaurant-name': 'bloomsbury restaurant'}
# Gold name = bloomsbury restaurant
# Extracted = bloomsbury
# Post-processed extracted = bloomsbury
# --------
# Hi! Can you give me some information on the Bangkok City restaurant?
# {'restaurant-name': 'bangkok city'}
# Gold name = bangkok city
# Extracted = bangkok city restaurant
# Post-processed extracted = bangkok city restaurant
# --------
# Have you ever heard of a hotel called the Ashley Hotel?
# {'hotel-name': 'ashley hotel'}
# Gold name = ashley hotel
# Extracted = ashley hotel
# Post-processed extracted = ashley hotel
# Correct
# --------
# Yes, can you lookup the chiquito restaurant bar for me.
# {'restaurant-name': 'chiquito restaurant bar'}
# Gold name = chiquito restaurant bar
# Extracted = chiquito restaurant bar
# Post-processed extracted = chiquito restaurant bar
# Correct
# --------
# Hello I am looking for a restaurant called J restaurant
# {'restaurant-name': 'j restaurant'}
# Gold name = j restaurant
# Extracted = j restaurant
# Post-processed extracted = j restaurant
# Correct
# --------
# Can you help me find a place to eat called sala thong?
# {'restaurant-name': 'sala thong'}
# Gold name = sala thong
# Extracted = sala thong
# Post-processed extracted = sala thong
# Correct
# --------
# I am looking for a particular hotel. Its name is called city centre north b and b
# {'hotel-name': 'city centre north b and b'}
# Gold name = city centre north b and b
# Extracted = city centre north b
# Post-processed extracted = city centre north b
# --------
# Hi, is there a restaurant in town called the rice boat?
# {'restaurant-name': 'rice boat'}
# Gold name = rice boat
# Extracted = rice boat
# Post-processed extracted = rice boat
# Correct
# --------
# I'm just looking for a hotel called Leverton House.
# {'hotel-name': 'leverton house'}
# Gold name = leverton house
# Extracted = leverton house
# Post-processed extracted = leverton house
# Correct
# --------
# I'm looking for the university arms hotel. Can you give me more information about it?
# {'hotel-name': 'university arms hotel'}
# Gold name = university arms hotel
# Extracted = university arms hotel
# Post-processed extracted = university arms hotel
# Correct
# --------
# I want to make a booking at the alexander bed and breakfast.
# {'hotel-name': 'alexander bed and breakfast'}
# Gold name = alexander bed and breakfast
# Extracted = alexander bed and breakfast
# Post-processed extracted = alexander bed and breakfast
# Correct
# --------
# Can I get some information on the arbury lodge guesthouse?
# {'hotel-name': 'arbury lodge guesthouse'}
# Gold name = arbury lodge guesthouse
# Extracted = arbury lodge guesthouse
# Post-processed extracted = arbury lodge guesthouse
# Correct
# --------
# Can you find the restaurant names Loch Fyne?
# {'restaurant-name': 'loch fyne'}
# Gold name = loch fyne
# Extracted = loch fyne
# Post-processed extracted = loch fyne
# Correct
# --------
# Can you give me information on a restaurant called graffiti?
# {'restaurant-name': 'graffiti'}
# Gold name = graffiti
# Extracted = graffiti
# Post-processed extracted = graffiti
# Correct
# --------
# I would like to stay at Rosa's bed and breakfast in cambridge. can you give tell me their contact information and location?
# {'hotel-name': 'rosas bed and breakfast'}
# Gold name = rosas bed and breakfast
# Extracted = rosa
# Post-processed extracted = rosa
# --------
# I need some information on a place called Pizza express.
# {'restaurant-name': 'pizza express'}
# Gold name = pizza express
# Extracted = pizza express
# Post-processed extracted = pizza express
# Correct
# --------
# Hello. I'm trying to find a restaurant called Graffiti. Can you help me locate it?
# {'restaurant-name': 'graffiti'}
# Gold name = graffiti
# Extracted = graffiti
# Post-processed extracted = graffiti
# Correct
# --------
# Hi, I'm really looking forward to coming to Cambridge. You have an Express by Holiday Inn, right?
# {'hotel-name': 'express by holiday inn'}
# Gold name = express by holiday inn
# Extracted = express by holiday inn
# Post-processed extracted = express by holiday inn
# Correct
# --------
# I would like information on the Gonville hotel.
# {'hotel-name': 'gonville hotel'}
# Gold name = gonville hotel
# Extracted = gonville hotel
# Post-processed extracted = gonville hotel
# Correct
# --------
# What is the address for find pizza hut city centre?
# {'restaurant-name': 'pizza hut city centre'}
# Gold name = pizza hut city centre
# Extracted = pizza hut
# Post-processed extracted = pizza hut
# --------
# I'm looking for pizza hut fen ditton.
# {'restaurant-name': 'pizza hut fenditton'}
# Gold name = pizza hut fenditton
# Extracted = pizza hut
# Post-processed extracted = pizza hut
# --------
# Do you know where I can find the Peking Restaurant?
# {'restaurant-name': 'peking restaurant'}
# Gold name = peking restaurant
# Extracted = peking restaurant
# Post-processed extracted = peking restaurant
# Correct
# --------
# Do you have any information on a hotel called the Acorn Guesthouse?
# {'hotel-name': 'acorn guest house'}
# Gold name = acorn guest house
# Extracted = acorn guesthouse
# Post-processed extracted = acorn guesthouse
# --------
# I'm looking for a restaurant called Meghna.
# {'restaurant-name': 'meghna'}
# Gold name = meghna
# Extracted = meghna
# Post-processed extracted = meghna
# Correct
# --------
# Can you tell me more about the peking restaurant? Thank you.
# {'restaurant-name': 'peking restaurant'}
# Gold name = peking restaurant
# Extracted = peking restaurant
# Post-processed extracted = peking restaurant
# Correct
# --------
# Can you tell me where the restaurant Tandoori Palace is located?
# {'restaurant-name': 'tandoori palace'}
# Gold name = tandoori palace
# Extracted = tandoori palace
# Post-processed extracted = tandoori palace
# Correct
# --------
# Yes, I am looking for information for the Kirkwood House. Can you help me?
# {'hotel-name': 'kirkwood house'}
# Gold name = kirkwood house
# Extracted = kirkwood house
# Post-processed extracted = kirkwood house
# Correct
# --------
# Can you help me find a hotel called Limehouse? Thanks.
# {'hotel-name': 'limehouse'}
# Gold name = limehouse
# Extracted = limehouse
# Post-processed extracted = limehouse
# Correct
# --------
# I'm looking for a restaurant named hakka
# {'restaurant-name': 'hakka'}
# Gold name = hakka
# Extracted = hakka
# Post-processed extracted = hakka
# Correct
# --------
# I'm looking for a particular restaurant called j restaurant.
# {'restaurant-name': 'j restaurant'}
# Gold name = j restaurant
# Extracted = j restaurant
# Post-processed extracted = j restaurant
# Correct
# --------
# Greetings! I'm looking for the Worth House, I heard it's in Cambridge.
# {'hotel-name': 'worth house'}
# Gold name = worth house
# Extracted = worth house
# Post-processed extracted = worth house
# Correct
# --------
# There's a place I've heard of that I'm looking for more details. Warkworth House. Do you know of it?
# {'hotel-name': 'warkworth house'}
# Gold name = warkworth house
# Extracted = warkworth house
# Post-processed extracted = warkworth house
# Correct
# --------
# Can you help me find a restaurant i am looking for? Its name is the Rice Boat.
# {'restaurant-name': 'rice boat'}
# Gold name = rice boat
# Extracted = rice boat
# Post-processed extracted = rice boat
# Correct
# --------
# Hi, could you help me find out more information about Panahar restaurant in your area?
# {'restaurant-name': 'panahar'}
# Gold name = panahar
# Extracted = panahar
# Post-processed extracted = panahar
# Correct
# --------
# Yes I am looking for information on a hotel called City Center North B and B.
# {'hotel-name': 'city centre north b and b'}
# Gold name = city centre north b and b
# Extracted = city center north b and b
# Post-processed extracted = city center north b and b
# --------
# I am looking for a hotel called the alpha-milton guest house.
# {'hotel-name': 'alpha-milton guest house'}
# Gold name = alpha-milton guest house
# Extracted = alpha-milton guest house
# Post-processed extracted = alpha-milton guest house
# Correct
# --------
# Where is Finches Bed and Breakfast located?
# {'hotel-name': 'finches bed and breakfast'}
# Gold name = finches bed and breakfast
# Extracted = finches
# Post-processed extracted = finches
# --------
# I'm hoping to find Rosa's Bed and Breakfast.
# {'hotel-name': 'rosas bed and breakfast'}
# Gold name = rosas bed and breakfast
# Extracted = rosa's bed and breakfast
# Post-processed extracted = rosa bed and breakfast
# --------
# I need information on a restaurant called saffron brasserie please.
# {'restaurant-name': 'saffron brasserie'}
# Gold name = saffron brasserie
# Extracted = saffron brasserie
# Post-processed extracted = saffron brasserie
# Correct
# --------
# I would like to book at room at alexander bed and breakfast
# {'hotel-name': 'alexander bed and breakfast'}
# Gold name = alexander bed and breakfast
# Extracted = alexander
# Post-processed extracted = alexander
# --------
# Is the travellers rest restaurant still open?
# {'restaurant-name': 'travellers rest'}
# Gold name = travellers rest
# Extracted = travellers rest restaurant
# Post-processed extracted = travellers rest restaurant
# --------
# I want to book the Archway House in Cambridge.
# {'hotel-name': 'archway house'}
# Gold name = archway house
# Extracted = archway house
# Post-processed extracted = archway house
# Correct
# --------
# I am looking for a restaurant called curry garden.
# {'restaurant-name': 'curry garden'}
# Gold name = curry garden
# Extracted = curry garden
# Post-processed extracted = curry garden
# Correct
# --------
# I am looking for a particular restaurant. Its name is called cafe uno.
# {'restaurant-name': 'cafe uno'}
# Gold name = cafe uno
# Extracted = cafe uno
# Post-processed extracted = cafe uno
# Correct
# --------
# I am looking for ALexeander b&b.
# {'hotel-name': 'alexeander b&b'}
# Gold name = alexeander b&b
# Extracted = alexeander
# Post-processed extracted = alexeander
# --------
# Hi, I am looking for a restaurant called nandos city centre.
# {'restaurant-name': 'nandos city centre'}
# Gold name = nandos city centre
# Extracted = nandos city centre
# Post-processed extracted = nandos city centre
# Correct
# --------
# I want some information on the university arms hotel please
# {'hotel-name': 'university arms hotel', 'hotel-parking': 'yes', 'hotel-stars': '4'}
# Gold name = university arms hotel
# Extracted = university arms hotel
# Post-processed extracted = university arms hotel
# Correct
# --------
# I'm looking for a hotel called warkworth house
# {'hotel-name': 'warkworth house'}
# Gold name = warkworth house
# Extracted = warkworth house
# Post-processed extracted = warkworth house
# Correct
# --------
# I am looking for information on the Warkworth House.
# {'hotel-name': 'warkworth house'}
# Gold name = warkworth house
# Extracted = warkworth house
# Post-processed extracted = warkworth house
# Correct
# --------
# I was told about a great place to eat called the copper kettle.
# {'restaurant-name': 'copper kettle'}
# Gold name = copper kettle
# Extracted = copper kettle
# Post-processed extracted = copper kettle
# Correct
# --------
# I'm looking for a restaurant called Loch Fyne. Can you tell me a bit about it?
# {'restaurant-name': 'loch fyne'}
# Gold name = loch fyne
# Extracted = loch fyne
# Post-processed extracted = loch fyne
# Correct
# --------
# I am looking for a restaurant called Cocum.
# {'restaurant-name': 'cocum'}
# Gold name = cocum
# Extracted = cocum
# Post-processed extracted = cocum
# Correct
# --------
# I'm looking for some information on a restaurant called the varsity restaurant.
# {'restaurant-name': 'the varsity restaurant'}
# Gold name = the varsity restaurant
# Extracted = varsity restaurant
# Post-processed extracted = varsity restaurant
# --------
# Can you tell me some info on the Avalon hotel?
# {'hotel-name': 'avalon'}
# Gold name = avalon
# Extracted = avalon hotel
# Post-processed extracted = avalon hotel
# --------
# I am looking for information on the hamilton lodge hotel.
# {'hotel-name': 'hamilton lodge'}
# Gold name = hamilton lodge
# Extracted = hamilton lodge hotel
# Post-processed extracted = hamilton lodge hotel
# --------
# I am looking for the address and phone number for the Backstreet Bistro please.
# {'restaurant-name': 'backstreet bistro'}
# Gold name = backstreet bistro
# Extracted = backstreet bistro
# Post-processed extracted = backstreet bistro
# Correct
# --------
# I need to get some information on a restaurant named eraina
# {'restaurant-name': 'eraina'}
# Gold name = eraina
# Extracted = eraina
# Post-processed extracted = eraina
# Correct
# --------
# Can you tell me about the Carolina B&B?
# {'hotel-name': 'carolina b&b'}
# Gold name = carolina b&b
# Extracted = carolina b&b
# Post-processed extracted = carolina b&b
# Correct
# --------
# I need information to find the huntingdon marriott hotel.
# {'hotel-name': 'huntingdon marriott hotel'}
# Gold name = huntingdon marriott hotel
# Extracted = huntingdon marriott hotel
# Post-processed extracted = huntingdon marriott hotel
# Correct
# --------
# I'd like some information on a restaurant called Kymmoy, please.
# {'restaurant-name': 'kymmoy'}
# Gold name = kymmoy
# Extracted = kymmoy
# Post-processed extracted = kymmoy
# Correct
# --------
# i'm looking for university arms hotel
# {'hotel-name': 'university arms hotel'}
# Gold name = university arms hotel
# Extracted = university arms hotel
# Post-processed extracted = university arms hotel
# Correct
# --------
# I'm looking for some info on a hotel called the cambrdige belfry.
# {'hotel-name': 'cambridge belfry'}
# Gold name = cambridge belfry
# Extracted = cambrdige belfry
# Post-processed extracted = cambrdige belfry
# --------
# Hi! I am attempting to find a restaurant in Cambridge called Traveller's Rest. Do you know of it?
# {'restaurant-name': 'travellers rest'}
# Gold name = travellers rest
# Extracted = traveller's rest
# Post-processed extracted = traveller rest
# --------
# Yes can you tell me something about the Cow Pizza Kitchen and Bar?
# {'restaurant-name': 'the cow pizza kitchen and bar'}
# Gold name = the cow pizza kitchen and bar
# Extracted = cow pizza kitchen
# Post-processed extracted = cow pizza kitchen
# --------
# Hi I am looking to get some info on the aylesbray lodge guest house
# {'hotel-name': 'aylesbray lodge guest house'}
# Gold name = aylesbray lodge guest house
# Extracted = aylesbray lodge
# Post-processed extracted = aylesbray lodge
# --------
# I am looking for a hotel called Warkworth House.
# {'hotel-name': 'warkworth house'}
# Gold name = warkworth house
# Extracted = warkworth house
# Post-processed extracted = warkworth house
# Correct
# --------
# Hi, can you help me locate a hotel named City Centre B and B. Really looking forward to trying different restaurants.
# {'hotel-name': 'city centre north b and b'}
# Gold name = city centre north b and b
# Extracted = city centre b and b
# Post-processed extracted = city centre b and b
# --------
# Can you give me some information on the Alpha Milton guesthouse?
# {'hotel-area': 'north', 'hotel-name': 'alpha-milton guest house'}
# Gold name = alpha-milton guest house
# Extracted = alpha milton
# Post-processed extracted = alpha milton
# --------
# Where can I find the galleria restaurant?
# {'restaurant-name': 'galleria'}
# Gold name = galleria
# Extracted = galleria
# Post-processed extracted = galleria
# Correct
# --------
# Have you ever heard of the hotel Avalon?
# {'hotel-name': 'avalon'}
# Gold name = avalon
# Extracted = avalon
# Post-processed extracted = avalon
# Correct
# --------
# I am looking for a restaurant called the Slug and Lettuce.
# {'restaurant-name': 'slug and lettuce'}
# Gold name = slug and lettuce
# Extracted = slug and lettuce
# Post-processed extracted = slug and lettuce
# Correct
# --------
# Hi, I am planning a trip. Have you heard of a particular hotel? I think it is called the Carolina Bed and Breakfast.
# {'hotel-name': 'carolina bed and breakfast'}
# Gold name = carolina bed and breakfast
# Extracted = carolina bed and breakfast
# Post-processed extracted = carolina bed and breakfast
# Correct
# --------
# Can you help me with some information on a restaurant called luca cucina and bar?
# {'restaurant-name': 'luca cucina and bar'}
# Gold name = luca cucina and bar
# Extracted = luca cucina and bar
# Post-processed extracted = luca cucina and bar
# Correct
# --------
# I have heard a lot of good things about the Arbury Lodge Guesthouse. Would you be able to provide any information on them?
# {'hotel-name': 'arbury lodge guesthouse', 'hotel-type': 'guesthouse'}
# Gold name = arbury lodge guesthouse
# Extracted = arbury lodge guesthouse
# Post-processed extracted = arbury lodge guesthouse
# Correct
# --------
# I'm looking for information on the Autumn House. Can you help me out?
# {'hotel-name': 'autumn house'}
# Gold name = autumn house
# Extracted = autumn house
# Post-processed extracted = autumn house
# Correct
# --------
# I'm looking for a cheap restaurant that serves modern european food.
# {'restaurant-food': 'modern european', 'restaurant-name': 'dontcare', 'restaurant-pricerange': 'cheap'}
# Gold name = dontcare
# Extracted = cheap restaurant
# Post-processed extracted = cheap restaurant
# --------
# Hello, I am looking for a certain hotel in Cambridge called the autumn house.
# {'hotel-name': 'autumn house'}
# Gold name = autumn house
# Extracted = the autumn house
# ...
# {'restaurant-name': 'dojo noodle bar'}
# Gold name = dojo noodle bar
# Extracted = dojo noodle bar
# Post-processed extracted = dojo noodle bar
# Correct
# --------
# Can you please help me get information on cityroomz?
# {'hotel-name': 'cityroomz'}
# Gold name = cityroomz
# Extracted = cityroomz
# Post-processed extracted = cityroomz
# Correct
# --------
# Hello, I'm planning a trip to Cambridge and looking to make a reservation at a restaurant called the "Royal Standard". Can you get me the information for that restaurant please?
# {'restaurant-name': 'royal standard'}
# Gold name = royal standard
# Extracted = royal standard
# Post-processed extracted = royal standard
# Correct
# --------
# Yeah, what can you tell me about Archway House?
# {'hotel-name': 'archway house'}
# Gold name = archway house
# Extracted = archway house
# Post-processed extracted = archway house
# Correct
# --------
# Hi, I'm looking for information on a particular restaurant called Galleria.
# {'restaurant-name': 'galleria'}
# Gold name = galleria
# Extracted = galleria
# Post-processed extracted = galleria
# Correct
# --------
# I am looking fot a hotel, Allenbell.
# {'hotel-name': 'allenbell'}
# Gold name = allenbell
# Extracted = allenbell
# Post-processed extracted = allenbell
# Correct
# --------
# I am looking to eat at Rajmahal.
# {'restaurant-name': 'rajmahal'}
# Gold name = rajmahal
# Extracted = rajmahal
# Post-processed extracted = rajmahal
# Correct
# --------
# I am in Cambridge and would like to try the restaurant City Stop Restaurant.
# {'restaurant-name': 'city stop restaurant'}
# Gold name = city stop restaurant
# Extracted = city stop restaurant
# Post-processed extracted = city stop restaurant
# Correct
# --------
# I'm looking for a hotel called the autumn house, can you give me some information about it?
# {'hotel-name': 'autumn house'}
# Gold name = autumn house
# Extracted = the autumn house
# Post-processed extracted = the autumn house
# --------
# I would like to get information on the bridge guest house.
# {'hotel-name': 'bridge guest house'}
# Gold name = bridge guest house
# Extracted = bridge guest house
# Post-processed extracted = bridge guest house
# Correct
# --------
# Hello, what can you tell me about de luca cucina and bar?
# {'restaurant-name': 'de luca cucina and bar'}
# Gold name = de luca cucina and bar
# Extracted = de luca cucina and bar
# Post-processed extracted = de luca cucina and bar
# Correct
# --------
# Hello, I am looking for a restaurant called hotel du vin bistro.
# {'restaurant-name': 'hotel du vin and bistro'}
# Gold name = hotel du vin and bistro
# Extracted = hotel du vin bistro
# Post-processed extracted = hotel du vin bistro
# --------
# Hello, I would like to find the el shaddai hotel. Can you help me?
# {'hotel-name': 'el shaddai'}
# Gold name = el shaddai
# Extracted = el shaddai hotel
# Post-processed extracted = el shaddai hotel
# --------
# Yes, I am searching for a hotel named the Aylesbray Lodge Guest House?
# {'hotel-name': 'aylesbray lodge guest house'}
# Gold name = aylesbray lodge guest house
# Extracted = aylesbray lodge guest house
# Post-processed extracted = aylesbray lodge guest house
# Correct
# --------
# Can you help me find Restaurant One Seven?
# {'restaurant-name': 'restaurant one seven'}
# Gold name = restaurant one seven
# Extracted = restaurant one seven
# Post-processed extracted = restaurant one seven
# Correct
# --------
# I am looking for the restaurant Nandos.
# {'restaurant-area': 'dontcare', 'restaurant-name': 'nandos'}
# Gold name = nandos
# Extracted = nandos
# Post-processed extracted = nandos
# Correct
# --------
# Hello. I am looking for a hotel called gonville hotel.
# {'hotel-name': 'gonville hotel'}
# Gold name = gonville hotel
# Extracted = gonville hotel
# Post-processed extracted = gonville hotel
# Correct
# --------
# Hi there. Can you tell me if you have any information on the Bridge Guest House?
# {'hotel-name': 'bridge guest house'}
# Gold name = bridge guest house
# Extracted = bridge guest house
# Post-processed extracted = bridge guest house
# Correct
# --------
# Hi, where can I find the Autumn House hotel?
# {'hotel-name': 'autumn house'}
# Gold name = autumn house
# Extracted = autumn house
# Post-processed extracted = autumn house
# Correct
# --------
# Hi, I'm looking for a hotel called Leverton House.
# {'hotel-name': 'leverton house'}
# Gold name = leverton house
# Extracted = leverton house
# Post-processed extracted = leverton house
# Correct
# --------
# I want the address to the Autumn House hotel in Cambridge.
# {'hotel-name': 'autumn house'}
# Gold name = autumn house
# Extracted = autumn house
# Post-processed extracted = autumn house
# Correct
# --------
# I want to find some information about a hotel called alexander bed and breakfast.
# {'hotel-name': 'alexander bed and breakfast'}
# Gold name = alexander bed and breakfast
# Extracted = alexander bed and breakfast
# Post-processed extracted = alexander bed and breakfast
# Correct
# --------
# I'm looking for information on a restaurant called La Margherita.
# {'restaurant-name': 'la margherita'}
# Gold name = la margherita
# Extracted = la margherita
# Post-processed extracted = la margherita
# Correct
# --------
# I want to find some information on da vinci pizzeria
# {'restaurant-name': 'da vinci pizzeria'}
# Gold name = da vinci pizzeria
# Extracted = da vinci pizzeria
# Post-processed extracted = da vinci pizzeria
# Correct
# --------
# I'm looking for a particular restaurant. Its name is called rice boat.
# {'restaurant-name': 'rice boat'}
# Gold name = rice boat
# Extracted = rice boat
# Post-processed extracted = rice boat
# Correct
# --------
# I'm looking for a particular restaurant. Its name is called panahar.
# {'restaurant-name': 'panahar'}
# Gold name = panahar
# Extracted = panahar
# Post-processed extracted = panahar
# Correct
# --------
# I'm trying to find a hotel called Worth House. Can you help me?
# {'hotel-name': 'worth house'}
# Gold name = worth house
# Extracted = worth house
# Post-processed extracted = worth house
# Correct
# --------
# I'm looking for the hotel called Kirkwood House.
# {'hotel-name': 'kirkwood house'}
# Gold name = kirkwood house
# Extracted = kirkwood house
# Post-processed extracted = kirkwood house
# Correct
# --------
# I would like to book a reservation at the cambridge lodge restaurant
# {'restaurant-name': 'cambridge lodge restaurant'}
# Gold name = cambridge lodge restaurant
# Extracted = cambridge lodge restaurant
# Post-processed extracted = cambridge lodge restaurant
# Correct
# --------
# I'm looking for information about a restaurant named the golden wok.
# {'restaurant-name': 'golden wok'}
# Gold name = golden wok
# Extracted = golden wok
# Post-processed extracted = golden wok
# Correct
# --------
# I'm looking for a hotel called kirkwood house
# {'hotel-name': 'kirkwood house'}
# Gold name = kirkwood house
# Extracted = kirkwood house
# Post-processed extracted = kirkwood house
# Correct
# --------
# I am looking for details on the yu garden restaurant.
# {'restaurant-name': 'yu garden'}
# Gold name = yu garden
# Extracted = yu garden restaurant
# Post-processed extracted = yu garden restaurant
# --------
# I would like to find the Anatolia restaurant please.
# {'restaurant-name': 'anatolia'}
# Gold name = anatolia
# Extracted = anatolia
# Post-processed extracted = anatolia
# Correct
# --------
# Can you get me information on a restaurant called j restaurant?
# {'restaurant-name': 'j restaurant'}
# Gold name = j restaurant
# Extracted = j restaurant
# Post-processed extracted = j restaurant
# Correct
# --------
# I am looking for a hotel, the Alpha-Milton Guest House.
# {'hotel-name': 'alpha-milton guest house'}
# Gold name = alpha-milton guest house
# Extracted = alpha-milton guest house
# Post-processed extracted = alpha-milton guest house
# Correct
# --------
# Can you get me information on a place called kymmoy?
# {'restaurant-name': 'kymmoy'}
# Gold name = kymmoy
# Extracted = kymmoy
# Post-processed extracted = kymmoy
# Correct
# --------
# I would like some information on the gonville hotel
# {'hotel-name': 'gonville hotel'}
# Gold name = gonville hotel
# Extracted = gonville hotel
# Post-processed extracted = gonville hotel
# Correct
# --------
# Can you help direct me a restaurant called Golden House?
# {'restaurant-name': 'golden house'}
# Gold name = golden house
# Extracted = golden house
# Post-processed extracted = golden house
# Correct
# --------
# I am looking for more information regarding the cambridge chop house.
# {'restaurant-name': 'cambridge chop house'}
# Gold name = cambridge chop house
# Extracted = cambridge chop house
# Post-processed extracted = cambridge chop house
# Correct
# --------
# I'd like more information about the Ashley Hotel, can you help?
# {'hotel-name': 'ashley hotel'}
# Gold name = ashley hotel
# Extracted = ashley hotel
# Post-processed extracted = ashley hotel
# Correct
# --------
# Need a restaurant called the golden curry
# {'restaurant-name': 'golden curry'}
# Gold name = golden curry
# Extracted = golden curry
# Post-processed extracted = golden curry
# Correct
# --------
# I'm looking for information on a hotel called alexander bed and breakfast.
# {'hotel-name': 'alexander bed and breakfast'}
# Gold name = alexander bed and breakfast
# Extracted = alexander bed and breakfast
# Post-processed extracted = alexander bed and breakfast
# Correct
# --------
# I'm looking for a restaurant called the copper kettle.
# {'restaurant-name': 'copper kettle'}
# Gold name = copper kettle
# Extracted = copper kettle
# Post-processed extracted = copper kettle
# Correct
# --------
# Hi there. I was wondering if you could provide some information on the Bridge Guest House hotel.
# {'hotel-name': 'bridge guest house'}
# Gold name = bridge guest house
# Extracted = bridge guest house hotel
# Post-processed extracted = bridge guest house hotel
# --------
# I'm looking for a certain hotel called the cityroomz. Can you tell me more about it?
# {'hotel-name': 'cityroomz'}
# Gold name = cityroomz
# Extracted = cityroomz
# Post-processed extracted = cityroomz
# Correct
# --------
# Hi I am looking for a hotel called limehouse.
# {'hotel-name': 'limehouse'}
# Gold name = limehouse
# Extracted = limehouse
# Post-processed extracted = limehouse
# Correct
# --------
# I am looking for a place called stazione restaurant and coffee bar. Can you help me?
# {'restaurant-name': 'stazione restaurant and coffee bar'}
# Gold name = stazione restaurant and coffee bar
# Extracted = stazione restaurant and coffee bar
# Post-processed extracted = stazione restaurant and coffee bar
# Correct
# --------
# I am looking for a hotel called finches bed and breakfast.
# {'hotel-name': 'finches bed and breakfast'}
# Gold name = finches bed and breakfast
# Extracted = finches bed and breakfast
# Post-processed extracted = finches bed and breakfast
# Correct
# --------
# Hello, I'd like some information about a hotel called the hamilton lodge, please.
# {'hotel-name': 'hamilton lodge'}
# Gold name = hamilton lodge
# Extracted = hamilton lodge
# Post-processed extracted = hamilton lodge
# Correct
# --------
# I want information on a particular hotel called home from home. Can you send me what you have on that?
# {'hotel-name': 'home from home'}
# Gold name = home from home
# Extracted = home from home
# Post-processed extracted = home from home
# Correct
# --------
# I don't know if you've heard of it but can you please get me some information on the la tasca restaurant?
# {'restaurant-name': 'la tasca'}
# Gold name = la tasca
# Extracted = la tasca restaurant
# Post-processed extracted = la tasca restaurant
# --------
# I'm looking for a restaurant called little seoul?
# {'restaurant-name': 'little seoul'}
# Gold name = little seoul
# Extracted = little seoul
# Post-processed extracted = little seoul
# Correct
# --------
# Can you find a hotel by the name of Leverton House?
# {'hotel-name': 'leverton house'}
# Gold name = leverton house
# Extracted = leverton house
# Post-processed extracted = leverton house
# Correct
# --------
# I'm looking for a restaurant called ask. Do you know of it?
# {'restaurant-name': 'ask'}
# Gold name = ask
# Extracted = ask
# Post-processed extracted = ask
# Correct
# --------
# Hey, I'm trying to find a restaurant called Taj Tandoori. What do you know about that?
# {'restaurant-name': 'taj tandoori'}
# Gold name = taj tandoori
# Extracted = taj tandoori
# Post-processed extracted = taj tandoori
# Correct
# --------
# Please find a restaurant called Galleria.
# {'restaurant-name': 'galleria'}
# Gold name = galleria
# Extracted = galleria
# Post-processed extracted = galleria
# Correct
# --------
# While in Cambridge I would really like to know where to find a place to eat called meghna.
# {'restaurant-name': 'meghna'}
# Gold name = meghna
# Extracted = meghna
# Post-processed extracted = meghna
# Correct
# --------
# Hello, I am looking for information on a restaurant name Rice House.
# {'restaurant-name': 'rice house'}
# Gold name = rice house
# Extracted = rice house
# Post-processed extracted = rice house
# Correct
# --------
# I am looking for a restaurant called shanghai family restaurant.
# {'restaurant-name': 'shanghai family restaurant'}
# Gold name = shanghai family restaurant
# Extracted = shanghai family restaurant
# Post-processed extracted = shanghai family restaurant
# Correct
# --------
# Find me a place called maharajah tandoori restaurant, please
# {'restaurant-name': 'maharajah tandoori restaurant'}
# Gold name = maharajah tandoori restaurant
# Extracted = maharajah tandoori restaurant
# Post-processed extracted = maharajah tandoori restaurant
# Correct
# --------
# I'm looking for a hotel called avalon.
# {'hotel-name': 'avalon'}
# Gold name = avalon
# Extracted = avalon
# Post-processed extracted = avalon
# Correct
# --------
# Could you help me find Cityroomz, please?
# {'hotel-name': 'cityroomz'}
# Gold name = cityroomz
# Extracted = cityroomz
# Post-processed extracted = cityroomz
# Correct
# --------
# I am looking for some info on India House
# {'restaurant-area': 'dontcare', 'restaurant-food': 'dontcare', 'restaurant-name': 'india house', 'restaurant-pricerange': 'dontcare'}
# Gold name = india house
# Extracted = india house
# Post-processed extracted = india house
# Correct
# --------
# Can you get me information on a hotel called cityroomz?
# {'hotel-name': 'cityroomz'}
# Gold name = cityroomz
# Extracted = cityroomz
# Post-processed extracted = cityroomz
# Correct
# --------
# While I am visiting Cambridge, I would like to stay at the Ashley Hotel. Where is it located?
# {'hotel-name': 'ashley hotel'}
# Gold name = ashley hotel
# Extracted = ashley hotel
# Post-processed extracted = ashley hotel
# Correct
# --------
# I've heard good things about the Acorn guest house. Could you find it for me?
# {'hotel-name': 'acorn guest house'}
# Gold name = acorn guest house
# Extracted = acorn
# Post-processed extracted = acorn
# --------
# I am looking for a restaurant called thanh binh in Cambridge.
# {'restaurant-name': 'thanh binh'}
# Gold name = thanh binh
# Extracted = thanh binh
# Post-processed extracted = thanh binh
# Correct
# --------
# I am looking for information on a hotel called Carolina Bed and Breakfast.
# {'hotel-name': 'carolina bed and breakfast'}
# Gold name = carolina bed and breakfast
# Extracted = carolina bed and breakfast
# Post-processed extracted = carolina bed and breakfast
# Correct
# --------
# I am looking for the price range of the hotel Finches bed and breakfast.
# {'hotel-name': 'finches bed and breakfast'}
# Gold name = finches bed and breakfast
# Extracted = finches
# Post-processed extracted = finches
# --------
# What can you tell me about the bangkok city restaurant?
# {'restaurant-name': 'bangkok city'}
# Gold name = bangkok city
# Extracted = bangkok city restaurant
# Post-processed extracted = bangkok city restaurant
# --------
# I'm looking for information on a hotel called the lensfield hotel.
# {'hotel-name': 'lensfield hotel'}
# Gold name = lensfield hotel
# Extracted = lensfield hotel
# Post-processed extracted = lensfield hotel
# Correct
# --------
# Hello. I would like some information about the Aylesbray lodge guest house.
# {'hotel-name': 'aylesbray lodge guest house'}
# Gold name = aylesbray lodge guest house
# Extracted = aylesbray
# Post-processed extracted = aylesbray
# --------
# I'm looking for a restaurant my friend recommended, I think she called it the Curry Prince.
# {'restaurant-name': 'curry prince'}
# Gold name = curry prince
# Extracted = curry prince
# Post-processed extracted = curry prince
# Correct
# --------
# Can you find a hotel named Worth House for me? Thanks.
# {'hotel-name': 'worth house'}
# Gold name = worth house
# Extracted = worth house
# Post-processed extracted = worth house
# Correct
# --------
# Completed

# %%
score = correct_count * 100 / max_row
print(f"Accuracy = {score:.1f} %")
# Out:
# Accuracy = 77.3 %

# %%
wrong_preds
# Out:
# [['Heya, can you find me an expensive restaurant with north african food?',
#   'north african',
#   'african'],
#  ["I want something that's moderately priced. Any type of food.",
#   'any type of',
#   'dontcare'],
#  ["I'm looking for a moderate priced place to dine serving modern european food.",
#   'european',
#   'modern european'],
#  ["I'm looking for a restaurant in the centre serving modern european food.",
#   'european',
#   'modern european'],
#  ["I'm so hungry! Can you find me a really great modern european restaurant? Money is no object!",
#   'european',
#   'modern european'],
#  ['Is there a modern European restaurant in the north?',
#   'european',
#   'modern european'],
#  ['AM looking for a place to dine. The restaurant should be in the south and should serve gastropod food.',
#   'gastropod',
#   'gastropub'],
#  ["Hi! I'd like to find a seafood restaurant in the centre of town, please.",
#   'sea',
#   'seafood'],
#  ['im looking for a place that serves morden european food and with a cheap price range',
#   'morden european',
#   'european'],
#  ['I am looking for a cheap modern European restaurant. Can you help me?',
#   'european',
#   'modern european'],
#  ['I am looking for a restaurant serving seafood, in the center of the town.',
#   'sea',
#   'seafood'],
#  ['Could you help me find a restaurant with middle-eastern cuisine?',
#   'middle-eastern',
#   'middle eastern'],
#  ["I'm looking for a restaurant in the center of town that serves food from the americas.",
#   'americas',
#   'the americas'],
#  ['I am looking for a nice bistro in Cambridge, moderately priced would be good.',
#   'cambridge moderately priced would be good',
#   'bistro'],
#  ['I am looking for a restaurant that servers modern european food.',
#   'european',
#   'modern european'],
#  ['Hi, is there a moderately priced international cuisine restaurant in Cambridge?',
#   'international cuisine',
#   'international'],
#  ['Hi, are there any modern global restaurants in the centre?',
#   'global',
#   'modern global'],
#  ['I am looking for a place to eat. I want to eat modern european food in the expensive price range please.',
#   'european',
#   'modern european'],
#  ['I am looking for a restaurant that sell seafood,will prefer one in the center of the city.',
#   'sea',
#   'seafood'],
#  ['We want to try a local restaurant that serves Asian or oriental food.',
#   'asian or oriental',
#   'asian oriental'],
#  ["I'm looking for a gastropub in the east.",
#   'gastropub in the east',
#   'gastropub'],
#  ["I'm looking for unusual and expensive cuisine in the west. Do you have any suggestions?",
#   'west',
#   'unusual'],
#  ["I'm looking for a seafood restaurant in the moderate price range.",
#   'sea',
#   'seafood'],
#  ["Hi, I'm looking for a place to eat, preferably a cheap South Indian restaurant.",
#   'south indian',
#   'indian'],
#  ["Hi, I'm looking for a restaurant that serves Carribbean food. Do you have any like that?",
#   'carribbean',
#   'caribbean'],
#  ['Need a place to eat, modern euro food at the centre.',
#   'modern euro',
#   'modern'],
#  ["Hello! I'm looking for a cheap restaurant that serves modern global food.",
#   'global',
#   'modern global'],
#  ['Hello there. Any suggestions on a good seafood restaurant located in the centre of town?',
#   'sea',
#   'seafood'],
#  ["I'm looking for a cheap restaurant that serves modern european food.",
#   'european',
#   'modern european'],
#  ['Are there any restaurants in town that serve modern american food?',
#   'american',
#   'modern american'],
#  ['I really need to find a restaurant that serves modern european food. An expensive one is fine.',
#   'european',
#   'modern european'],
#  ["I'm looking for a cheap restaurant that serves portugese food.",
#   'portugese',
#   'portuguese'],
#  ["I'm looking for a place to dine in the centre of town that serves modern european food.",
#   'european',
#   'modern european'],
#  ["I'm looking for a modern european restaurant that had a moderate price range.",
#   'european',
#   'modern european'],
#  ["Hi there, I'm hungry. Please help me find a cheap place that serves the americas food",
#   'americas',
#   'the americas'],
#  ["I'm looking for a very nice place to dine. Something expensive.",
#   'expensive',
#   'dontcare'],
#  ['im looking for a place to dine, it should be in the south serving morden global food',
#   'morden global',
#   'global'],
#  ['Are there any crossover restaurants in the west?',
#   'crossover restaurants in the west',
#   'crossover'],
#  ["Hello! I'm looking for a restaurant that serves modern global food in the centre.",
#   'global',
#   'modern global'],
#  ['I am looking for a moderately priced restaurant in the south part of town. Any kind of food is good with me; I would just like to know the phone number of the venue you find.',
#   'any kind of',
#   'dontcare'],
#  ["I'm interested in finding a modern European restaurant for dinner with a moderate price range on their menu.",
#   'european',
#   'modern european'],
#  ["I'm looking for a seafood restaurant in the centre.", 'sea', 'seafood'],
#  ["I'd like to find an expensive gastropub, should you have such a beast.",
#   'gastropub should you have such a beast',
#   'gastropub'],
#  ["Hello, I'm looking for a restaurant that serves mondern european foods for modest prices.",
#   'mondern european',
#   'european'],
#  ["Good eve! I'm looking for a nice place to have a spot of afternoon tea.",
#   'tea',
#   'afternoon tea'],
#  ['I am looking for a modern European restaurant in the moderate range.',
#   'european',
#   'modern european'],
#  ["I'm looking for a modern european restaurant in the centre.",
#   'european',
#   'modern european'],
#  ['Can you help me find a cheapt italian restaurant?',
#   'cheapt italian',
#   'italian'],
#  ["Yes, I'm looking for a restaurant that serves American food and is in the center of town.",
#   'american',
#   'north american'],
#  ['I need a place to eat that serves sea food.', 'sea', 'seafood'],
#  ['Hi , can you recommend an inexpensive seafood restaurant?',
#   'sea',
#   'seafood'],
#  ['Is there any expensive seafood restaurant in town?', 'sea', 'seafood'],
#  ["Hello, I'm looking for a modern european restaurant in the center.",
#   'european',
#   'modern european'],
#  ['I want to find a seafood restaurant in the centre', 'sea', 'seafood'],
#  ["Hi! I'm looking for a cheap restaurant in the north, any type!",
#   'cheap restaurant in the north',
#   'dontcare'],
#  ['Hi, I want to eat at an expensive seafood restaurant in Cambridge. Where can I go?',
#   'sea',
#   'seafood'],
#  ['I need a place for a modern european food. Moderate range ought to do it. Thank you.',
#   'european',
#   'modern european'],
#  ['I am looking for a restaurant in the city center that serves modern European food.',
#   'modern european',
#   'european'],
#  ['I want to find a restaurant in any part of town and serves seafood.',
#   'sea',
#   'seafood'],
#  ['I am looking for some info on India House', 'india house', 'dontcare'],
#  ["Hello, I'm looking for a modern European restaurant. Got any?",
#   'european',
#   'modern european'],
#  ['Find me a place to dine on some cheap foods from the americas please.',
#   'americas',
#   'the americas'],
#  ['Find me a modern european restaurant in the south.',
#   'european',
#   'modern european']]

# %%
# extract food type
def get_food_type(text, nlp_model=model):
    """
        extract the food type from the text
    """
    query = {
    'question': 'What is the food origin?',
    'context': text
    }
    res = nlp_model(query)
    return res["answer"]

s = """I need to find a good vegetarian restaurant"""
get_food_type(s)
# Out:
# 'vegetarian'

# %%
# filter by names
kw2 = 'restaurant-food='
foodtype_df = train_df.query("answer.str.contains(@kw2)")
print(len(names_df))
foodtype_df.reset_index(inplace=True)
foodtype_df.drop(columns=["index"], inplace=True)
foodtype_df.head()
# Out:
# 556
# C:\Users\Minh UBC\AppData\Local\Temp\ipykernel_13880\1904840543.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   foodtype_df.drop(columns=["index"], inplace=True)
#                                                 text  \
# 0  I am looking for a restaurant. I would like so...
# 1        Yeah, could you recommend a good gastropub?
# 2  I want to find an expensive restaurant and ser...
# 3  Where's a good place to eat crossover food in ...
# 4  Can you help me find an expensive Chinese food...
#
#                                               answer           intent  \
# 0  ['find_restaurant', 'restaurant-food=chinese',...  find_restaurant
# 1   ['find_restaurant', 'restaurant-food=gastropub']  find_restaurant
# 2  ['find_restaurant', 'restaurant-food=european'...  find_restaurant
# 3   ['find_restaurant', 'restaurant-food=crossover']  find_restaurant
# 4  ['find_restaurant', 'restaurant-food=chinese',...  find_restaurant
#
#                                                slots  \
# 0  {'restaurant-food': 'chinese', 'restaurant-pri...
# 1                   {'restaurant-food': 'gastropub'}
# 2  {'restaurant-food': 'european', 'restaurant-pr...
# 3                   {'restaurant-food': 'crossover'}
# 4  {'restaurant-food': 'chinese', 'restaurant-pri...
#
#                                           text_lower
# 0  i am looking for a restaurant. i would like so...
# 1        yeah, could you recommend a good gastropub?
# 2  i want to find an expensive restaurant and ser...
# 3  where's a good place to eat crossover food in ...
# 4  can you help me find an expensive chinese food...

# %%
# go through each of the item to analyze and predict name
gold_names = []
sys_names = []
correct_count = 0
wrong_preds = []

n = len(foodtype_df)
max_row = n # set to n for full set
for i in range(max_row):
    item = foodtype_df.iloc[i]

    txt = item["text"]

    print(txt)
    print(item["slots"])
    # extract gold name
    # gold_name = ""
    gold_name = item["slots"].get("restaurant-food", "")
    print("Gold name =", gold_name)
        
    pred_name = get_food_type(txt).lower()
    
    # apply some post-processing (remove 'the', 'restaurant', etc)
    print("Extracted =", pred_name)
    pred_name = (pred_name
                 # .replace("the", "")
                 .replace("food", "")
                 .replace("'s", "")
                 .replace(".", "")
                 .replace(",", "")
                 .strip()
                )
    print("Post-processed extracted =", pred_name)

    if gold_name == pred_name:
        print("Correct")
        correct_count += 1
    else:
        wrong_preds.append([txt, pred_name, gold_name])
    
    print("--------")

print("Completed")
# Out:
# I am looking for a restaurant. I would like something cheap that has Chinese food.
# {'restaurant-food': 'chinese', 'restaurant-pricerange': 'cheap'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# Yeah, could you recommend a good gastropub?
# {'restaurant-food': 'gastropub'}
# Gold name = gastropub
# Extracted = gastropub
# Post-processed extracted = gastropub
# Correct
# --------
# I want to find an expensive restaurant and serves european food. Can i also have the address, phone number and its area. ?
# {'restaurant-food': 'european', 'restaurant-pricerange': 'expensive'}
# Gold name = european
# Extracted = european
# Post-processed extracted = european
# Correct
# --------
# Where's a good place to eat crossover food in Cambridge?
# {'restaurant-food': 'crossover'}
# Gold name = crossover
# Extracted = crossover food
# Post-processed extracted = crossover
# Correct
# --------
# Can you help me find an expensive Chinese food restaurant?
# {'restaurant-food': 'chinese', 'restaurant-pricerange': 'expensive'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# I'm looking to go to dinner tonight and am in the mood for some good Bistro in the centre of town, can you find me some options?
# {'restaurant-area': 'centre', 'restaurant-food': 'bistro'}
# Gold name = bistro
# Extracted = bistro
# Post-processed extracted = bistro
# Correct
# --------
# Heya, can you find me an expensive restaurant with north african food?
# {'restaurant-food': 'african', 'restaurant-pricerange': 'expensive'}
# Gold name = african
# Extracted = north african
# Post-processed extracted = north african
# --------
# I would like inexpensive Turkish food.
# {'restaurant-food': 'turkish', 'restaurant-pricerange': 'cheap'}
# Gold name = turkish
# Extracted = turkish
# Post-processed extracted = turkish
# Correct
# --------
# I would like a restaurant that serves world food
# {'restaurant-food': 'world'}
# Gold name = world
# Extracted = world
# Post-processed extracted = world
# Correct
# --------
# I need a South restaurant with british food.
# {'restaurant-area': 'south', 'restaurant-food': 'british'}
# Gold name = british
# Extracted = british
# Post-processed extracted = british
# Correct
# --------
# Are you able to find me a french expensive restaurant?
# {'restaurant-food': 'french', 'restaurant-pricerange': 'expensive'}
# Gold name = french
# Extracted = french
# Post-processed extracted = french
# Correct
# --------
# Good morning, I need help finding a restaurant that serves bistro in the moderate price range.
# {'restaurant-food': 'bistro', 'restaurant-pricerange': 'moderate'}
# Gold name = bistro
# Extracted = bistro
# Post-processed extracted = bistro
# Correct
# --------
# Is there any place here in the centre that serves corsica food?
# {'restaurant-area': 'centre', 'restaurant-food': 'corsica'}
# Gold name = corsica
# Extracted = corsica
# Post-processed extracted = corsica
# Correct
# --------
# I am looking for a cheap restaurant that serves Scandinavian food
# {'restaurant-food': 'scandinavian', 'restaurant-pricerange': 'cheap'}
# Gold name = scandinavian
# Extracted = scandinavian
# Post-processed extracted = scandinavian
# Correct
# --------
# I'm looking for a restaurant that serves international food.
# {'restaurant-food': 'international'}
# Gold name = international
# Extracted = international
# Post-processed extracted = international
# Correct
# --------
# I want to find a restaurant in the east part of town. It serves chinese food. What is the address, phone number, and postcode?
# {'restaurant-area': 'east', 'restaurant-food': 'chinese'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# I want to eat at an expensive gastropub restaurant
# {'restaurant-food': 'gastropub', 'restaurant-pricerange': 'expensive'}
# Gold name = gastropub
# Extracted = gastropub
# Post-processed extracted = gastropub
# Correct
# --------
# I want something that's moderately priced. Any type of food.
# {'restaurant-food': 'dontcare', 'restaurant-pricerange': 'moderate'}
# Gold name = dontcare
# Extracted = any type of food
# Post-processed extracted = any type of
# --------
# Hello, I am looking for a restaurant that serves Portuguese food.
# {'restaurant-food': 'portuguese'}
# Gold name = portuguese
# Extracted = portuguese
# Post-processed extracted = portuguese
# Correct
# --------
# I am looking for a French restaurant.
# {'restaurant-food': 'french'}
# Gold name = french
# Extracted = french
# Post-processed extracted = french
# Correct
# --------
# I'm looking for a cheap portuguese restaurant
# {'restaurant-food': 'portuguese', 'restaurant-pricerange': 'cheap'}
# Gold name = portuguese
# Extracted = portuguese
# Post-processed extracted = portuguese
# Correct
# --------
# I'm looking for some cheap Chinese food. Got any restaurants that fit the bill?
# {'restaurant-food': 'chinese', 'restaurant-pricerange': 'cheap'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# I'm looking for an indonesian restaurant that's moderate in price.
# {'restaurant-food': 'indonesian', 'restaurant-pricerange': 'moderate'}
# Gold name = indonesian
# Extracted = indonesian
# Post-processed extracted = indonesian
# Correct
# --------
# I'm in the mood for some modern eclectic food so please find me a cheap restaurant that sells some
# {'restaurant-food': 'modern eclectic', 'restaurant-pricerange': 'cheap'}
# Gold name = modern eclectic
# Extracted = modern eclectic
# Post-processed extracted = modern eclectic
# Correct
# --------
# I'm looking for an inexpensive African restaurant.
# {'restaurant-food': 'african', 'restaurant-pricerange': 'cheap'}
# Gold name = african
# Extracted = african
# Post-processed extracted = african
# Correct
# --------
# Is there a cheap restaurant serving belgian food?
# {'restaurant-food': 'belgian', 'restaurant-pricerange': 'cheap'}
# Gold name = belgian
# Extracted = belgian
# Post-processed extracted = belgian
# Correct
# --------
# Can you find me a moderately priced chinese restaurant please
# {'restaurant-food': 'chinese', 'restaurant-pricerange': 'moderate'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# I would like a restaurant in any area that serves scandinavian food
# {'restaurant-area': 'dontcare', 'restaurant-food': 'scandinavian'}
# Gold name = scandinavian
# Extracted = scandinavian
# Post-processed extracted = scandinavian
# Correct
# --------
# Hello, I am looking for a place to dine. I'd prefer it to be moderately priced and serve Indian food.
# {'restaurant-food': 'indian', 'restaurant-pricerange': 'moderate'}
# Gold name = indian
# Extracted = indian
# Post-processed extracted = indian
# Correct
# --------
# Would you be able to suggest a steakhouse restaurant in Cambridge?
# {'restaurant-food': 'steakhouse'}
# Gold name = steakhouse
# Extracted = steakhouse
# Post-processed extracted = steakhouse
# Correct
# --------
# I'm looking for a moderate priced place to dine serving modern european food.
# {'restaurant-food': 'modern european', 'restaurant-pricerange': 'moderate'}
# Gold name = modern european
# Extracted = european
# Post-processed extracted = european
# --------
# I want to find a restaurant in the centre part of town and serves british food.
# {'restaurant-area': 'centre', 'restaurant-food': 'british'}
# Gold name = british
# Extracted = british
# Post-processed extracted = british
# Correct
# --------
# I need the address of a restaurant that serves gastropub food.
# {'restaurant-food': 'gastropub'}
# Gold name = gastropub
# Extracted = gastropub
# Post-processed extracted = gastropub
# Correct
# --------
# Hello. I'm trying to find a restaurant that serves Swiss food. Can you recommend anything to me?
# {'restaurant-food': 'swiss'}
# Gold name = swiss
# Extracted = swiss
# Post-processed extracted = swiss
# Correct
# --------
# I want to dine at an expensive asian oriental food restaurant.
# {'restaurant-food': 'asian oriental', 'restaurant-pricerange': 'expensive'}
# Gold name = asian oriental
# Extracted = asian oriental
# Post-processed extracted = asian oriental
# Correct
# --------
# Yes, I'm looking for a Cuban restaurant in the Centre.
# {'restaurant-area': 'centre', 'restaurant-food': 'cuban'}
# Gold name = cuban
# Extracted = cuban
# Post-processed extracted = cuban
# Correct
# --------
# I am looking for a place to eat that's expensive and serves Belgian food.
# {'restaurant-food': 'belgian', 'restaurant-pricerange': 'expensive'}
# Gold name = belgian
# Extracted = belgian
# Post-processed extracted = belgian
# Correct
# --------
# I'm looking for a restaurant in the centre serving modern european food.
# {'restaurant-area': 'centre', 'restaurant-food': 'modern european'}
# Gold name = modern european
# Extracted = european
# Post-processed extracted = european
# --------
# Hi, can you point me to an expensive restaurant that serves Italian food? I will be in the area soon.
# {'restaurant-food': 'italian', 'restaurant-pricerange': 'expensive'}
# Gold name = italian
# Extracted = italian
# Post-processed extracted = italian
# Correct
# --------
# I need to place to eat, say, in the center of the town with some creative food.
# {'restaurant-area': 'centre', 'restaurant-food': 'creative'}
# Gold name = creative
# Extracted = creative food
# Post-processed extracted = creative
# Correct
# --------
# I'm so hungry! Can you find me a really great modern european restaurant? Money is no object!
# {'restaurant-food': 'modern european'}
# Gold name = modern european
# Extracted = european
# Post-processed extracted = european
# --------
# I am looking for an upscale Chinese food restaurant in Cambridge; can you make a recommendation?
# {'restaurant-food': 'chinese', 'restaurant-pricerange': 'expensive'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# I want to find a German restaurant please that's in the cheap price range.
# {'restaurant-food': 'german', 'restaurant-pricerange': 'cheap'}
# Gold name = german
# Extracted = german
# Post-processed extracted = german
# Correct
# --------
# We would like to eat some Japanese food while we are visiting.
# {'restaurant-food': 'japanese'}
# Gold name = japanese
# Extracted = japanese
# Post-processed extracted = japanese
# Correct
# --------
# I'm looking for asian oriental food in expensive range.
# {'restaurant-food': 'asian oriental', 'restaurant-pricerange': 'expensive'}
# Gold name = asian oriental
# Extracted = asian oriental
# Post-processed extracted = asian oriental
# Correct
# --------
# I am looking for a restaurant in the expensive price range. It should serve Sri Lankan food.
# {'restaurant-food': 'sri lankan', 'restaurant-pricerange': 'expensive'}
# Gold name = sri lankan
# Extracted = sri lankan
# Post-processed extracted = sri lankan
# Correct
# --------
# I am looking for a restaurant in the south part of town that serves Jamaican food.
# {'restaurant-area': 'south', 'restaurant-food': 'jamaican'}
# Gold name = jamaican
# Extracted = jamaican
# Post-processed extracted = jamaican
# Correct
# --------
# I want to find a restaurant in the north part of town and serves international food.
# {'restaurant-area': 'north', 'restaurant-food': 'international'}
# Gold name = international
# Extracted = international
# Post-processed extracted = international
# Correct
# --------
# Please find me a corsica restaurant.
# {'restaurant-food': 'corsica'}
# Gold name = corsica
# Extracted = corsica
# Post-processed extracted = corsica
# Correct
# --------
# I would like a restaurant in the north part of town that serves korean food
# {'restaurant-area': 'north', 'restaurant-food': 'korean'}
# Gold name = korean
# Extracted = korean
# Post-processed extracted = korean
# Correct
# --------
# I want to find out if there are any places to dine that serve Australian food in the centre.
# {'restaurant-area': 'centre', 'restaurant-food': 'australian'}
# Gold name = australian
# Extracted = australian
# Post-processed extracted = australian
# Correct
# --------
# Are there any British restaurant that serve moderate priced food?
# {'restaurant-food': 'british', 'restaurant-pricerange': 'moderate'}
# Gold name = british
# Extracted = british
# Post-processed extracted = british
# Correct
# --------
# Hello, I am looking for an expensive restaurant that serves vegetarian food.
# {'restaurant-food': 'vegetarian', 'restaurant-pricerange': 'expensive'}
# Gold name = vegetarian
# Extracted = vegetarian
# Post-processed extracted = vegetarian
# Correct
# --------
# Can you tell me about any german restaurants in the east part of the city?
# {'restaurant-area': 'east', 'restaurant-food': 'german'}
# Gold name = german
# Extracted = german
# Post-processed extracted = german
# Correct
# --------
# Hi, I am looking for a restaurant that is expensive and serves European food.
# {'restaurant-food': 'european', 'restaurant-pricerange': 'expensive'}
# Gold name = european
# Extracted = european
# Post-processed extracted = european
# Correct
# --------
# I would like to dine at a restaurant serving Indian food on the east side of town. Any suggestions?
# {'restaurant-area': 'east', 'restaurant-food': 'indian'}
# Gold name = indian
# Extracted = indian
# Post-processed extracted = indian
# Correct
# --------
# I am looking for a German restaurant in the west part of town.
# {'restaurant-area': 'west', 'restaurant-food': 'german'}
# Gold name = german
# Extracted = german
# Post-processed extracted = german
# Correct
# --------
# Yeah, my wife and kids are demanding Spanish food. Can we keep it on the cheap side, please?
# {'restaurant-food': 'spanish', 'restaurant-pricerange': 'cheap'}
# Gold name = spanish
# Extracted = spanish
# Post-processed extracted = spanish
# Correct
# --------
# I'm needing a place to dine. It needs to be an expensive Brazilian place.
# {'restaurant-food': 'brazilian', 'restaurant-pricerange': 'expensive'}
# Gold name = brazilian
# Extracted = brazilian
# Post-processed extracted = brazilian
# Correct
# --------
# I'm hoping to find a restaurant in the centre that serves British food.
# {'restaurant-area': 'centre', 'restaurant-food': 'british'}
# Gold name = british
# Extracted = british
# Post-processed extracted = british
# Correct
# --------
# I am looking for a restaurant with vegetarian food.
# {'restaurant-food': 'vegetarian'}
# Gold name = vegetarian
# Extracted = vegetarian
# Post-processed extracted = vegetarian
# Correct
# --------
# Is there a modern European restaurant in the north?
# {'restaurant-area': 'north', 'restaurant-food': 'modern european'}
# Gold name = modern european
# Extracted = european
# Post-processed extracted = european
# --------
# Can you find a place in town that serves Polynesian food?
# {'restaurant-food': 'polynesian'}
# Gold name = polynesian
# Extracted = polynesian
# Post-processed extracted = polynesian
# Correct
# --------
# AM looking for a place to dine. The restaurant should be in the south and should serve gastropod food.
# {'restaurant-area': 'south', 'restaurant-food': 'gastropub'}
# Gold name = gastropub
# Extracted = gastropod
# Post-processed extracted = gastropod
# --------
# I'm looking for a chinese restaurant in city centre.
# {'restaurant-area': 'centre', 'restaurant-food': 'chinese'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# I am looking for a restaurant that serves indian food in the west.
# {'restaurant-area': 'west', 'restaurant-food': 'indian'}
# Gold name = indian
# Extracted = indian
# Post-processed extracted = indian
# Correct
# --------
# Hello, are there any moderate turkish restaurants in town?
# {'restaurant-food': 'turkish', 'restaurant-pricerange': 'moderate'}
# Gold name = turkish
# Extracted = turkish
# Post-processed extracted = turkish
# Correct
# --------
# is there a portuguese food restaurant?
# {'restaurant-food': 'portuguese'}
# Gold name = portuguese
# Extracted = portuguese
# Post-processed extracted = portuguese
# Correct
# --------
# I would like to find a French restaurant, please.
# {'restaurant-food': 'french'}
# Gold name = french
# Extracted = french
# Post-processed extracted = french
# Correct
# --------
# Hi! I'd like to find a seafood restaurant in the centre of town, please.
# {'restaurant-area': 'centre', 'restaurant-food': 'seafood'}
# Gold name = seafood
# Extracted = seafood
# Post-processed extracted = sea
# --------
# Hello I am looking for a restaurant that serves Italian food and I need it to be cheap.
# {'restaurant-food': 'italian', 'restaurant-pricerange': 'cheap'}
# Gold name = italian
# Extracted = italian
# Post-processed extracted = italian
# Correct
# --------
# I would like to find a restaurant in any area and it should serve lebanese food.
# {'restaurant-area': 'dontcare', 'restaurant-food': 'lebanese'}
# Gold name = lebanese
# Extracted = lebanese
# Post-processed extracted = lebanese
# Correct
# --------
# I am looking for a Thai restaurant - any area will do.
# {'restaurant-area': 'dontcare', 'restaurant-food': 'thai'}
# Gold name = thai
# Extracted = thai
# Post-processed extracted = thai
# Correct
# --------
# Can you help me find a moderately priced Indian restaurant?
# {'restaurant-food': 'indian', 'restaurant-pricerange': 'moderate'}
# Gold name = indian
# Extracted = indian
# Post-processed extracted = indian
# Correct
# --------
# Hey, is there any good italian food on the eastside?
# {'restaurant-area': 'east', 'restaurant-food': 'italian'}
# Gold name = italian
# Extracted = italian
# Post-processed extracted = italian
# Correct
# --------
# Please help me find an expensive restaurant that serves Chinese food. Thank you.
# {'restaurant-food': 'chinese', 'restaurant-pricerange': 'expensive'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# I would like a restaurant in the centre of town that serves caribbean food
# {'restaurant-area': 'centre', 'restaurant-food': 'caribbean'}
# Gold name = caribbean
# Extracted = caribbean
# Post-processed extracted = caribbean
# Correct
# --------
# I'm looking for an expensive Chinese restaurant.
# {'restaurant-food': 'chinese', 'restaurant-pricerange': 'expensive'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# I am looking for the address and price range of a restaurant serving chinese food in the south part of town.
# {'restaurant-area': 'south', 'restaurant-food': 'chinese'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# Hi! I'm searching for a Panasian restaurant in the south part of town.
# {'restaurant-area': 'south', 'restaurant-food': 'panasian'}
# Gold name = panasian
# Extracted = panasian
# Post-processed extracted = panasian
# Correct
# --------
# I would like to try an expensive, italian place while visiting cambridge.
# {'restaurant-food': 'italian', 'restaurant-pricerange': 'expensive'}
# Gold name = italian
# Extracted = italian
# Post-processed extracted = italian
# Correct
# --------
# I am looking for a place to dine. I would like european food in the expensive price range.
# {'restaurant-food': 'european', 'restaurant-pricerange': 'expensive'}
# Gold name = european
# Extracted = european
# Post-processed extracted = european
# Correct
# --------
# I want to eat someplace with unusual food. Price is no object. What can you suggest?
# {'restaurant-food': 'unusual', 'restaurant-pricerange': 'expensive'}
# Gold name = unusual
# Extracted = unusual food
# Post-processed extracted = unusual
# Correct
# --------
# Howdy! I'm craving some cheap Italian food, you got any place like that?
# {'restaurant-food': 'italian', 'restaurant-pricerange': 'cheap'}
# Gold name = italian
# Extracted = italian
# Post-processed extracted = italian
# Correct
# --------
# I am looking for a restaurant that serves mediterranean food.
# {'restaurant-food': 'mediterranean'}
# Gold name = mediterranean
# Extracted = mediterranean
# Post-processed extracted = mediterranean
# Correct
# --------
# I am looking for an Italian restaurant in the east.
# {'restaurant-area': 'east', 'restaurant-food': 'italian'}
# Gold name = italian
# Extracted = italian
# Post-processed extracted = italian
# Correct
# --------
# Hi. I'm trying to find a restaurant that serves Welsh food. Can you help me?
# {'restaurant-food': 'welsh'}
# Gold name = welsh
# Extracted = welsh
# Post-processed extracted = welsh
# Correct
# --------
# I'm looking for a restaurant that serves Indian food located in the centre.
# {'restaurant-area': 'centre', 'restaurant-food': 'indian'}
# Gold name = indian
# Extracted = indian
# Post-processed extracted = indian
# Correct
# --------
# Are there any Mexican restaurants in the centre?
# {'restaurant-area': 'centre', 'restaurant-food': 'mexican'}
# Gold name = mexican
# Extracted = mexican
# Post-processed extracted = mexican
# Correct
# --------
# Hello, I'm trying to find an expensive asian oriental restaurant. Can you help me find one?
# {'restaurant-food': 'asian oriental', 'restaurant-pricerange': 'expensive'}
# Gold name = asian oriental
# Extracted = asian oriental
# Post-processed extracted = asian oriental
# Correct
# --------
# I'm looking for a Belgian food restaurant in the centre. Can you help me?
# {'restaurant-area': 'centre', 'restaurant-food': 'belgian'}
# Gold name = belgian
# Extracted = belgian
# Post-processed extracted = belgian
# Correct
# --------
# I am looking for a cheap gastropub restaurant in the centre of town
# {'restaurant-area': 'centre', 'restaurant-food': 'gastropub', 'restaurant-pricerange': 'cheap'}
# Gold name = gastropub
# Extracted = gastropub
# Post-processed extracted = gastropub
# Correct
# --------
# Can you tell me if there are any european restaurants in the center of town?
# {'restaurant-area': 'centre', 'restaurant-food': 'european'}
# Gold name = european
# Extracted = european
# Post-processed extracted = european
# Correct
# --------
# I need a place to dine on expensive crossover food.
# {'restaurant-food': 'crossover'}
# Gold name = crossover
# Extracted = crossover food
# Post-processed extracted = crossover
# Correct
# --------
# I'm looking for unusual food in the south part of town.
# {'restaurant-area': 'south', 'restaurant-food': 'unusual'}
# Gold name = unusual
# Extracted = unusual
# Post-processed extracted = unusual
# Correct
# --------
# Could you find me a welsh restaurant in the cheap price range ?
# {'restaurant-food': 'welsh', 'restaurant-pricerange': 'cheap'}
# Gold name = welsh
# Extracted = welsh
# Post-processed extracted = welsh
# Correct
# --------
# I am looking for a chinese restaurant. I want a place that is expensive and classy.
# {'restaurant-food': 'chinese', 'restaurant-pricerange': 'expensive'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# What is that european food place's address?
# {'restaurant-food': 'european'}
# Gold name = european
# Extracted = european
# Post-processed extracted = european
# Correct
# --------
# Looking for someone that serves Australasian food?
# {'restaurant-food': 'australasian'}
# Gold name = australasian
# Extracted = australasian
# Post-processed extracted = australasian
# Correct
# --------
# Do you know of any cheap indian restaurants?
# {'restaurant-food': 'indian', 'restaurant-pricerange': 'cheap'}
# Gold name = indian
# Extracted = indian
# Post-processed extracted = indian
# Correct
# --------
# I'm looking for an English restaurant that's moderately priced..
# {'restaurant-food': 'english', 'restaurant-pricerange': 'moderate'}
# Gold name = english
# Extracted = english
# Post-processed extracted = english
# Correct
# --------
# I'm looking for a chinese restaurant in the center of town.
# {'restaurant-area': 'centre', 'restaurant-food': 'chinese'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# I'm in the east part of town, and I'd like to find a nearby Scandinavian restaurant.
# {'restaurant-area': 'east', 'restaurant-food': 'scandinavian'}
# Gold name = scandinavian
# Extracted = scandinavian
# Post-processed extracted = scandinavian
# Correct
# --------
# I am looking for an expensive restaurant that serves Portuguese food. Please also provide the phone number.
# {'restaurant-food': 'portuguese', 'restaurant-pricerange': 'expensive'}
# Gold name = portuguese
# Extracted = portuguese
# Post-processed extracted = portuguese
# Correct
# --------
# Could you help me find a restaurant that's moderately priced, and services sri lankan cuisine?
# {'restaurant-food': 'sri lankan', 'restaurant-pricerange': 'moderate'}
# Gold name = sri lankan
# Extracted = sri lankan
# Post-processed extracted = sri lankan
# Correct
# --------
# Hello. I want a cheap barbeque restaurant.
# {'restaurant-food': 'barbeque', 'restaurant-pricerange': 'cheap'}
# Gold name = barbeque
# Extracted = barbeque
# Post-processed extracted = barbeque
# Correct
# --------
# Can you help me find a corsica restaurant?
# {'restaurant-food': 'corsica'}
# Gold name = corsica
# Extracted = corsica
# Post-processed extracted = corsica
# Correct
# --------
# I am looking for a restaurant in the centre of town that serves kosher food.
# {'restaurant-area': 'centre', 'restaurant-food': 'kosher'}
# Gold name = kosher
# Extracted = kosher
# Post-processed extracted = kosher
# Correct
# --------
# Hello, I am looking for a moderately priced restaurant that serves gastropub food.
# {'restaurant-food': 'gastropub', 'restaurant-pricerange': 'moderate'}
# Gold name = gastropub
# Extracted = gastropub
# Post-processed extracted = gastropub
# Correct
# --------
# Can you find me an italian restaurant in the centre?
# {'restaurant-area': 'centre', 'restaurant-food': 'italian'}
# Gold name = italian
# Extracted = italian
# Post-processed extracted = italian
# Correct
# --------
# I want a place that serves Swiss food.
# {'restaurant-food': 'swiss'}
# Gold name = swiss
# Extracted = swiss
# Post-processed extracted = swiss
# Correct
# --------
# I am looking for a place to dine. The restaurant should be in the cheap price range and should serve vietnamese food.
# {'restaurant-food': 'vietnamese', 'restaurant-pricerange': 'cheap'}
# Gold name = vietnamese
# Extracted = vietnamese
# Post-processed extracted = vietnamese
# Correct
# --------
# I'd like to find an Italian restaurant, on the west side.
# {'restaurant-area': 'west', 'restaurant-food': 'italian'}
# Gold name = italian
# Extracted = italian
# Post-processed extracted = italian
# Correct
# --------
# I am looking for an expensive place to dine that serves catalan food.
# {'restaurant-food': 'catalan', 'restaurant-pricerange': 'expensive'}
# Gold name = catalan
# Extracted = catalan
# Post-processed extracted = catalan
# Correct
# --------
# I'm looking for a restaurant that serves kosher food in the west side.
# {'restaurant-area': 'west', 'restaurant-food': 'kosher'}
# Gold name = kosher
# Extracted = kosher
# Post-processed extracted = kosher
# Correct
# --------
# Where can I get some British food that isn't too cheap or expensive?
# {'restaurant-food': 'british', 'restaurant-pricerange': 'moderate'}
# Gold name = british
# Extracted = british
# Post-processed extracted = british
# Correct
# --------
# I need to find some caribbean food in south town.
# {'restaurant-area': 'south', 'restaurant-food': 'caribbean'}
# Gold name = caribbean
# Extracted = caribbean
# Post-processed extracted = caribbean
# Correct
# --------
# Can you find me an expensive restaurant that serves steakhouse food?
# {'restaurant-food': 'steakhouse', 'restaurant-pricerange': 'expensive'}
# Gold name = steakhouse
# Extracted = steakhouse
# Post-processed extracted = steakhouse
# Correct
# --------
# I am looking for a restaurant in the expensive price range that serves Belgian food.
# {'restaurant-food': 'belgian', 'restaurant-pricerange': 'expensive'}
# Gold name = belgian
# Extracted = belgian
# Post-processed extracted = belgian
# Correct
# --------
# im looking for a place that serves morden european food and with a cheap price range
# {'restaurant-food': 'european', 'restaurant-pricerange': 'cheap'}
# Gold name = european
# Extracted = morden european
# Post-processed extracted = morden european
# --------
# I'm looking for a restaurant that serves traditional european food, that's not too expensive or too cheap.
# {'restaurant-food': 'european', 'restaurant-pricerange': 'moderate'}
# Gold name = european
# Extracted = european
# Post-processed extracted = european
# Correct
# --------
# Can you help me find an expensive restaurant that serves Chinese food to dine at? Thanks.
# {'restaurant-food': 'chinese', 'restaurant-pricerange': 'expensive'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# I'm looking for an austrian restaurant.
# {'restaurant-food': 'austrian'}
# Gold name = austrian
# Extracted = austrian
# Post-processed extracted = austrian
# Correct
# --------
# I am looking to eat moderate priced British food
# {'restaurant-food': 'british', 'restaurant-pricerange': 'moderate'}
# Gold name = british
# Extracted = british
# Post-processed extracted = british
# Correct
# --------
# I'm looking for a moderately priced Japanese restaurant.
# {'restaurant-food': 'japanese', 'restaurant-pricerange': 'moderate'}
# Gold name = japanese
# Extracted = japanese
# Post-processed extracted = japanese
# Correct
# --------
# i want to find an international restaurant
# {'restaurant-food': 'international'}
# Gold name = international
# Extracted = international
# Post-processed extracted = international
# Correct
# --------
# Find me an expensive restaurant that serves gastropub food
# {'restaurant-food': 'gastropub', 'restaurant-pricerange': 'expensive'}
# Gold name = gastropub
# Extracted = gastropub
# Post-processed extracted = gastropub
# Correct
# --------
# I'm looking for a Chinese restaurant.
# {'restaurant-food': 'chinese'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# I'd like a jamaican restaurant please.
# {'restaurant-food': 'jamaican'}
# Gold name = jamaican
# Extracted = jamaican
# Post-processed extracted = jamaican
# Correct
# --------
# Hi, I'm looking for a European restaurant.
# {'restaurant-food': 'european'}
# Gold name = european
# Extracted = european
# Post-processed extracted = european
# Correct
# --------
# Yes, I'm looking for a steakhouse restaurant in the expensive price range.
# {'restaurant-food': 'steakhouse', 'restaurant-pricerange': 'expensive'}
# Gold name = steakhouse
# Extracted = steakhouse
# Post-processed extracted = steakhouse
# Correct
# --------
# I want english food.
# {'restaurant-food': 'english'}
# Gold name = english
# Extracted = english
# Post-processed extracted = english
# Correct
# --------
# I want to find an expensive restaurant serving christmas food.
# {'restaurant-food': 'christmas', 'restaurant-pricerange': 'expensive'}
# Gold name = christmas
# Extracted = christmas food
# Post-processed extracted = christmas
# Correct
# --------
# I'm looking for hungarian food in the Centre
# {'restaurant-area': 'centre', 'restaurant-food': 'hungarian'}
# Gold name = hungarian
# Extracted = hungarian
# Post-processed extracted = hungarian
# Correct
# --------
# I would like to find a very expensive indian restaurant, can you help me?
# {'restaurant-food': 'indian', 'restaurant-pricerange': 'expensive'}
# Gold name = indian
# Extracted = indian
# Post-processed extracted = indian
# Correct
# --------
# I need to find a good vegetarian restaurant
# {'restaurant-food': 'vegetarian'}
# Gold name = vegetarian
# Extracted = vegetarian
# Post-processed extracted = vegetarian
# Correct
# --------
# I am looking for an expensive Australian place.
# {'restaurant-food': 'australian', 'restaurant-pricerange': 'expensive'}
# Gold name = australian
# Extracted = australian
# Post-processed extracted = australian
# Correct
# --------
# I am looking for a restaurant in the center of town that serves European food.
# {'restaurant-area': 'centre', 'restaurant-food': 'european'}
# Gold name = european
# Extracted = european
# Post-processed extracted = european
# Correct
# --------
# I want to find a place to eat Chinese in the cheap price range.
# {'restaurant-food': 'chinese', 'restaurant-pricerange': 'cheap'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# I'm looking for malaysian food.
# {'restaurant-food': 'malaysian'}
# Gold name = malaysian
# Extracted = malaysian
# Post-processed extracted = malaysian
# Correct
# --------
# I need to find a asian restaurant in Cambridge
# {'restaurant-food': 'asian'}
# Gold name = asian
# Extracted = asian
# Post-processed extracted = asian
# Correct
# --------
# I am looking for a place in the centre of town that serves Thai food.
# {'restaurant-area': 'centre', 'restaurant-food': 'thai'}
# Gold name = thai
# Extracted = thai
# Post-processed extracted = thai
# Correct
# --------
# Are there any cheap Indian restaurants around?
# {'restaurant-food': 'indian', 'restaurant-pricerange': 'cheap'}
# Gold name = indian
# Extracted = indian
# Post-processed extracted = indian
# Correct
# --------
# I'm looking for a gastropub restaurant.
# {'restaurant-food': 'gastropub'}
# Gold name = gastropub
# Extracted = gastropub
# Post-processed extracted = gastropub
# Correct
# --------
# I am in the center are of Cambridge, are there any Japanese restaurants in that part of town?
# {'restaurant-area': 'centre', 'restaurant-food': 'japanese'}
# Gold name = japanese
# Extracted = japanese
# Post-processed extracted = japanese
# Correct
# --------
# I am looking for a restaurant serving spanish food, please.
# {'restaurant-food': 'spanish'}
# Gold name = spanish
# Extracted = spanish
# Post-processed extracted = spanish
# Correct
# --------
# Hi! Are there any European restaurants in the center of town?
# {'restaurant-area': 'centre', 'restaurant-food': 'european'}
# Gold name = european
# Extracted = european
# Post-processed extracted = european
# Correct
# --------
# I would like to book a table at a turkish place and is moderately priced.
# {'restaurant-food': 'turkish', 'restaurant-pricerange': 'moderate'}
# Gold name = turkish
# Extracted = turkish
# Post-processed extracted = turkish
# Correct
# --------
# Find me a cheap vietnamese food place please.
# {'restaurant-food': 'vietnamese', 'restaurant-pricerange': 'cheap'}
# Gold name = vietnamese
# Extracted = vietnamese
# Post-processed extracted = vietnamese
# Correct
# --------
# I am looking for a cheap modern European restaurant. Can you help me?
# {'restaurant-food': 'modern european', 'restaurant-pricerange': 'cheap'}
# Gold name = modern european
# Extracted = european
# Post-processed extracted = european
# --------
# I want to find a cheap restaurant serving hungarian food.
# {'restaurant-food': 'hungarian', 'restaurant-pricerange': 'cheap'}
# Gold name = hungarian
# Extracted = hungarian
# Post-processed extracted = hungarian
# Correct
# --------
# I am looking for a place to dine in the moderate price range and serves European food.
# {'restaurant-food': 'european', 'restaurant-pricerange': 'moderate'}
# Gold name = european
# Extracted = european
# Post-processed extracted = european
# Correct
# --------
# I am looking for a french restaurant.
# {'restaurant-food': 'french'}
# Gold name = french
# Extracted = french
# Post-processed extracted = french
# Correct
# --------
# Can you find me a cheap Spanish restaurant?
# {'restaurant-food': 'spanish', 'restaurant-pricerange': 'cheap'}
# Gold name = spanish
# Extracted = spanish
# Post-processed extracted = spanish
# Correct
# --------
# I am looking for a restaurant that serves British food and in the east part of town.
# {'restaurant-area': 'east', 'restaurant-food': 'british'}
# Gold name = british
# Extracted = british
# Post-processed extracted = british
# Correct
# --------
# I am looking for a vegetarian restaurant near South Cambridge, or a restaurant that has a variety of vegetarian dishes.
# {'restaurant-food': 'vegetarian'}
# Gold name = vegetarian
# Extracted = vegetarian
# Post-processed extracted = vegetarian
# Correct
# --------
# I am looking for a restaurant that serves Japanese food. I don't care about the price range.
# {'restaurant-food': 'japanese', 'restaurant-pricerange': 'dontcare'}
# Gold name = japanese
# Extracted = japanese
# Post-processed extracted = japanese
# Correct
# --------
# Can you help me find a moderately placed modern european restaurant?
# {'restaurant-food': 'european', 'restaurant-pricerange': 'moderate'}
# Gold name = european
# Extracted = european
# Post-processed extracted = european
# Correct
# --------
# I am looking to get some eritrean food in the west part of town.
# {'restaurant-area': 'west', 'restaurant-food': 'eritrean'}
# Gold name = eritrean
# Extracted = eritrean
# Post-processed extracted = eritrean
# Correct
# --------
# I need a restaurant in the cheap price range that serves Portuguese food.
# {'restaurant-food': 'portuguese', 'restaurant-pricerange': 'cheap'}
# Gold name = portuguese
# Extracted = portuguese
# Post-processed extracted = portuguese
# Correct
# --------
# I am looking for a restaurant serving Spanish food.
# {'restaurant-food': 'spanish'}
# Gold name = spanish
# Extracted = spanish
# Post-processed extracted = spanish
# Correct
# --------
# I am looking for a restaurant that serves british food in the west area. Can you locate one for me please?
# {'restaurant-area': 'west', 'restaurant-food': 'british'}
# Gold name = british
# Extracted = british
# Post-processed extracted = british
# Correct
# --------
# I want to find a restaurant in the centre part of town and serves barbeque food. If not then how about modern european food?
# {'restaurant-area': 'centre', 'restaurant-food': 'barbeque'}
# Gold name = barbeque
# Extracted = barbeque
# Post-processed extracted = barbeque
# Correct
# --------
# I don't care about price range, find me an european food restaurant, please.
# {'restaurant-food': 'european', 'restaurant-pricerange': 'dontcare'}
# Gold name = european
# Extracted = european
# Post-processed extracted = european
# Correct
# --------
# I am looking for a restaurant serving seafood, in the center of the town.
# {'restaurant-area': 'centre', 'restaurant-food': 'seafood'}
# Gold name = seafood
# Extracted = seafood
# Post-processed extracted = sea
# --------
# Could you help me find a restaurant with middle-eastern cuisine?
# {'restaurant-food': 'middle eastern'}
# Gold name = middle eastern
# Extracted = middle-eastern
# Post-processed extracted = middle-eastern
# --------
# I am looking for a greek restaurant on the east side of town.
# {'restaurant-area': 'east', 'restaurant-food': 'greek'}
# Gold name = greek
# Extracted = greek
# Post-processed extracted = greek
# Correct
# --------
# I'm looking for a restaurant in the center of town that serves food from the americas.
# {'restaurant-area': 'centre', 'restaurant-food': 'the americas'}
# Gold name = the americas
# Extracted = americas
# Post-processed extracted = americas
# --------
# Please recommend me an expensive restaurant that serves afghan food.
# {'restaurant-food': 'afghan', 'restaurant-pricerange': 'expensive'}
# Gold name = afghan
# Extracted = afghan
# Post-processed extracted = afghan
# Correct
# --------
# I'm looking for a restaurant that serves venetian food.
# {'restaurant-food': 'venetian'}
# Gold name = venetian
# Extracted = venetian
# Post-processed extracted = venetian
# Correct
# --------
# I am looking for an Italian restaurant in the centre of town, could you provide me with some options to choose from please?
# {'restaurant-area': 'centre', 'restaurant-food': 'italian'}
# Gold name = italian
# Extracted = italian
# Post-processed extracted = italian
# Correct
# --------
# I want a cheap Italian restaurant in the south side of town.
# {'restaurant-area': 'south', 'restaurant-food': 'italian', 'restaurant-pricerange': 'cheap'}
# Gold name = italian
# Extracted = italian
# Post-processed extracted = italian
# Correct
# --------
# Where can I find malaysian food? I prefer an expensive restaurant please
# {'restaurant-food': 'malaysian'}
# Gold name = malaysian
# Extracted = malaysian
# Post-processed extracted = malaysian
# Correct
# --------
# Hi I need to find a place to dine serving Vietnamese food in the cheap price range.
# {'restaurant-food': 'vietnamese', 'restaurant-pricerange': 'cheap'}
# Gold name = vietnamese
# Extracted = vietnamese
# Post-processed extracted = vietnamese
# Correct
# --------
# I am looking for a moderately priced chinese restaurant.
# {'restaurant-food': 'chinese', 'restaurant-pricerange': 'moderate'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# Hello, I am looking for a moderately priced restaurant that serves basque food.
# {'restaurant-food': 'basque', 'restaurant-pricerange': 'moderate'}
# Gold name = basque
# Extracted = basque
# Post-processed extracted = basque
# Correct
# --------
# I'm looking for a chinese restaurant in the south part of town.
# {'restaurant-area': 'south', 'restaurant-food': 'chinese'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# I want to find a restaurant in any part of town and serves malaysian food.
# {'restaurant-area': 'dontcare', 'restaurant-food': 'malaysian'}
# Gold name = malaysian
# Extracted = malaysian
# Post-processed extracted = malaysian
# Correct
# --------
# I'm looking for someplace to get British cuisine in the center of town.
# {'restaurant-area': 'centre', 'restaurant-food': 'british'}
# Gold name = british
# Extracted = british
# Post-processed extracted = british
# Correct
# --------
# Hi. This might be a long shot, but can you help me find a restaurant that serves Swedish food? I don't care about price.
# {'restaurant-food': 'swedish', 'restaurant-pricerange': 'dontcare'}
# Gold name = swedish
# Extracted = swedish
# Post-processed extracted = swedish
# Correct
# --------
# I am looking for a danish restaurant in the south part of town.
# {'restaurant-area': 'south', 'restaurant-food': 'danish'}
# Gold name = danish
# Extracted = danish
# Post-processed extracted = danish
# Correct
# --------
# I am searching for a Lebanese restaurant in the east part of town.
# {'restaurant-area': 'east', 'restaurant-food': 'lebanese'}
# Gold name = lebanese
# Extracted = lebanese
# Post-processed extracted = lebanese
# Correct
# --------
# Hello I am looking for a place in the north to dine and they need to serve chinese food
# {'restaurant-area': 'north', 'restaurant-food': 'chinese'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# I'm looking for a place to dine. The restaurant should be in the centre and should serve mediterranean food.
# {'restaurant-area': 'centre', 'restaurant-food': 'mediterranean'}
# Gold name = mediterranean
# Extracted = mediterranean
# Post-processed extracted = mediterranean
# Correct
# --------
# I'm looking for a nice Italian restaurant. Nothing too expensive...like mid range?
# {'restaurant-food': 'italian', 'restaurant-pricerange': 'moderate'}
# Gold name = italian
# Extracted = italian
# Post-processed extracted = italian
# Correct
# --------
# I would like a cheap restaurant that serves malaysian food
# {'restaurant-food': 'malaysian', 'restaurant-pricerange': 'cheap'}
# Gold name = malaysian
# Extracted = malaysian
# Post-processed extracted = malaysian
# Correct
# --------
# Hi. I'm looking for a relatively expensive international restaurant to dine at this evening. Is there one that you would recommend?
# {'restaurant-food': 'international', 'restaurant-pricerange': 'expensive'}
# Gold name = international
# Extracted = international
# Post-processed extracted = international
# Correct
# --------
# I am looking for a restaurant serving Persian food in the expensive price range.
# {'restaurant-food': 'persian', 'restaurant-pricerange': 'expensive'}
# Gold name = persian
# Extracted = persian
# Post-processed extracted = persian
# Correct
# --------
# Hello. I'm trying to find an inexpensive restaurant that serves Moroccan food. Can you help me?
# {'restaurant-food': 'moroccan', 'restaurant-pricerange': 'cheap'}
# Gold name = moroccan
# Extracted = moroccan
# Post-processed extracted = moroccan
# Correct
# --------
# Really would like to find a place that serves Indian food in the North
# {'restaurant-area': 'north', 'restaurant-food': 'indian'}
# Gold name = indian
# Extracted = indian
# Post-processed extracted = indian
# Correct
# --------
# I'd like information about a restaurant in South that serves English food.
# {'restaurant-area': 'south', 'restaurant-food': 'english'}
# Gold name = english
# Extracted = english
# Post-processed extracted = english
# Correct
# --------
# I want a restaurant serving mediterranean food and I don't care about the price range.
# {'restaurant-food': 'mediterranean', 'restaurant-pricerange': 'dontcare'}
# Gold name = mediterranean
# Extracted = mediterranean
# Post-processed extracted = mediterranean
# Correct
# --------
# Hey, could you tell me if there are any panasian restaurants in the east side of town?
# {'restaurant-area': 'east', 'restaurant-food': 'panasian'}
# Gold name = panasian
# Extracted = panasian
# Post-processed extracted = panasian
# Correct
# --------
# I'm looking for a pricey Indian place. I wanna show off to my date.
# {'restaurant-food': 'indian', 'restaurant-pricerange': 'expensive'}
# Gold name = indian
# Extracted = indian
# Post-processed extracted = indian
# Correct
# --------
# I'm looking for a posh British restaurant to take my bird to, know of one?
# {'restaurant-food': 'british', 'restaurant-pricerange': 'expensive'}
# Gold name = british
# Extracted = british
# Post-processed extracted = british
# Correct
# --------
# I am looking for a place to dine that serves Sri Lankan food in the moderate price range.
# {'restaurant-food': 'sri lankan', 'restaurant-pricerange': 'moderate'}
# Gold name = sri lankan
# Extracted = sri lankan
# Post-processed extracted = sri lankan
# Correct
# --------
# Is there an expensive restaurant serving caribbean food?
# {'restaurant-food': 'caribbean', 'restaurant-pricerange': 'expensive'}
# Gold name = caribbean
# Extracted = caribbean
# Post-processed extracted = caribbean
# Correct
# --------
# I'm looking for a portuguese restaurant in the south side.
# {'restaurant-area': 'south', 'restaurant-food': 'portuguese'}
# Gold name = portuguese
# Extracted = portuguese
# Post-processed extracted = portuguese
# Correct
# --------
# Hello, I am looking for info on a restaurant in the west that serves french food.
# {'restaurant-area': 'west', 'restaurant-food': 'french'}
# Gold name = french
# Extracted = french
# Post-processed extracted = french
# Correct
# --------
# I have to book a place to eat that serves irish food and is located in the centre, can you help me?
# {'restaurant-area': 'centre', 'restaurant-food': 'irish'}
# Gold name = irish
# Extracted = irish
# Post-processed extracted = irish
# Correct
# --------
# I'm looking for a gastropub food restaurant in the centre of Cambridge please.
# {'restaurant-area': 'centre', 'restaurant-food': 'gastropub'}
# Gold name = gastropub
# Extracted = gastropub
# Post-processed extracted = gastropub
# Correct
# --------
# I'm looking for a casual Sri Lankan restaurant.
# {'restaurant-food': 'sri lankan'}
# Gold name = sri lankan
# Extracted = sri lankan
# Post-processed extracted = sri lankan
# Correct
# --------
# I am looking for an expensive Italian restaurant.
# {'restaurant-food': 'italian', 'restaurant-pricerange': 'expensive'}
# Gold name = italian
# Extracted = italian
# Post-processed extracted = italian
# Correct
# --------
# looking for barbeque food.
# {'restaurant-food': 'barbeque'}
# Gold name = barbeque
# Extracted = barbeque
# Post-processed extracted = barbeque
# Correct
# --------
# I'd like a european food place in the west please.
# {'restaurant-area': 'west', 'restaurant-food': 'european'}
# Gold name = european
# Extracted = european
# Post-processed extracted = european
# Correct
# --------
# I am looking for an expensive restaurant that serves russian food.
# {'restaurant-food': 'russian', 'restaurant-pricerange': 'expensive'}
# Gold name = russian
# Extracted = russian
# Post-processed extracted = russian
# Correct
# --------
# need a place to eat european food, expensive too.
# {'restaurant-food': 'european', 'restaurant-pricerange': 'expensive'}
# Gold name = european
# Extracted = european
# Post-processed extracted = european
# Correct
# --------
# Hello, I am looking for an expensive restaurant that serves fusion food.
# {'restaurant-food': 'fusion', 'restaurant-pricerange': 'expensive'}
# Gold name = fusion
# Extracted = fusion
# Post-processed extracted = fusion
# Correct
# --------
# Can you help me find a place to eat that serves unusual food in the centre?
# {'restaurant-area': 'centre', 'restaurant-food': 'unusual'}
# Gold name = unusual
# Extracted = unusual food
# Post-processed extracted = unusual
# Correct
# --------
# Hello, I am looking for a restaurant that serves vegetarian food.
# {'restaurant-food': 'vegetarian'}
# Gold name = vegetarian
# Extracted = vegetarian
# Post-processed extracted = vegetarian
# Correct
# --------
# Is it possible to get any Greek food in the centre part of town?
# {'restaurant-food': 'greek'}
# Gold name = greek
# Extracted = greek
# Post-processed extracted = greek
# Correct
# --------
# I am looking for a cuban restaurant in the north part of town.
# {'restaurant-area': 'north', 'restaurant-food': 'cuban'}
# Gold name = cuban
# Extracted = cuban
# Post-processed extracted = cuban
# Correct
# --------
# I am trying to find a restaurant in the south of the city that serves modern American food.
# {'restaurant-area': 'south', 'restaurant-food': 'modern american'}
# Gold name = modern american
# Extracted = modern american
# Post-processed extracted = modern american
# Correct
# --------
# I would like to find a Danish restaurant with a moderate price range.
# {'restaurant-food': 'danish', 'restaurant-pricerange': 'moderate'}
# Gold name = danish
# Extracted = danish
# Post-processed extracted = danish
# Correct
# --------
# I would like a restaurant in the east part of town that serves british food
# ...
# Correct
# --------
# Hello, I am trying to locate a restaurant that serves northern European food, and I would prefer a more elegant setting.
# {'restaurant-food': 'northern european'}
# Gold name = northern european
# Extracted = northern european
# Post-processed extracted = northern european
# Correct
# --------
# I'm looking for a mexican restaurant in the south part of town.
# {'restaurant-area': 'south', 'restaurant-food': 'mexican'}
# Gold name = mexican
# Extracted = mexican
# Post-processed extracted = mexican
# Correct
# --------
# I am looking for the phone number and address of a restaurant that serves european food?
# {'restaurant-food': 'european'}
# Gold name = european
# Extracted = european
# Post-processed extracted = european
# Correct
# --------
# Hi, I'd like to find an expensive cantonese restaurant.
# {'restaurant-food': 'cantonese', 'restaurant-pricerange': 'expensive'}
# Gold name = cantonese
# Extracted = cantonese
# Post-processed extracted = cantonese
# Correct
# --------
# Hello, I am looking for a restaurant that serves African food.
# {'restaurant-food': 'african'}
# Gold name = african
# Extracted = african
# Post-processed extracted = african
# Correct
# --------
# I'm looking for some Chinese food, any good places in town?
# {'restaurant-food': 'chinese'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# Hi, I'm trying to find a moderate turkish place to eat at. Is there anything like that?
# {'restaurant-food': 'turkish', 'restaurant-pricerange': 'moderate'}
# Gold name = turkish
# Extracted = turkish
# Post-processed extracted = turkish
# Correct
# --------
# I am looking for a restaurant in the moderate price range that serves Lebanese food.
# {'restaurant-food': 'lebanese', 'restaurant-pricerange': 'moderate'}
# Gold name = lebanese
# Extracted = lebanese
# Post-processed extracted = lebanese
# Correct
# --------
# I need to find a place to dine in the expensive price range that serves indian food.
# {'restaurant-food': 'indian', 'restaurant-pricerange': 'expensive'}
# Gold name = indian
# Extracted = indian
# Post-processed extracted = indian
# Correct
# --------
# I need a restaurant in the east part of town that serves world food.
# {'restaurant-area': 'east', 'restaurant-food': 'world'}
# Gold name = world
# Extracted = world
# Post-processed extracted = world
# Correct
# --------
# I'm looking for a place to dine. The restaurant should serve indian food and should be in the centre.
# {'restaurant-area': 'centre', 'restaurant-food': 'indian'}
# Gold name = indian
# Extracted = indian
# Post-processed extracted = indian
# Correct
# --------
# Hi, I'd like a listing for a Mediterranean restaurant.
# {'restaurant-food': 'mediterranean'}
# Gold name = mediterranean
# Extracted = mediterranean
# Post-processed extracted = mediterranean
# Correct
# --------
# I'm looking for a cheap place to dine that serves danish food.
# {'restaurant-food': 'danish', 'restaurant-pricerange': 'cheap'}
# Gold name = danish
# Extracted = danish
# Post-processed extracted = danish
# Correct
# --------
# I want to find a restaurant in any part of town and serves seafood.
# {'restaurant-area': 'dontcare', 'restaurant-food': 'seafood'}
# Gold name = seafood
# Extracted = seafood
# Post-processed extracted = sea
# --------
# I am looking for a moderately priced restaurant that serves Caribbean food.
# {'restaurant-food': 'caribbean', 'restaurant-pricerange': 'moderate'}
# Gold name = caribbean
# Extracted = caribbean
# Post-processed extracted = caribbean
# Correct
# --------
# Yes I would like to find Spanish food in the center of town.
# {'restaurant-area': 'centre', 'restaurant-food': 'spanish'}
# Gold name = spanish
# Extracted = spanish
# Post-processed extracted = spanish
# Correct
# --------
# I am looking for a Persian restaurant with expensive price range food.
# {'restaurant-food': 'persian', 'restaurant-pricerange': 'expensive'}
# Gold name = persian
# Extracted = persian
# Post-processed extracted = persian
# Correct
# --------
# Hi there, can you help me find a restaurant in the centre of town? Someplace with British food?
# {'restaurant-area': 'centre', 'restaurant-food': 'british'}
# Gold name = british
# Extracted = british
# Post-processed extracted = british
# Correct
# --------
# I need to find a moderately priced north indian restaurant.
# {'restaurant-food': 'north indian', 'restaurant-pricerange': 'moderate'}
# Gold name = north indian
# Extracted = north indian
# Post-processed extracted = north indian
# Correct
# --------
# I need some tacos! Can you help me find a Mexican restaurant on the south side of the city?
# {'restaurant-area': 'south', 'restaurant-food': 'mexican'}
# Gold name = mexican
# Extracted = mexican
# Post-processed extracted = mexican
# Correct
# --------
# I want to have some afghan food.
# {'restaurant-food': 'afghan'}
# Gold name = afghan
# Extracted = afghan
# Post-processed extracted = afghan
# Correct
# --------
# I am looking for a place to dine. The restaurant should serve african food and should be in the centre
# {'restaurant-area': 'centre', 'restaurant-food': 'african'}
# Gold name = african
# Extracted = african
# Post-processed extracted = african
# Correct
# --------
# I am looking for an Italian restaurant in the west part of town
# {'restaurant-area': 'west', 'restaurant-food': 'italian'}
# Gold name = italian
# Extracted = italian
# Post-processed extracted = italian
# Correct
# --------
# I need help finding a book on italian food
# {'restaurant-food': 'italian'}
# Gold name = italian
# Extracted = italian
# Post-processed extracted = italian
# Correct
# --------
# Hi, i am looking for a middle eastern restaurant in the expensive price range.
# {'restaurant-food': 'middle eastern', 'restaurant-pricerange': 'expensive'}
# Gold name = middle eastern
# Extracted = middle eastern
# Post-processed extracted = middle eastern
# Correct
# --------
# Where can I find a moderately priced restaurant that serves European food?
# {'restaurant-food': 'european', 'restaurant-pricerange': 'moderate'}
# Gold name = european
# Extracted = european
# Post-processed extracted = european
# Correct
# --------
# Is there a latin american restaurant in the center?
# {'restaurant-area': 'centre', 'restaurant-food': 'latin american'}
# Gold name = latin american
# Extracted = latin american
# Post-processed extracted = latin american
# Correct
# --------
# I am looking for a restaurant in the centre that serves indian food.
# {'restaurant-area': 'centre', 'restaurant-food': 'indian'}
# Gold name = indian
# Extracted = indian
# Post-processed extracted = indian
# Correct
# --------
# I need the phone number of a restaurant in the west part of town that serves italian ood.
# {'restaurant-area': 'west', 'restaurant-food': 'italian'}
# Gold name = italian
# Extracted = italian
# Post-processed extracted = italian
# Correct
# --------
# I need a restaurant in Cambridge that has international food and a moderate price range please.
# {'restaurant-food': 'international', 'restaurant-pricerange': 'moderate'}
# Gold name = international
# Extracted = international
# Post-processed extracted = international
# Correct
# --------
# A cheap jamaican restaurant, please. If you cannot find one, then mediterranean.
# {'restaurant-food': 'jamaican', 'restaurant-pricerange': 'cheap'}
# Gold name = jamaican
# Extracted = jamaican
# Post-processed extracted = jamaican
# Correct
# --------
# Could you tell me if Cambridge has any expensive Austrian restaurants?
# {'restaurant-food': 'austrian', 'restaurant-pricerange': 'expensive'}
# Gold name = austrian
# Extracted = austrian
# Post-processed extracted = austrian
# Correct
# --------
# I am looking for an expensive restaurant that serves Persian food.
# {'restaurant-food': 'persian', 'restaurant-pricerange': 'expensive'}
# Gold name = persian
# Extracted = persian
# Post-processed extracted = persian
# Correct
# --------
# I need a place to eat that serves north indian food.
# {'restaurant-food': 'north indian'}
# Gold name = north indian
# Extracted = north indian
# Post-processed extracted = north indian
# Correct
# --------
# Would you be able to tell me where to find a moderately priced, Halal restaurant?
# {'restaurant-food': 'halal', 'restaurant-pricerange': 'moderate'}
# Gold name = halal
# Extracted = halal
# Post-processed extracted = halal
# Correct
# --------
# I am looking for an expensive restaurant that serves Korean food. I would like the address and area, please.
# {'restaurant-food': 'korean', 'restaurant-pricerange': 'expensive'}
# Gold name = korean
# Extracted = korean
# Post-processed extracted = korean
# Correct
# --------
# I'm coming to visit Cambridge! I can't wait to see all of the local tourist attractions! Do you have any Mediterranean restaurants around there?
# {'restaurant-food': 'mediterranean'}
# Gold name = mediterranean
# Extracted = mediterranean
# Post-processed extracted = mediterranean
# Correct
# --------
# Can you help me find a moderately priced Indian food restaurant?
# {'restaurant-food': 'indian', 'restaurant-pricerange': 'moderate'}
# Gold name = indian
# Extracted = indian
# Post-processed extracted = indian
# Correct
# --------
# Hello! I'm looking for a nice restaurant that serves Scottish food. Can you recommend one?
# {'restaurant-food': 'scottish'}
# Gold name = scottish
# Extracted = scottish
# Post-processed extracted = scottish
# Correct
# --------
# Please see if you can find me an Indian restaurant on the East end
# {'restaurant-area': 'east', 'restaurant-food': 'indian'}
# Gold name = indian
# Extracted = indian
# Post-processed extracted = indian
# Correct
# --------
# Id like to eat at an expensive Indian place, know any?
# {'restaurant-food': 'indian', 'restaurant-pricerange': 'expensive'}
# Gold name = indian
# Extracted = indian
# Post-processed extracted = indian
# Correct
# --------
# Can you please help me find a cheap italian restaurant?
# {'restaurant-food': 'italian', 'restaurant-pricerange': 'cheap'}
# Gold name = italian
# Extracted = italian
# Post-processed extracted = italian
# Correct
# --------
# I am looking for a Cuban food place, in the east.
# {'restaurant-area': 'east', 'restaurant-food': 'cuban'}
# Gold name = cuban
# Extracted = cuban
# Post-processed extracted = cuban
# Correct
# --------
# I would like a moderately priced steakhouse restaurant.
# {'restaurant-food': 'steakhouse', 'restaurant-pricerange': 'moderate'}
# Gold name = steakhouse
# Extracted = steakhouse
# Post-processed extracted = steakhouse
# Correct
# --------
# You may help me by finding a Muslim restaurant for me to eat at please.
# {'restaurant-food': 'muslim'}
# Gold name = muslim
# Extracted = muslim
# Post-processed extracted = muslim
# Correct
# --------
# I want a moderately priced restaurant and serves asian oriental food. What is the address and phone number?
# {'restaurant-food': 'asian oriental', 'restaurant-pricerange': 'moderate'}
# Gold name = asian oriental
# Extracted = asian oriental
# Post-processed extracted = asian oriental
# Correct
# --------
# Do you have any restaurants that serve caribbean food?
# {'restaurant-food': 'caribbean'}
# Gold name = caribbean
# Extracted = caribbean
# Post-processed extracted = caribbean
# Correct
# --------
# I would like a cheap restaurant that serves mediterranean food
# {'restaurant-food': 'mediterranean', 'restaurant-pricerange': 'cheap'}
# Gold name = mediterranean
# Extracted = mediterranean
# Post-processed extracted = mediterranean
# Correct
# --------
# I am looking for a place serving christmas food in the centre of town.
# {'restaurant-area': 'centre', 'restaurant-food': 'christmas'}
# Gold name = christmas
# Extracted = christmas food
# Post-processed extracted = christmas
# Correct
# --------
# I am looking for some info on India House
# {'restaurant-area': 'dontcare', 'restaurant-food': 'dontcare', 'restaurant-name': 'india house', 'restaurant-pricerange': 'dontcare'}
# Gold name = dontcare
# Extracted = india house
# Post-processed extracted = india house
# --------
# I am looking for a place to eat in the moderate price range serving Indian food.
# {'restaurant-food': 'indian', 'restaurant-pricerange': 'moderate'}
# Gold name = indian
# Extracted = indian
# Post-processed extracted = indian
# Correct
# --------
# Hello, I'm looking for a modern European restaurant. Got any?
# {'restaurant-food': 'modern european'}
# Gold name = modern european
# Extracted = european
# Post-processed extracted = european
# --------
# I am looking for a restaurant that serves indian food.
# {'restaurant-food': 'indian'}
# Gold name = indian
# Extracted = indian
# Post-processed extracted = indian
# Correct
# --------
# I want to know if there are any places serving Belgian food in the centre?
# {'restaurant-area': 'centre', 'restaurant-food': 'belgian'}
# Gold name = belgian
# Extracted = belgian
# Post-processed extracted = belgian
# Correct
# --------
# I am looking for a restaurant in the center of town that serves Russian food.
# {'restaurant-area': 'centre', 'restaurant-food': 'russian'}
# Gold name = russian
# Extracted = russian
# Post-processed extracted = russian
# Correct
# --------
# I'm looking for a place to eat in Cambridge. I'd like to eat light bites in the mid price range please.
# {'restaurant-food': 'light bites', 'restaurant-pricerange': 'moderate'}
# Gold name = light bites
# Extracted = light bites
# Post-processed extracted = light bites
# Correct
# --------
# Find me a place to dine on some cheap foods from the americas please.
# {'restaurant-food': 'the americas', 'restaurant-pricerange': 'cheap'}
# Gold name = the americas
# Extracted = americas
# Post-processed extracted = americas
# --------
# I would like a restaurant in the north part of town that serves australasian food
# {'restaurant-area': 'north', 'restaurant-food': 'australasian'}
# Gold name = australasian
# Extracted = australasian
# Post-processed extracted = australasian
# Correct
# --------
# Hi! I'm planning my trip to Cambridge and I was wondering if you had information on any Mediterranean restaurants located in the centre of Cambridge?
# {'restaurant-area': 'centre', 'restaurant-food': 'mediterranean'}
# Gold name = mediterranean
# Extracted = mediterranean
# Post-processed extracted = mediterranean
# Correct
# --------
# I'm looking for an expensive indian restaurant.
# {'restaurant-food': 'indian', 'restaurant-pricerange': 'expensive'}
# Gold name = indian
# Extracted = indian
# Post-processed extracted = indian
# Correct
# --------
# I would like a restaurant in the east part of town that serves gastropub food
# {'restaurant-area': 'east', 'restaurant-food': 'gastropub'}
# Gold name = gastropub
# Extracted = gastropub
# Post-processed extracted = gastropub
# Correct
# --------
# Can you find me a Turkish restaurant in the expensive price range please?
# {'restaurant-food': 'turkish', 'restaurant-pricerange': 'expensive'}
# Gold name = turkish
# Extracted = turkish
# Post-processed extracted = turkish
# Correct
# --------
# I would like a restaurant in the west part of town that serves international food
# {'restaurant-area': 'west', 'restaurant-food': 'international'}
# Gold name = international
# Extracted = international
# Post-processed extracted = international
# Correct
# --------
# Hello, I'm looking for an expensive restaurant that serves british food please
# {'restaurant-food': 'british', 'restaurant-pricerange': 'expensive'}
# Gold name = british
# Extracted = british
# Post-processed extracted = british
# Correct
# --------
# Can you help me find a Russian restaurant?
# {'restaurant-food': 'russian'}
# Gold name = russian
# Extracted = russian
# Post-processed extracted = russian
# Correct
# --------
# I'm looking for a steakhouse restaurant in the east part of town.
# {'restaurant-area': 'east', 'restaurant-food': 'steakhouse'}
# Gold name = steakhouse
# Extracted = steakhouse
# Post-processed extracted = steakhouse
# Correct
# --------
# Greetings, got any British food places in town?
# {'restaurant-food': 'british'}
# Gold name = british
# Extracted = british
# Post-processed extracted = british
# Correct
# --------
# Hi! I need a restaurant that serves Chinese food please!
# {'restaurant-food': 'chinese'}
# Gold name = chinese
# Extracted = chinese
# Post-processed extracted = chinese
# Correct
# --------
# Find me a modern european restaurant in the south.
# {'restaurant-area': 'south', 'restaurant-food': 'modern european'}
# Gold name = modern european
# Extracted = european
# Post-processed extracted = european
# --------
# Hello, I am looking for a cheap restaurant that serves german food.
# {'restaurant-food': 'german', 'restaurant-pricerange': 'cheap'}
# Gold name = german
# Extracted = german
# Post-processed extracted = german
# Correct
# --------
# Completed

# %%
score = correct_count * 100 / max_row
print(f"Accuracy = {score:.1f} %")
# Out:
# Accuracy = 94.3 %

# %%
print("Wrong counts =", len(wrong_preds))
for text, sys, gold in wrong_preds:
    print("Text =", text)
    print("Sys =", sys)
    print("Gold =", gold)
    print("-----")
# Out:
# Wrong counts = 63
# Text = Heya, can you find me an expensive restaurant with north african food?
# Sys = north african
# Gold = african
# -----
# Text = I want something that's moderately priced. Any type of food.
# Sys = any type of
# Gold = dontcare
# -----
# Text = I'm looking for a moderate priced place to dine serving modern european food.
# Sys = european
# Gold = modern european
# -----
# Text = I'm looking for a restaurant in the centre serving modern european food.
# Sys = european
# Gold = modern european
# -----
# Text = I'm so hungry! Can you find me a really great modern european restaurant? Money is no object!
# Sys = european
# Gold = modern european
# -----
# Text = Is there a modern European restaurant in the north?
# Sys = european
# Gold = modern european
# -----
# Text = AM looking for a place to dine. The restaurant should be in the south and should serve gastropod food.
# Sys = gastropod
# Gold = gastropub
# -----
# Text = Hi! I'd like to find a seafood restaurant in the centre of town, please.
# Sys = sea
# Gold = seafood
# -----
# Text = im looking for a place that serves morden european food and with a cheap price range
# Sys = morden european
# Gold = european
# -----
# Text = I am looking for a cheap modern European restaurant. Can you help me?
# Sys = european
# Gold = modern european
# -----
# Text = I am looking for a restaurant serving seafood, in the center of the town.
# Sys = sea
# Gold = seafood
# -----
# Text = Could you help me find a restaurant with middle-eastern cuisine?
# Sys = middle-eastern
# Gold = middle eastern
# -----
# Text = I'm looking for a restaurant in the center of town that serves food from the americas.
# Sys = americas
# Gold = the americas
# -----
# Text = I am looking for a nice bistro in Cambridge, moderately priced would be good.
# Sys = cambridge moderately priced would be good
# Gold = bistro
# -----
# Text = I am looking for a restaurant that servers modern european food.
# Sys = european
# Gold = modern european
# -----
# Text = Hi, is there a moderately priced international cuisine restaurant in Cambridge?
# Sys = international cuisine
# Gold = international
# -----
# Text = Hi, are there any modern global restaurants in the centre?
# Sys = global
# Gold = modern global
# -----
# Text = I am looking for a place to eat. I want to eat modern european food in the expensive price range please.
# Sys = european
# Gold = modern european
# -----
# Text = I am looking for a restaurant that sell seafood,will prefer one in the center of the city.
# Sys = sea
# Gold = seafood
# -----
# Text = We want to try a local restaurant that serves Asian or oriental food.
# Sys = asian or oriental
# Gold = asian oriental
# -----
# Text = I'm looking for a gastropub in the east.
# Sys = gastropub in the east
# Gold = gastropub
# -----
# Text = I'm looking for unusual and expensive cuisine in the west. Do you have any suggestions?
# Sys = west
# Gold = unusual
# -----
# Text = I'm looking for a seafood restaurant in the moderate price range.
# Sys = sea
# Gold = seafood
# -----
# Text = Hi, I'm looking for a place to eat, preferably a cheap South Indian restaurant.
# Sys = south indian
# Gold = indian
# -----
# Text = Hi, I'm looking for a restaurant that serves Carribbean food. Do you have any like that?
# Sys = carribbean
# Gold = caribbean
# -----
# Text = Need a place to eat, modern euro food at the centre.
# Sys = modern euro
# Gold = modern
# -----
# Text = Hello! I'm looking for a cheap restaurant that serves modern global food.
# Sys = global
# Gold = modern global
# -----
# Text = Hello there. Any suggestions on a good seafood restaurant located in the centre of town?
# Sys = sea
# Gold = seafood
# -----
# Text = I'm looking for a cheap restaurant that serves modern european food.
# Sys = european
# Gold = modern european
# -----
# Text = Are there any restaurants in town that serve modern american food?
# Sys = american
# Gold = modern american
# -----
# Text = I really need to find a restaurant that serves modern european food. An expensive one is fine.
# Sys = european
# Gold = modern european
# -----
# Text = I'm looking for a cheap restaurant that serves portugese food.
# Sys = portugese
# Gold = portuguese
# -----
# Text = I'm looking for a place to dine in the centre of town that serves modern european food.
# Sys = european
# Gold = modern european
# -----
# Text = I'm looking for a modern european restaurant that had a moderate price range.
# Sys = european
# Gold = modern european
# -----
# Text = Hi there, I'm hungry. Please help me find a cheap place that serves the americas food
# Sys = americas
# Gold = the americas
# -----
# Text = I'm looking for a very nice place to dine. Something expensive.
# Sys = expensive
# Gold = dontcare
# -----
# Text = im looking for a place to dine, it should be in the south serving morden global food
# Sys = morden global
# Gold = global
# -----
# Text = Are there any crossover restaurants in the west?
# Sys = crossover restaurants in the west
# Gold = crossover
# -----
# Text = Hello! I'm looking for a restaurant that serves modern global food in the centre.
# Sys = global
# Gold = modern global
# -----
# Text = I am looking for a moderately priced restaurant in the south part of town. Any kind of food is good with me; I would just like to know the phone number of the venue you find.
# Sys = any kind of
# Gold = dontcare
# -----
# Text = I'm interested in finding a modern European restaurant for dinner with a moderate price range on their menu.
# Sys = european
# Gold = modern european
# -----
# Text = I'm looking for a seafood restaurant in the centre.
# Sys = sea
# Gold = seafood
# -----
# Text = I'd like to find an expensive gastropub, should you have such a beast.
# Sys = gastropub should you have such a beast
# Gold = gastropub
# -----
# Text = Hello, I'm looking for a restaurant that serves mondern european foods for modest prices.
# Sys = mondern european
# Gold = european
# -----
# Text = Good eve! I'm looking for a nice place to have a spot of afternoon tea.
# Sys = tea
# Gold = afternoon tea
# -----
# Text = I am looking for a modern European restaurant in the moderate range.
# Sys = european
# Gold = modern european
# -----
# Text = I'm looking for a modern european restaurant in the centre.
# Sys = european
# Gold = modern european
# -----
# Text = Can you help me find a cheapt italian restaurant?
# Sys = cheapt italian
# Gold = italian
# -----
# Text = Yes, I'm looking for a restaurant that serves American food and is in the center of town.
# Sys = american
# Gold = north american
# -----
# Text = I need a place to eat that serves sea food.
# Sys = sea
# Gold = seafood
# -----
# Text = Hi , can you recommend an inexpensive seafood restaurant?
# Sys = sea
# Gold = seafood
# -----
# Text = Is there any expensive seafood restaurant in town?
# Sys = sea
# Gold = seafood
# -----
# Text = Hello, I'm looking for a modern european restaurant in the center.
# Sys = european
# Gold = modern european
# -----
# Text = I want to find a seafood restaurant in the centre
# Sys = sea
# Gold = seafood
# -----
# Text = Hi! I'm looking for a cheap restaurant in the north, any type!
# Sys = cheap restaurant in the north
# Gold = dontcare
# -----
# Text = Hi, I want to eat at an expensive seafood restaurant in Cambridge. Where can I go?
# Sys = sea
# Gold = seafood
# -----
# Text = I need a place for a modern european food. Moderate range ought to do it. Thank you.
# Sys = european
# Gold = modern european
# -----
# Text = I am looking for a restaurant in the city center that serves modern European food.
# Sys = modern european
# Gold = european
# -----
# Text = I want to find a restaurant in any part of town and serves seafood.
# Sys = sea
# Gold = seafood
# -----
# Text = I am looking for some info on India House
# Sys = india house
# Gold = dontcare
# -----
# Text = Hello, I'm looking for a modern European restaurant. Got any?
# Sys = european
# Gold = modern european
# -----
# Text = Find me a place to dine on some cheap foods from the americas please.
# Sys = americas
# Gold = the americas
# -----
# Text = Find me a modern european restaurant in the south.
# Sys = european
# Gold = modern european
# -----
